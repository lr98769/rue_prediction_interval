# %% [markdown]
# # Data Preprocessing

# %%
# Important libraries
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
import csv
from wordcloud import WordCloud
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt

# File paths
fp_notebooks_folder = "./"
fp_code_folder = "../"
fp_processed_folder = os.path.join(fp_code_folder, "../processed_data")
fp_converted_folder = os.path.join(fp_processed_folder, "converted_to_csv")
fp_downsampled_folder = os.path.join(fp_processed_folder, "downsampled")
fp_downsampled_continuous_file = os.path.join(fp_downsampled_folder, "continous.csv")
fp_downsampled_continuous_ae_file = os.path.join(fp_downsampled_folder, "continous_ae.csv")
fp_downsampled_dropna_file = os.path.join(fp_downsampled_folder, "dropna.csv")
fp_fields_file = os.path.join(fp_converted_folder, "fields.csv")

# %%
# Get fields file to analyse
fields_df = pd.read_csv(fp_fields_file, quoting=csv.QUOTE_NONE, escapechar='/', index_col=0)
fields_df
# Out:
#            fs  sig_len  n_sig   base_date base_time  \
# 0    0.976562    51138      7  1994-12-13  08:38:53
# 1    0.976562    77038      7  1995-02-22  13:08:55
# 2    0.976562   141796      7  1995-02-24  09:44:42
# 3    0.976562   131250     12  1995-03-02  15:36:24
# 4    0.976562     4606      5  1995-01-24  08:22:11
# ..        ...      ...    ...         ...       ...
# 111  0.976562   151176     14  1996-04-06  15:26:26
# 112  0.976562   147656     15  1996-04-22  17:35:49
# 113  0.976562   154687     12  1996-04-29  14:48:52
# 114  0.976562   193946     18  1996-05-02  11:54:49
# 115  0.976562   178121      4  1996-06-23  15:01:25
#
#                                                  units  \
# 0    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 1    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 2    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 3    ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 4                 ['mmHg', 'mmHg', 'mmHg', 'bpm', '%']
# ..                                                 ...
# 111  ['mmHg', 'mmHg', 'mmHg', 'lpm', 'mmHg', 'bpm',...
# 112  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'lpm', 'mmHg',...
# 113  ['mmHg', 'mmHg', 'mmHg', 'lpm', 'mmHg', 'bpm',...
# 114  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'lpm', 'mmHg',...
# 115                        ['lpm', 'bpm', '%', 'degC']
#
#                                               sig_name comments  \
# 0    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 1    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 2    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 3    ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 4     ['NBPmean', 'NBPsys', 'NBPdias', 'RESP', 'SpO2']       []
# ..                                                 ...      ...
# 111  ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'CVP'...       []
# 112  ['ABPmean', 'ABPsys', 'ABPdias', 'AWRR', 'C.O....       []
# 113  ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'CVP'...       []
# 114  ['ABPmean', 'ABPsys', 'ABPdias', 'AWRR', 'C.O....       []
# 115                 ['C.O.', 'RESP', 'SpO2', 'Tblood']       []
#
#                                          unique_alarms record
# 0    {'*ASYSTOLE': 23, '*TACHY 216 > 180': 9, '*VEN...   048n
# 1    {'ABP  184 > 180': 115, 'ABP  182 > 180': 115,...   052n
# 2    {'PAIR VPBs': 982, 'HR  53 <  55': 560, 'MULTI...   054n
# 3    {'VPBs > 5/MIN': 1661, 'PAIR VPBs': 1584, 'MUL...   055n
# 4                             {'MULTIFORM VPBs': 4600}   208n
# ..                                                 ...    ...
# 111  {'VPBs > 5/MIN': 20341, 'VPBs > 11/MIN': 1085,...   482n
# 112  {'IRREGULAR HR': 19031, 'MULTIFORM VPBs': 1982...   484n
# 113  {'PAIR VPBs': 731, 'VPBs > 11/MIN': 567, 'IRRE...   485n
# 114  {'PAIR VPBs': 4158, 'RUN VPBs 3 - 9': 1688, 'M...   486n
# 115  {'ABP   80 < 85': 234, 'RUN VPBs 3 - 9': 199, ...   488n
#
# [116 rows x 10 columns]

# %%
def add_feat_names(fields_df):
    feat_names = []
    for i in range(len(fields_df)):
        row = fields_df.iloc[i]
        units_list, sig_list = eval(row["units"]), eval(row["sig_name"])
        cur_feat_names = {sig_list[j] + " (" + units_list[j] + ")" for j in range(len(units_list))}
        feat_names.append(cur_feat_names)
    return feat_names

fields_df["feat_cols"] = add_feat_names(fields_df)
fields_df
# Out:
#            fs  sig_len  n_sig   base_date base_time  \
# 0    0.976562    51138      7  1994-12-13  08:38:53
# 1    0.976562    77038      7  1995-02-22  13:08:55
# 2    0.976562   141796      7  1995-02-24  09:44:42
# 3    0.976562   131250     12  1995-03-02  15:36:24
# 4    0.976562     4606      5  1995-01-24  08:22:11
# ..        ...      ...    ...         ...       ...
# 111  0.976562   151176     14  1996-04-06  15:26:26
# 112  0.976562   147656     15  1996-04-22  17:35:49
# 113  0.976562   154687     12  1996-04-29  14:48:52
# 114  0.976562   193946     18  1996-05-02  11:54:49
# 115  0.976562   178121      4  1996-06-23  15:01:25
#
#                                                  units  \
# 0    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 1    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 2    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 3    ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 4                 ['mmHg', 'mmHg', 'mmHg', 'bpm', '%']
# ..                                                 ...
# 111  ['mmHg', 'mmHg', 'mmHg', 'lpm', 'mmHg', 'bpm',...
# 112  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'lpm', 'mmHg',...
# 113  ['mmHg', 'mmHg', 'mmHg', 'lpm', 'mmHg', 'bpm',...
# 114  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'lpm', 'mmHg',...
# 115                        ['lpm', 'bpm', '%', 'degC']
#
#                                               sig_name comments  \
# 0    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 1    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 2    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 3    ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 4     ['NBPmean', 'NBPsys', 'NBPdias', 'RESP', 'SpO2']       []
# ..                                                 ...      ...
# 111  ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'CVP'...       []
# 112  ['ABPmean', 'ABPsys', 'ABPdias', 'AWRR', 'C.O....       []
# 113  ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'CVP'...       []
# 114  ['ABPmean', 'ABPsys', 'ABPdias', 'AWRR', 'C.O....       []
# 115                 ['C.O.', 'RESP', 'SpO2', 'Tblood']       []
#
#                                          unique_alarms record  \
# 0    {'*ASYSTOLE': 23, '*TACHY 216 > 180': 9, '*VEN...   048n
# 1    {'ABP  184 > 180': 115, 'ABP  182 > 180': 115,...   052n
# 2    {'PAIR VPBs': 982, 'HR  53 <  55': 560, 'MULTI...   054n
# 3    {'VPBs > 5/MIN': 1661, 'PAIR VPBs': 1584, 'MUL...   055n
# 4                             {'MULTIFORM VPBs': 4600}   208n
# ..                                                 ...    ...
# 111  {'VPBs > 5/MIN': 20341, 'VPBs > 11/MIN': 1085,...   482n
# 112  {'IRREGULAR HR': 19031, 'MULTIFORM VPBs': 1982...   484n
# 113  {'PAIR VPBs': 731, 'VPBs > 11/MIN': 567, 'IRRE...   485n
# 114  {'PAIR VPBs': 4158, 'RUN VPBs 3 - 9': 1688, 'M...   486n
# 115  {'ABP   80 < 85': 234, 'RUN VPBs 3 - 9': 199, ...   488n
#
#                                              feat_cols
# 0    {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...
# 1    {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...
# 2    {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...
# 3    {C.O. (lpm), PULSE (bpm), ABPdias (mmHg), Tblo...
# 4    {SpO2 (%), NBPsys (mmHg), NBPmean (mmHg), NBPd...
# ..                                                 ...
# 111  {C.O. (lpm), ST1 (mV), PAWP (mmHg), ABPdias (m...
# 112  {AWRR (bpm), C.O. (lpm), ETCO2 (mmHg), IMCO2 (...
# 113  {C.O. (lpm), PAWP (mmHg), ABPdias (mmHg), Tblo...
# 114  {AWRR (bpm), C.O. (lpm), ST1 (mV), PAWP (mmHg)...
# 115  {SpO2 (%), C.O. (lpm), RESP (bpm), Tblood (degC)}
#
# [116 rows x 11 columns]

# %% [markdown]
# ## Select Feature Set

# %%
# Check what are the most common subset of features
def most_comment_subset_of_features(fields_df):
    feat_set_series = fields_df["feat_cols"]
    feat_set_counts = feat_set_series.value_counts().reset_index()
    feat_set_counts.columns = ["feat_set", "count"]
    feat_set_counts["num_features"] = [len(feat_set) for feat_set in feat_set_counts["feat_set"]]
    feat_set_counts = feat_set_counts.sort_values("num_features", ascending=True)
    num_unique_feat_sets = len(feat_set_counts)
    
    feat_set_inc_list = []
    for i in range(num_unique_feat_sets):
        total_count = 0
        potential_subset = feat_set_counts["feat_set"].iloc[i]
        for j in range(i,num_unique_feat_sets):
            potential_superset, count = feat_set_counts[["feat_set","count"]].iloc[j].values
            if potential_subset.issubset(potential_superset):
                total_count += count
        feat_set_inc_list.append({"feat_set": potential_subset, "inc_count": total_count})
    
    feat_set_inc_df = pd.DataFrame(feat_set_inc_list)
    
    return feat_set_counts, feat_set_inc_df.sort_values("inc_count", ascending=False)
feat_set_stats = most_comment_subset_of_features(fields_df)
display(feat_set_stats[0])
display(feat_set_stats[1])
# Out:
#                                              feat_set  count  num_features
# 39                                       {RESP (bpm)}      1             1
# 1                              {SpO2 (%), RESP (bpm)}     12             2
# 35              {C.O. (lpm), SpO2 (%), Tblood (degC)}      1             3
# 4   {SpO2 (%), C.O. (lpm), RESP (bpm), Tblood (degC)}      6             4
# 32  {AWRR (bpm), ETCO2 (mmHg), IMCO2 (mmHg), RESP ...      1             5
# 5   {SpO2 (%), NBPsys (mmHg), NBPmean (mmHg), NBPd...      4             5
# 10  {C.O. (lpm), Tblood (degC), RESP (bpm), PAWP (...      2             5
# 16  {ABPdias (mmHg), ABPsys (mmHg), HR (bpm), SpO2...      2             6
# 40  {PULSE (bpm), NBPsys (mmHg), RESP (bpm), NBPme...      1             6
# 14  {PULSE (bpm), SpO2 (%), NBPsys (mmHg), RESP (b...      2             7
# 37  {C.O. (lpm), SpO2 (%), Tblood (degC), NBPsys (...      1             7
# 0   {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...     15             7
# 20  {C.O. (lpm), Tblood (degC), UAPdias (mmHg), UA...      1             7
# 15  {PULSE (bpm), SpO2 (%), ABPdias (mmHg), NBPsys...      2             9
# 19  {ST1 (mV), PULSE (bpm), ABPdias (mmHg), ST2 (m...      1             9
# 44  {PULSE (bpm), ARTdias (mmHg), PAPdias (mmHg), ...      1             9
# 45  {PULSE (bpm), ABPdias (mmHg), PAPdias (mmHg), ...      1             9
# 29  {PAPmean (mmHg), PULSE (bpm), SpO2 (%), NBPsys...      1            10
# 46  {PAWP (mmHg), ABPdias (mmHg), PAPdias (mmHg), ...      1            10
# 6   {PULSE (bpm), SpO2 (%), ABPdias (mmHg), NBPsys...      4            10
# 3   {PULSE (bpm), ABPdias (mmHg), PAPdias (mmHg), ...      7            10
# 48  {ST1 (mV), CVP (mmHg), ST3 (mV), ABPdias (mmHg...      1            11
# 41  {PULSE (bpm), SpO2 (%), ABPdias (mmHg), NBPsys...      1            11
# 31  {PAPmean (mmHg), PULSE (bpm), SpO2 (%), ABPdia...      1            12
# 52  {C.O. (lpm), PAWP (mmHg), ABPdias (mmHg), Tblo...      1            12
# 12  {C.O. (lpm), PULSE (bpm), ABPdias (mmHg), Tblo...      2            12
# 38  {PAPmean (mmHg), PULSE (bpm), ARTdias (mmHg), ...      1            13
# 2   {PAPmean (mmHg), PULSE (bpm), SpO2 (%), ABPdia...      9            13
# 23  {C.O. (lpm), PULSE (bpm), PAWP (mmHg), ABPdias...      1            13
# 33  {C.O. (lpm), PULSE (bpm), PAWP (mmHg), ABPdias...      1            13
# 13  {PAPmean (mmHg), SpO2 (%), PAWP (mmHg), ABPdia...      2            13
# 50  {ART1mean (mmHg), PULSE (bpm), ARTdias (mmHg),...      1            14
# 9   {PAPmean (mmHg), PULSE (bpm), SpO2 (%), PAWP (...      2            14
# 42  {ST1 (mV), PAPmean (mmHg), SpO2 (%), ABPdias (...      1            14
# 22  {C.O. (lpm), ST1 (mV), PAWP (mmHg), ABPdias (m...      1            14
# 26  {C.O. (lpm), ST1 (mV), PAWP (mmHg), ST3 (mV), ...      1            15
# 21  {AWRR (bpm), C.O. (lpm), ETCO2 (mmHg), IMCO2 (...      1            15
# 36  {P4sys (mmHg), P4dias (mmHg), P4mean (mmHg), P...      1            16
# 51  {ST1 (mV), PAPmean (mmHg), PULSE (bpm), SpO2 (...      1            16
# 27  {C.O. (lpm), ARTdias (mmHg), PAWP (mmHg), PAPs...      1            16
# 8   {C.O. (lpm), ST1 (mV), PULSE (bpm), PAWP (mmHg...      3            16
# 28  {C.O. (lpm), ST1 (mV), PAWP (mmHg), ST3 (mV), ...      1            16
# 17  {PAPmean (mmHg), PULSE (bpm), ARTdias (mmHg), ...      2            16
# 11  {C.O. (lpm), ST1 (mV), PAWP (mmHg), PAPsys (mm...      2            16
# 43  {C.O. (lpm), ST1 (mV), PAPmean (mmHg), SpO2 (%...      1            17
# 18  {C.O. (lpm), ST1 (mV), PULSE (bpm), PAPsys (mm...      1            17
# 7   {AWRR (bpm), C.O. (lpm), ST1 (mV), PAWP (mmHg)...      3            18
# 25  {AWRR (bpm), C.O. (lpm), ST1 (mV), ETCO2 (mmHg...      1            18
# 30  {Tblood (degC), ABPmean (mmHg), ABPsys (mmHg),...      1            19
# 34  {Tblood (degC), LAP (mmHg), ABPmean (mmHg), AB...      1            19
# 47  {Tblood (degC), NBPsys (mmHg), ABPmean (mmHg),...      1            19
# 24  {Tblood (degC), RESP (bpm), ABPmean (mmHg), AB...      1            20
# 49  {Tblood (degC), LAP (mmHg), ABPmean (mmHg), AB...      1            22
#                                              feat_set  inc_count
# 0                                        {RESP (bpm)}         90
# 1                              {SpO2 (%), RESP (bpm)}         88
# 7   {ABPdias (mmHg), ABPsys (mmHg), HR (bpm), SpO2...         57
# 11  {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...         48
# 2               {C.O. (lpm), SpO2 (%), Tblood (degC)}         37
# 16  {PULSE (bpm), ABPdias (mmHg), PAPdias (mmHg), ...         35
# 5   {SpO2 (%), NBPsys (mmHg), NBPmean (mmHg), NBPd...         32
# 20  {PULSE (bpm), ABPdias (mmHg), PAPdias (mmHg), ...         27
# 8   {PULSE (bpm), NBPsys (mmHg), RESP (bpm), NBPme...         24
# 9   {PULSE (bpm), SpO2 (%), NBPsys (mmHg), RESP (b...         23
# 13  {PULSE (bpm), SpO2 (%), ABPdias (mmHg), NBPsys...         23
# 19  {PULSE (bpm), SpO2 (%), ABPdias (mmHg), NBPsys...         19
# 24  {C.O. (lpm), PAWP (mmHg), ABPdias (mmHg), Tblo...         19
# 3   {SpO2 (%), C.O. (lpm), RESP (bpm), Tblood (degC)}         18
# 17  {PAPmean (mmHg), PULSE (bpm), SpO2 (%), NBPsys...         16
# 34  {C.O. (lpm), ST1 (mV), PAWP (mmHg), ABPdias (m...         16
# 23  {PAPmean (mmHg), PULSE (bpm), SpO2 (%), ABPdia...         16
# 35  {C.O. (lpm), ST1 (mV), PAWP (mmHg), ST3 (mV), ...         15
# 27  {PAPmean (mmHg), PULSE (bpm), SpO2 (%), ABPdia...         14
# 18  {PAWP (mmHg), ABPdias (mmHg), PAPdias (mmHg), ...         10
# 46  {AWRR (bpm), C.O. (lpm), ST1 (mV), PAWP (mmHg)...          7
# 28  {C.O. (lpm), PULSE (bpm), PAWP (mmHg), ABPdias...          7
# 30  {PAPmean (mmHg), SpO2 (%), PAWP (mmHg), ABPdia...          6
# 6   {C.O. (lpm), Tblood (degC), RESP (bpm), PAWP (...          6
# 40  {C.O. (lpm), ST1 (mV), PULSE (bpm), PAWP (mmHg...          6
# 25  {C.O. (lpm), PULSE (bpm), ABPdias (mmHg), Tblo...          5
# 15  {PULSE (bpm), ARTdias (mmHg), PAPdias (mmHg), ...          5
# 14  {ST1 (mV), PULSE (bpm), ABPdias (mmHg), ST2 (m...          4
# 43  {C.O. (lpm), ST1 (mV), PAWP (mmHg), PAPsys (mm...          4
# 36  {AWRR (bpm), C.O. (lpm), ETCO2 (mmHg), IMCO2 (...          3
# 32  {PAPmean (mmHg), PULSE (bpm), SpO2 (%), PAWP (...          3
# 33  {ST1 (mV), PAPmean (mmHg), SpO2 (%), ABPdias (...          3
# 26  {PAPmean (mmHg), PULSE (bpm), ARTdias (mmHg), ...          3
# 4   {AWRR (bpm), ETCO2 (mmHg), IMCO2 (mmHg), RESP ...          3
# 10  {C.O. (lpm), SpO2 (%), Tblood (degC), NBPsys (...          2
# 49  {Tblood (degC), LAP (mmHg), ABPmean (mmHg), AB...          2
# 48  {Tblood (degC), ABPmean (mmHg), ABPsys (mmHg),...          2
# 39  {C.O. (lpm), ARTdias (mmHg), PAWP (mmHg), PAPs...          2
# 47  {AWRR (bpm), C.O. (lpm), ST1 (mV), ETCO2 (mmHg...          2
# 41  {C.O. (lpm), ST1 (mV), PAWP (mmHg), ST3 (mV), ...          2
# 42  {PAPmean (mmHg), PULSE (bpm), ARTdias (mmHg), ...          2
# 29  {C.O. (lpm), PULSE (bpm), PAWP (mmHg), ABPdias...          2
# 45  {C.O. (lpm), ST1 (mV), PULSE (bpm), PAPsys (mm...          1
# 51  {Tblood (degC), RESP (bpm), ABPmean (mmHg), AB...          1
# 50  {Tblood (degC), NBPsys (mmHg), ABPmean (mmHg),...          1
# 31  {ART1mean (mmHg), PULSE (bpm), ARTdias (mmHg),...          1
# 44  {C.O. (lpm), ST1 (mV), PAPmean (mmHg), SpO2 (%...          1
# 12  {C.O. (lpm), Tblood (degC), UAPdias (mmHg), UA...          1
# 38  {ST1 (mV), PAPmean (mmHg), PULSE (bpm), SpO2 (...          1
# 37  {P4sys (mmHg), P4dias (mmHg), P4mean (mmHg), P...          1
# 21  {ST1 (mV), CVP (mmHg), ST3 (mV), ABPdias (mmHg...          1
# 22  {PULSE (bpm), SpO2 (%), ABPdias (mmHg), NBPsys...          1
# 52  {Tblood (degC), LAP (mmHg), ABPmean (mmHg), AB...          1

# %%
feat_set = feat_set_stats[1].iloc[2][0]
# Check above count
def check_feat_set_count(fields_df, cur_feat_set):
    feat_set_series = fields_df["feat_cols"]
    count = 0
    for fs in feat_set_series:
        if cur_feat_set.issubset(fs):
            count += 1
    return count
check_feat_set_count(fields_df, cur_feat_set=feat_set)
# Out:
# 57

# %%
# Shortlist patients with feat_set
def shortlist_patients_with_feat_set(fields_df, cur_feat_set):
    feat_set_series = fields_df["feat_cols"]
    records = []
    for i, fs in enumerate(feat_set_series):
        if cur_feat_set.issubset(fs):
            records.append(fields_df["record"].iloc[i])
    return records
shortlisted_records = shortlist_patients_with_feat_set(fields_df, cur_feat_set=feat_set)
print(len(shortlisted_records), "Records:", shortlisted_records)
# Out:
# 57 Records: ['048n', '052n', '054n', '055n', '211n', '212n', '213n', '214n', '216n', '220n', '221n', '226n', '230n', '231n', '232n', '235n', '237n', '240n', '241n', '242n', '243n', '245n', '248n', '252n', '253n', '254n', '259n', '260n', '264n', '267n', '268n', '269n', '271n', '291n', '293n', '401n', '403n', '408n', '409n', '413n', '414n', '415n', '417n', '418n', '427n', '442n', '449n', '455n', '457n', '464n', '465n', '466n', '467n', '471n', '472n', '474n', '476n']

['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 1    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 2    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 3    ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 7          ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', '%']
# 8    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 9    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 10   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 12   ['mmHg', 'mmHg', 'mmHg', 'mmHg', 'mmHg', 'mmHg...
# 15   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 16   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 20   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 21   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 22   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 23   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 25   ['mmHg', 'mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg'...
# 26   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 27   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 28   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 29   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 30   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 31   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 32   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 33   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 34   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 35   ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 37   ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 38   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 40   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 41   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 42   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 43   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 44   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 55         ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', '%']
# 56   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 57   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 58   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 61   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 62   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 65   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 66   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 67   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 68   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 69   ['mmHg', 'mmHg', 'mmHg', 'mmHg', 'mmHg', 'mmHg...
# 71   ['mmHg', 'mmHg', 'mmHg', 'mmHg', 'mmHg', 'mmHg...
# 82   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 87   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 93   ['mmHg', 'mmHg', 'mmHg', 'lpm', 'mmHg', 'bpm',...
# 95   ['mmHg', 'mmHg', 'mmHg', 'lpm', 'mmHg', 'bpm',...
# 98   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 99   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 100  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 101  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 103  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 104  ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 105  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'lpm', 'mmHg',...
# 106  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'lpm', 'mmHg',...
#
#                                               sig_name comments  \
# 0    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 1    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 2    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 3    ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 7    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'RESP',...       []
# 8    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 9    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 10   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 12   ['ABPmean', 'ABPsys', 'ABPdias', 'ARTmean', 'A...       []
# 15   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 16   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 20   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 21   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 22   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 23   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 25   ['ABPmean', 'ABPsys', 'ABPdias', 'CVP', 'HR', ...       []
# 26   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 27   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 28   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 29   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 30   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 31   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 32   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 33   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 34   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 35   ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 37   ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 38   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 40   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 41   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 42   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 43   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 44   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 55   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'RESP',...       []
# 56   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 57   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 58   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 61   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 62   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 65   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 66   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 67   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 68   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 69   ['ABPmean', 'ABPsys', 'ABPdias', 'ARTmean', 'A...       []
# 71   ['ABPmean', 'ABPsys', 'ABPdias', 'ARTmean', 'A...       []
# 82   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 87   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 93   ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'CVP'...       []
# 95   ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'CVP'...       []
# 98   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 99   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 100  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 101  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 103  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 104  ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 105  ['ABPmean', 'ABPsys', 'ABPdias', 'AWRR', 'C.O....       []
# 106  ['ABPmean', 'ABPsys', 'ABPdias', 'AWRR', 'C.O....       []
#
#                                          unique_alarms record  \
# 0    {'*ASYSTOLE': 23, '*TACHY 216 > 180': 9, '*VEN...   048n
# 1    {'ABP  184 > 180': 115, 'ABP  182 > 180': 115,...   052n
# 2    {'PAIR VPBs': 982, 'HR  53 <  55': 560, 'MULTI...   054n
# 3    {'VPBs > 5/MIN': 1661, 'PAIR VPBs': 1584, 'MUL...   055n
# 7    {'PAIR VPBs': 328, 'HR 126 > 120': 99, 'ABP  2...   211n
# 8    {'VPBs >  5/MIN': 11644, 'MISSED BEATS': 10580...   212n
# 9    {'VPBs >  5/MIN': 3536, 'ABP   87 < 90': 717, ...   213n
# 10   {'RUN VPBs > 2': 3855, 'PAIR VPBs': 2566, 'VEN...   214n
# 12   {'VENT TRIGEMINY': 483, 'VPBs >  5/MIN': 389, ...   216n
# 15                             {'MULTIFORM VPBs': 309}   220n
# 16   {'PAIR VPBs': 793, 'MULTIFORM VPBs': 565, 'ABP...   221n
# 20   {'HR 141 > 140': 1655, 'MISSED BEATS': 625, 'V...   226n
# 21   {'VPBs >  5/MIN': 2331, 'PAIR VPBs': 1673, 'IR...   230n
# 22   {'PAIR VPBs': 6251, 'MULTIFORM VPBs': 1619, 'M...   231n
# 23   {'PAIR VPBs': 21307, 'IRREGULAR HR': 10410, 'V...   232n
# 25   {'HR 121 > 120': 1959, 'HR 130 > 125': 1746, '...   235n
# 26   {'MULTIFORM VPBs': 9554, 'VPBs >  5/MIN': 8578...   237n
# 27   {'ABP   78 < 90': 286, 'MISSED BEATS': 268, 'A...   240n
# 28   {'MULTIFORM VPBs': 13232, 'PAIR VPBs': 11212, ...   241n
# 29   {'MULTIFORM VPBs': 26064, 'PAIR VPBs': 10354, ...   242n
# 30   {'HR 151 > 150': 803, 'HR 152 > 150': 549, 'HR...   243n
# 31   {'MISSED BEATS': 12082, 'RUN VPBs > 2': 285, '...   245n
# 32   {'MULTIFORM VPBs': 7413, 'PAIR VPBs': 2154, 'H...   248n
# 33   {'R-ON-T VPBs': 335, 'ABP   45 < 80': 31, 'ABP...   252n
# 34   {'R-ON-T VPBs': 370, 'MULTIFORM VPBs': 276, 'A...   253n
# 35   {'PAIR VPBs': 459, 'ABP   75 < 90': 321, '*VEN...   254n
# 37   {'PAIR VPBs': 2421, 'RUN VPBs > 2': 2139, 'R-O...   259n
# 38   {'PAIR VPBs': 574, 'R-ON-T VPBs': 293, 'RUN VP...   260n
# 40   {'VPBs >  8/MIN': 94262, 'MISSED BEATS': 10998...   264n
# 41   {'PAIR VPBs': 8237, 'MULTIFORM VPBs': 1093, 'V...   267n
# 42   {'HR 169 > 155': 287, 'PAP   46 > 40': 76, 'MI...   268n
# 43   {'PAIR VPBs': 25488, 'RUN VPBs > 2': 25332, 'V...   269n
# 44   {'VPBs >  5/MIN': 4308, 'PAIR VPBs': 3330, 'RU...   271n
# 55   {'ABP  320 > 150': 8, 'ABP   67 < 90': 3, 'ABP...   291n
# 56                              {'NBP  166 > 160': 46}   293n
# 57   {'ABP  222 > 195': 17, 'ABP  198 > 195': 15, '...   401n
# 58   {'ABP   79 < 80': 64, 'ABP   78 < 80': 28, '*A...   403n
# 61   {'IRREGULAR HR': 2290, 'MULTIFORM VPBs': 681, ...   408n
# 62   {'IRREGULAR HR': 28905, 'MULTIFORM VPBs': 9678...   409n
# 65   {'MULTIFORM VPBs': 9862, 'MISSED BEATS': 9671,...   413n
# 66   {'MULTIFORM VPBs': 18499, 'MISSED BEATS': 9796...   414n
# 67   {'MISSED BEATS': 281, 'ABP  171 > 160': 23, 'P...   415n
# 68   {'MULTIFORM VPBs': 288, 'MISSED BEATS': 106, '...   417n
# 69   {'R-ON-T VPBs': 1209, 'ABP   55 < 60': 17, 'PA...   418n
# 71   {'VPBs >  5/MIN': 2338, 'HR 111 > 110': 534, '...   427n
# 82   {'MULTIFORM VPBs': 25724, 'PAIR VPBs': 22615, ...   442n
# 87   {'ABP   84 < 85': 123, 'ABP   83 < 85': 98, 'A...   449n
# 93   {'PAIR VPBs': 3514, 'MULTIFORM VPBs': 2186, 'H...   455n
# 95   {'HR 170 > 120': 2410, 'HR 150 > 120': 908, 'H...   457n
# 98   {'VENT BIGEMINY': 1184, 'PAP  240 > 40': 510, ...   464n
# 99   {'PACER NOT CAPT': 4996, 'IRREGULAR HR': 4783,...   465n
# 100  {'IRREGULAR HR': 1627, 'PAP   53 > 50': 505, '...   466n
# 101  {'MULTIFORM VPBs': 15456, 'PAIR VPBs': 6949, '...   467n
# 103  {'IRREGULAR HR': 23790, 'VPBs >  5/MIN': 7678,...   471n
# 104  {'PAIR VPBs': 1887, 'VPBs > 11/MIN': 1818, 'MU...   472n
# 105  {'IRREGULAR HR': 2457, 'HR  64 <  65': 448, 'H...   474n
# 106  {'ST2   0.9>0.6': 776, 'ST3   0.8>0.6': 742, '...   476n
#
#                                              feat_cols
# 0    {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...
# 1    {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...
# 2    {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...
# 3    {C.O. (lpm), PULSE (bpm), ABPdias (mmHg), Tblo...
# 7    {ABPdias (mmHg), ABPsys (mmHg), HR (bpm), SpO2...
# 8    {PULSE (bpm), ABPdias (mmHg), PAPdias (mmHg), ...
# 9    {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...
# 10   {PULSE (bpm), SpO2 (%), ABPdias (mmHg), NBPsys...
# 12   {PAPmean (mmHg), PULSE (bpm), ARTdias (mmHg), ...
# 15   {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...
# 16   {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...
# 20   {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...
# 21   {PAPmean (mmHg), PULSE (bpm), SpO2 (%), ABPdia...
# 22   {PULSE (bpm), ABPdias (mmHg), PAPdias (mmHg), ...
# 23   {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...
# 25   {PULSE (bpm), SpO2 (%), ABPdias (mmHg), NBPsys...
# 26   {PAPmean (mmHg), PULSE (bpm), SpO2 (%), ABPdia...
# 27   {ST1 (mV), PAPmean (mmHg), SpO2 (%), ABPdias (...
# 28   {PAPmean (mmHg), PULSE (bpm), SpO2 (%), PAWP (...
# 29   {PAPmean (mmHg), PULSE (bpm), SpO2 (%), ABPdia...
# 30   {PULSE (bpm), ABPdias (mmHg), PAPdias (mmHg), ...
# 31   {PULSE (bpm), ABPdias (mmHg), PAPdias (mmHg), ...
# 32   {PULSE (bpm), ABPdias (mmHg), PAPdias (mmHg), ...
# 33   {PULSE (bpm), SpO2 (%), ABPdias (mmHg), NBPsys...
# 34   {PAPmean (mmHg), PULSE (bpm), SpO2 (%), PAWP (...
# 35   {C.O. (lpm), ST1 (mV), PAPmean (mmHg), SpO2 (%...
# 37   {C.O. (lpm), PULSE (bpm), ABPdias (mmHg), Tblo...
# 38   {PAPmean (mmHg), SpO2 (%), PAWP (mmHg), ABPdia...
# 40   {PAPmean (mmHg), PULSE (bpm), SpO2 (%), ABPdia...
# 41   {PAPmean (mmHg), PULSE (bpm), SpO2 (%), ABPdia...
# 42   {PAPmean (mmHg), PULSE (bpm), SpO2 (%), ABPdia...
# 43   {PAWP (mmHg), ABPdias (mmHg), PAPdias (mmHg), ...
# 44   {PAPmean (mmHg), SpO2 (%), PAWP (mmHg), ABPdia...
# 55   {ABPdias (mmHg), ABPsys (mmHg), HR (bpm), SpO2...
# 56   {PULSE (bpm), SpO2 (%), ABPdias (mmHg), NBPsys...
# 57   {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...
# 58   {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...
# 61   {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...
# 62   {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...
# 65   {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...
# 66   {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...
# 67   {PAPmean (mmHg), PULSE (bpm), SpO2 (%), ABPdia...
# 68   {ST1 (mV), PAPmean (mmHg), PULSE (bpm), SpO2 (...
# 69   {PAPmean (mmHg), PULSE (bpm), ARTdias (mmHg), ...
# 71   {P4sys (mmHg), P4dias (mmHg), P4mean (mmHg), P...
# 82   {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...
# 87   {ST1 (mV), PULSE (bpm), ABPdias (mmHg), ST2 (m...
# 93   {C.O. (lpm), ST1 (mV), PULSE (bpm), PAPsys (mm...
# 95   {C.O. (lpm), ST1 (mV), PAWP (mmHg), ST3 (mV), ...
# 98   {PULSE (bpm), ABPdias (mmHg), PAPdias (mmHg), ...
# 99   {PULSE (bpm), ABPdias (mmHg), PAPdias (mmHg), ...
# 100  {PULSE (bpm), SpO2 (%), ABPdias (mmHg), NBPsys...
# 101  {PAPmean (mmHg), PULSE (bpm), SpO2 (%), ABPdia...
# 103  {PAPmean (mmHg), PULSE (bpm), SpO2 (%), ABPdia...
# 104  {C.O. (lpm), PULSE (bpm), PAWP (mmHg), ABPdias...
# 105  {Tblood (degC), RESP (bpm), ABPmean (mmHg), AB...
# 106  {AWRR (bpm), C.O. (lpm), ST1 (mV), ETCO2 (mmHg...

# %%
fields_df_shortlisted.head()
# Out:
#          fs  sig_len  n_sig   base_date base_time  \
# 0  0.976562    51138      7  1994-12-13  08:38:53
# 1  0.976562    77038      7  1995-02-22  13:08:55
# 2  0.976562   141796      7  1995-02-24  09:44:42
# 3  0.976562   131250     12  1995-03-02  15:36:24
# 7  0.976562    75991      6  1995-01-26  14:34:07
#
#                                                units  \
# 0  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 1  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 2  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 3  ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 7        ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', '%']
#
#                                             sig_name comments  \
# 0  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 1  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 2  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 3  ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 7  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'RESP',...       []
#
#                                        unique_alarms record  \
# 0  {'*ASYSTOLE': 23, '*TACHY 216 > 180': 9, '*VEN...   048n
# 1  {'ABP  184 > 180': 115, 'ABP  182 > 180': 115,...   052n
# 2  {'PAIR VPBs': 982, 'HR  53 <  55': 560, 'MULTI...   054n
# 3  {'VPBs > 5/MIN': 1661, 'PAIR VPBs': 1584, 'MUL...   055n
# 7  {'PAIR VPBs': 328, 'HR 126 > 120': 99, 'ABP  2...   211n
#
#                                            feat_cols
# 0  {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...
# 1  {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...
# 2  {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...
# 3  {C.O. (lpm), PULSE (bpm), ABPdias (mmHg), Tblo...
# 7  {ABPdias (mmHg), ABPsys (mmHg), HR (bpm), SpO2...

# %% [markdown]
# ## Select Alarms to Predict

# %%
def most_common_alarms(fields_df_shortlisted):
    alarm_col = fields_df_shortlisted["unique_alarms"]
    alarm_count = {}
    num_shortlisted = len(fields_df_shortlisted)
    for i in range(num_shortlisted):
        unique_alarms_dict = eval(alarm_col.iloc[i])
        for alarm, count in unique_alarms_dict.items():
            alarm = alarm.strip()
            if alarm in alarm_count:
                alarm_count[alarm] += count
            else:
                alarm_count[alarm] = count
    alarm_series = pd.Series(alarm_count).sort_values(ascending=False).reset_index()
    alarm_series["index"] = alarm_series["index"]
    alarm_series.columns = ["alarms", "count"]
    return alarm_series

alarm_count = most_common_alarms(fields_df_shortlisted)
alarm_count.head(10)
# Out:
#            alarms   count
# 0       PAIR VPBs  165344
# 1  MULTIFORM VPBs  159343
# 2    IRREGULAR HR   96848
# 3   VPBs >  5/MIN   95106
# 4   VPBs >  8/MIN   94262
# 5    MISSED BEATS   61802
# 6    RUN VPBs > 2   47527
# 7     VENT RHYTHM   10349
# 8     *VENT TACHY   10286
# 9     R-ON-T VPBs    7655

# %%
# Show word cloud of alarms
def generate_alarm_wordcloud(alarm_count):
    text = " ".join(alarm for alarm, count in alarm_count[["alarms", "count"]].values for j in range(count))
    stopwords = set(STOPWORDS)
    wordcloud = WordCloud(
        width=1000, height=500, stopwords=stopwords, background_color="white", collocations=False, max_words=20).generate(text)
    plt.figure(figsize=(6,3))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()
generate_alarm_wordcloud(alarm_count)

# %%
# find out how many alarms with "VPB" in it
def query_alarm_count(alarm_count, keyword):
    alarm_list = []
    total_count = 0
    for alarm, count in alarm_count[["alarms", "count"]].values:
        if keyword in alarm:
            alarm_list.append(alarm)
            total_count += count 
    return alarm_count[alarm_count["alarms"].isin(alarm_list)], total_count
vpb_alarm_stats = query_alarm_count(alarm_count, keyword="VPB")
print(vpb_alarm_stats[1], "VPBs:")
display(vpb_alarm_stats[0])
# Out:
# 584358 VPBs:
#               alarms   count
# 0          PAIR VPBs  165344
# 1     MULTIFORM VPBs  159343
# 3      VPBs >  5/MIN   95106
# 4      VPBs >  8/MIN   94262
# 6       RUN VPBs > 2   47527
# 9        R-ON-T VPBs    7655
# 10      VPBs > 5/MIN    6642
# 14    RUN VPBs 3 - 9    4397
# 22     VPBs > 11/MIN    2172
# 24      RUN VPBs > 5    1900
# 749     RUN VPBs > 9       9
# 1357   VPBs > 23/MIN       1

# %%
# How many patients have vpb
def query_records_with_alarm_keyword(fields_df_shortlisted, keyword_list):
    df_list = []
    for keyword in keyword_list:
        count = 0
        record_list = []
        for record, alarm_str in fields_df_shortlisted[["record","unique_alarms"]].values:
            if keyword in alarm_str:
                count += 1
                record_list.append(record)
        df_list.append({"keyword": keyword, "count":count, "records": record_list})
    return pd.DataFrame(df_list)
vbp_record_stats = query_records_with_alarm_keyword(fields_df_shortlisted, keyword_list=["VPB"]+vpb_alarm_stats[0]["alarms"].tolist())
vbp_record_stats
# Out:
#            keyword  count                                            records
# 0              VPB     49  [048n, 054n, 055n, 211n, 212n, 213n, 214n, 216...
# 1        PAIR VPBs     39  [048n, 054n, 055n, 211n, 213n, 214n, 216n, 221...
# 2   MULTIFORM VPBs     33  [054n, 055n, 213n, 214n, 220n, 221n, 226n, 230...
# 3    VPBs >  5/MIN     26  [211n, 212n, 213n, 214n, 216n, 230n, 231n, 232...
# 4    VPBs >  8/MIN      1                                             [264n]
# 5     RUN VPBs > 2     22  [212n, 213n, 214n, 230n, 232n, 235n, 237n, 240...
# 6      R-ON-T VPBs     13  [214n, 232n, 245n, 252n, 253n, 259n, 260n, 418...
# 7     VPBs > 5/MIN      7         [055n, 226n, 408n, 409n, 442n, 457n, 472n]
# 8   RUN VPBs 3 - 9      9  [048n, 055n, 226n, 408n, 442n, 455n, 457n, 472...
# 9    VPBs > 11/MIN      3                                 [409n, 457n, 472n]
# 10    RUN VPBs > 5      1                                             [264n]
# 11    RUN VPBs > 9      2                                       [455n, 457n]
# 12   VPBs > 23/MIN      1                                             [457n]

# %%
# Shortlist patients with alarm
def shortlist_patients_with_alarm(vbp_record_stats, keyword):
    record_list = vbp_record_stats[vbp_record_stats["keyword"]==keyword]["records"][0]
    return record_list
shortlisted_records_alarm = shortlist_patients_with_alarm(vbp_record_stats, keyword="VPB")
fields_df_shortlisted_alarm = fields_df_shortlisted[fields_df_shortlisted["record"].isin(shortlisted_records_alarm)]
display(fields_df_shortlisted_alarm.head())
print(fields_df_shortlisted_alarm.shape)
# Out:
#          fs  sig_len  n_sig   base_date base_time  \
# 0  0.976562    51138      7  1994-12-13  08:38:53
# 2  0.976562   141796      7  1995-02-24  09:44:42
# 3  0.976562   131250     12  1995-03-02  15:36:24
# 7  0.976562    75991      6  1995-01-26  14:34:07
# 8  0.976562   145275     10  1995-04-04  14:00:03
#
#                                                units  \
# 0  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 2  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 3  ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 7        ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', '%']
# 8  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
#
#                                             sig_name comments  \
# 0  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 2  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 3  ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 7  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'RESP',...       []
# 8  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
#
#                                        unique_alarms record  \
# 0  {'*ASYSTOLE': 23, '*TACHY 216 > 180': 9, '*VEN...   048n
# 2  {'PAIR VPBs': 982, 'HR  53 <  55': 560, 'MULTI...   054n
# 3  {'VPBs > 5/MIN': 1661, 'PAIR VPBs': 1584, 'MUL...   055n
# 7  {'PAIR VPBs': 328, 'HR 126 > 120': 99, 'ABP  2...   211n
# 8  {'VPBs >  5/MIN': 11644, 'MISSED BEATS': 10580...   212n
#
#                                            feat_cols
# 0  {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...
# 2  {PULSE (bpm), ABPdias (mmHg), RESP (bpm), ABPs...
# 3  {C.O. (lpm), PULSE (bpm), ABPdias (mmHg), Tblo...
# 7  {ABPdias (mmHg), ABPsys (mmHg), HR (bpm), SpO2...
# 8  {PULSE (bpm), ABPdias (mmHg), PAPdias (mmHg), ...
# (49, 11)

# %%
# 6.22 million rows in total (with nan values)
fields_df_shortlisted_alarm["sig_len"].sum()
# Out:
# 6227307

# %% [markdown]
# ## Split Records into Train, Valid, Test Records

# %%
# split records by train, valid, test
def recordwise_train_valid_test_split(df, valid_prop, test_prop, seed):
    records = df["record"].unique()
    num_records = len(records)
    record_indices = np.arange(num_records)
    np.random.seed(seed=seed)
    np.random.shuffle(record_indices)
    shuffled_records = records[record_indices]
    num_valid, num_test = round(valid_prop * num_records), round(test_prop * num_records)
    num_train = num_records - num_valid - num_test
    train_records, valid_records, test_records = (
        shuffled_records[:num_train], shuffled_records[num_train: num_train+num_valid],
        shuffled_records[num_train+num_valid:num_train+num_valid+num_test],
    )
    return train_records, valid_records, test_records

train_records, valid_records, test_records = recordwise_train_valid_test_split(
    fields_df_shortlisted, valid_prop=0.1, test_prop=0.2, seed=2023)

# %%
print(len(train_records), "Train Records:", train_records)
print(len(valid_records), "Valid Records:", valid_records)
print(len(test_records), "Test Records:", test_records)
# Out:
# 40 Train Records: ['474n' '269n' '241n' '232n' '230n' '242n' '221n' '048n' '220n' '415n'
#  '418n' '403n' '226n' '259n' '268n' '401n' '464n' '260n' '476n' '237n'
#  '471n' '427n' '054n' '243n' '442n' '414n' '245n' '455n' '409n' '052n'
#  '211n' '293n' '216n' '417n' '235n' '472n' '267n' '457n' '214n' '449n']
# 6 Valid Records: ['467n' '466n' '253n' '212n' '413n' '231n']
# 11 Test Records: ['240n' '465n' '271n' '408n' '248n' '055n' '264n' '291n' '213n' '254n'
#  '252n']

# %% [markdown]
# ## Downsample Time Series Data

# %%
feat_set
# Out:
# {'ABPdias (mmHg)',
#  'ABPmean (mmHg)',
#  'ABPsys (mmHg)',
#  'HR (bpm)',
#  'RESP (bpm)',
#  'SpO2 (%)'}

# %%
i, j = np.ogrid[:6, :4]
x = 10*i + j
x.shape
# Out:
# (6, 4)

# %%
x
# Out:
# array([[ 0,  1,  2,  3],
#        [10, 11, 12, 13],
#        [20, 21, 22, 23],
#        [30, 31, 32, 33],
#        [40, 41, 42, 43],
#        [50, 51, 52, 53]])

# %%
window = 2
v = x.reshape(x.shape[0]//window, window, x.shape[1])
v
# Out:
# array([[[ 0,  1,  2,  3],
#         [10, 11, 12, 13]],
#
#        [[20, 21, 22, 23],
#         [30, 31, 32, 33]],
#
#        [[40, 41, 42, 43],
#         [50, 51, 52, 53]]])

# %%
v = v.astype('float')
v[v == 31] = np.NAN
v
# Out:
# array([[[ 0.,  1.,  2.,  3.],
#         [10., 11., 12., 13.]],
#
#        [[20., 21., 22., 23.],
#         [30., nan, 32., 33.]],
#
#        [[40., 41., 42., 43.],
#         [50., 51., 52., 53.]]])

# %%
np.where(~np.isnan(v).any(axis=(1,2)))[0]
# Out:
# array([0, 2])

# %%
print(np.isnan(v).any(axis=(1,2)))
np.isnan(v).any(axis=(1,2)).shape
# Out:
# [False  True False]
# (3,)

# %%
v[~np.isnan(v).any(axis=(1,2)), :, :]
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 v[~np.isnan(v).any(axis=(1,2)), :, :]
#
# File ~/anaconda3/envs/icu/lib/python3.10/site-packages/numpy/core/_methods.py:58, in _any(a, axis, dtype, out, keepdims, where)
#      55 def _any(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#      56     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      57     if where is True:
# ---> 58         return umr_any(a, axis, dtype, out, keepdims)
#      59     return umr_any(a, axis, dtype, out, keepdims, where=where)
#
# AxisError: axis 2 is out of bounds for array of dimension 2

# %%
def downsample_all_csvs(fp_converted_folder, feat_set, fields_df_shortlisted, downsample_function, window=60):
    df_list = []
    records = fields_df_shortlisted["record"].tolist()
    for record in tqdm(records):
        fp_csv = os.path.join(fp_converted_folder, record+".csv")
        df = pd.read_csv(fp_csv, index_col=0)
        df = downsample_function(df, window, feat_set, record)
        df["record"] = record
        df_list.append(df)
    all_df = pd.concat(df_list).reset_index()
    all_df.columns = ["record_index"] + all_df.columns[1:].to_list()
    return all_df

def downsample_ts(df, window, feat_set, alarm_col="alarms"):
    df[alarm_col] = df[alarm_col].str.strip()
    feat_set = list(feat_set)
    all_feat = feat_set + [alarm_col]
    df_feat_sel = df[all_feat]
    grouped = df_feat_sel.groupby((df_feat_sel.index/window).astype('i'))
    df_downsampled = grouped[feat_set].mean()
    alarm_list = []
    for group, alarms in grouped[alarm_col]:
        list_of_alarms = [eval(al) for al in alarms[alarms.notna()]]
        alarm_set = set().union(*list_of_alarms)
        alarm_list.append(alarm_set)
    df_downsampled["alarms"] = alarm_list
    return df_downsampled

def downsample_ts_withstd(df, window, feat_set, alarm_col="alarms"):
    df[alarm_col] = df[alarm_col].str.strip()
    feat_set = list(feat_set)
    all_feat = feat_set + [alarm_col]
    df_feat_sel = df[all_feat]
    grouped = df_feat_sel.groupby((df_feat_sel.index/window).astype('i'))
    
    # Downsample variables
    df_downsampled = grouped[feat_set].mean()
    df_downsampled.columns = [col + "_mean" for col in feat_set]
    std_cols = [col + "_std" for col in feat_set]
    df_downsampled[std_cols] = grouped[feat_set].std()
    
    # Aggregate alarms
    alarm_list = []
    for group, alarms in grouped[alarm_col]:
        list_of_alarms = [eval(al) for al in alarms[alarms.notna()]]
        alarm_set = set().union(*list_of_alarms)
        alarm_list.append(alarm_set)
    df_downsampled["alarms"] = alarm_list
    return df_downsampled

def set_seed(seed):
    import tensorflow as tf
    import random
    tf.config.experimental.enable_op_determinism()
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    tf.keras.utils.set_random_seed(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)

def display_history(history, show_acc=False):
    if show_acc:
        fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(6, 2.5))
        axes[0].plot(history.history['loss'])
        axes[0].plot(history.history['val_loss'])
        axes[0].set_title('Model Loss')
        axes[0].set_ylabel('Loss')
        axes[0].set_xlabel('Epoch')
        axes[0].legend(['Train', 'Val'], loc='upper left')
        axes[1].plot(history.history['accuracy'])
        axes[1].plot(history.history['val_accuracy'])
        axes[1].set_title('Model Accuracy')
        axes[1].set_ylabel('Accuracy')
        axes[1].set_xlabel('Epoch')
        axes[1].legend(['Train', 'Val'], loc='upper left')
        axes[2].plot(history.history['f1_score'])
        axes[2].plot(history.history['val_f1_score'])
        axes[2].set_title('Model F1 Score')
        axes[2].set_ylabel('F1 Score')
        axes[2].set_xlabel('Epoch')
        axes[2].legend(['Train', 'Val'], loc='upper left')
    else:
        fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(3, 2.5))
        axes.plot(history.history['loss'])
        axes.plot(history.history['val_loss'])
        axes.set_title('Model Loss')
        axes.set_ylabel('Loss')
        axes.set_xlabel('Epoch')
        axes.legend(['Train', 'Val'], loc='upper left')
    plt.tight_layout()
    plt.show()
    
def downsample_all_autoencoder(fp_converted_folder, feat_set, fields_df_shortlisted, alarm_col, window=60):
#     def rolling_df(df, feat_set, window):
#         mat = df[feat_set].values
#         num_feat = len(feat_set)
#         shape = (window, num_feat)
#         mat_rolled = np.lib.stride_tricks.sliding_window_view(mat, shape)
#         mat_rolled = np.squeeze(mat_rolled, axis=1)
#         return mat_rolled
    
    feat_set = list(feat_set)
    mat_list = []
    records = fields_df_shortlisted["record"].tolist()
    record_all = []
    alarm_all = []
    record_indices_all = []
    for record in tqdm(records):
        fp_csv = os.path.join(fp_converted_folder, record+".csv")
        df = pd.read_csv(fp_csv, index_col=0)
        df = df.reset_index()
        mat = df[feat_set].values
        new_length  = mat.shape[0]//window
        max_mat_size = new_length*window
        mat = mat[:max_mat_size,:]
        cur_mat = mat.reshape(new_length, window, mat.shape[1])
        notnan_mask = ~np.isnan(cur_mat).any(axis=(1,2))
        retained_indices = np.where(notnan_mask)[0]
        record_indices_all.extend(list(retained_indices))
        # remove nan
        cur_mat = cur_mat[notnan_mask, :, :]
        
        short_df = df.iloc[:max_mat_size,:]
        grouped = short_df.groupby(
            (short_df.index//window).astype('i'))
        # Aggregate alarms
        alarm_list = []
        for group, alarms in grouped[alarm_col]:
            if notnan_mask[group]:
                list_of_alarms = [eval(al) for al in alarms[alarms.notna()]]
                alarm_set = set().union(*list_of_alarms)
                alarm_list.append(alarm_set)
        
#         df = downsample_function(df, window, feat_set, record)
        record_all.extend([record for i in range(len(cur_mat))])
        mat_list.append(cur_mat)
        alarm_all.extend(alarm_list)
    sequence_all = np.vstack(mat_list)
    
    print("Flattening train, valid and all")
    print(sequence_all.shape, len(record_all), len(alarm_all))
    sequence_train = sequence_all[pd.Series(record_all).isin(train_records)]
    sequence_valid = sequence_all[pd.Series(record_all).isin(valid_records)]
    
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import LSTM, Dense, RepeatVector, TimeDistributed
    from tensorflow.keras.callbacks import EarlyStopping
    from  tensorflow.keras.optimizers import Adam
    set_seed(2023)
    num_feats = len(feat_set)
    width, output = num_feats*2, num_feats
    # define model
    model = Sequential()
    model.add(LSTM(width, activation='relu', input_shape=(window, num_feats)))
    model.add(RepeatVector(window))
    model.add(LSTM(width, activation='relu', return_sequences=True))
    model.add(TimeDistributed(Dense(output)))
    ADAM =Adam()#clipnorm=1.)
    model.compile(optimizer=ADAM, loss='mse')
    print(model.layers[0])
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20, restore_best_weights=True)
    history = model.fit(
        sequence_train, sequence_train, epochs=300,
        validation_data=(sequence_valid, sequence_valid),
        verbose=1,
        batch_size=512,
        callbacks=[es]
    )
    
    display_history(history, show_acc=False)
    
    from keras import backend as K
    get_encoder_layer_output = K.function([model.layers[0].input],
                                      [model.layers[0].output])
    pred_x = get_encoder_layer_output(sequence_all)[0]
    
    df = pd.DataFrame(pred_x, columns=[f"AE_Feature{i}" for i in range(num_feats*2)])
    df["Alarm"] = alarm_all
    df["Record Indices"] = record_indices_all 
    df["Record"] = record_all
    
    return df, model
              


# df_ds = downsample_all_csvs(
#     fp_converted_folder, feat_set, fields_df_shortlisted,  downsample_ts_withstd, window=60)
# df_ds

df_ds, model = downsample_all_autoencoder(fp_converted_folder, feat_set, fields_df_shortlisted, alarm_col="alarms", window=60)
df_ds
# Out:
#   0%|                                                                                      | 0/57 [00:00<?, ?it/s]/tmp/ipykernel_1744/1008234354.py:110: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)
#   4%|██▋                                                                           | 2/57 [00:00<00:05, 10.85it/s]/tmp/ipykernel_1744/1008234354.py:110: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)
#  21%|████████████████▏                                                            | 12/57 [00:02<00:07,  6.04it/s]/tmp/ipykernel_1744/1008234354.py:110: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)
#  23%|█████████████████▌                                                           | 13/57 [00:02<00:07,  6.11it/s]/tmp/ipykernel_1744/1008234354.py:110: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)
#  30%|██████████████████████▉                                                      | 17/57 [00:03<00:09,  4.05it/s]/tmp/ipykernel_1744/1008234354.py:110: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)
#  40%|███████████████████████████████                                              | 23/57 [00:05<00:09,  3.70it/s]/tmp/ipykernel_1744/1008234354.py:110: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)
#  60%|█████████████████████████████████████████████▉                               | 34/57 [00:08<00:06,  3.30it/s]/tmp/ipykernel_1744/1008234354.py:110: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)
#  72%|███████████████████████████████████████████████████████▍                     | 41/57 [00:10<00:04,  3.79it/s]/tmp/ipykernel_1744/1008234354.py:110: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)
#  77%|███████████████████████████████████████████████████████████▍                 | 44/57 [00:10<00:02,  5.19it/s]/tmp/ipykernel_1744/1008234354.py:110: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)
#  81%|██████████████████████████████████████████████████████████████▏              | 46/57 [00:11<00:02,  3.67it/s]/tmp/ipykernel_1744/1008234354.py:110: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)
#  82%|███████████████████████████████████████████████████████████████▍             | 47/57 [00:11<00:02,  3.63it/s]/tmp/ipykernel_1744/1008234354.py:110: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)
#  88%|███████████████████████████████████████████████████████████████████▌         | 50/57 [00:12<00:01,  4.05it/s]/tmp/ipykernel_1744/1008234354.py:110: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)
#  95%|████████████████████████████████████████████████████████████████████████▉    | 54/57 [00:14<00:01,  2.32it/s]/tmp/ipykernel_1744/1008234354.py:110: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)
# 100%|█████████████████████████████████████████████████████████████████████████████| 57/57 [00:14<00:00,  3.81it/s]
# Flattening train, valid and all
# (95055, 60, 6) 95055 95055
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# <keras.src.layers.rnn.lstm.LSTM object at 0x7f479bb800a0>
# Epoch 1/300
# 120/120 [==============================] - 9s 66ms/step - loss: 212913456.0000 - val_loss: 125884.6562
# Epoch 2/300
# 120/120 [==============================] - 7s 62ms/step - loss: 18192.8945 - val_loss: 41755.1758
# Epoch 3/300
# 120/120 [==============================] - 8s 64ms/step - loss: 15911.4326 - val_loss: 56653.0352
# Epoch 4/300
# 120/120 [==============================] - 8s 64ms/step - loss: 4072.2661 - val_loss: 118753.6172
# Epoch 5/300
# 3893  2.247495e-21  4.064362e-01  {ABP    0 < 85}             227   055n
# 3894  8.716792e-24  2.557843e-01               {}             228   055n
# 3895  4.910737e-23  6.433634e-01               {}             229   055n

# %%
model.save('../../models/lstm_autoencoder.keras')

# %%
df_ds = df_ds.rename(columns={"Alarm": "alarms", "Record": "record", "Record Indices":"record_index"})

# %%
df_ds["alarms"].value_counts()
# Out:
# alarms
# set()                                                                                79912
# {'PAIR VPBs'}                                                                         2261
# {'MULTIFORM VPBs'}                                                                    2096
# {'IRREGULAR HR'}                                                                      1549
# {'VPBs >  8/MIN'}                                                                     1494
#                                                                                      ...
# {'PAP    1 < 4', 'PAP    3 < 4', 'PAP   -7 < 4', 'PAP   -9 < 4', 'VENT RHYTHM'}          1
# {'PAP    2 < 4', 'PAP  -13 < 4', 'VENT RHYTHM'}                                          1
# {'PAP    1 < 4', 'PAP   -2 < 4', 'PAP   -9 < 4', 'VENT RHYTHM'}                          1
# {'PAP    1 < 4', 'PAP    0 < 4', 'PAP    2 < 4', 'VPBs >  8/MIN', 'PAP   -1 < 4'}        1
# {'PAP  119 > 40'}                                                                        1
# Name: count, Length: 1767, dtype: int64

# %%
def label_rows(df_ds, keyword):
    return [(keyword in str(al)) for al in df_ds["alarms"]]
df_ds["VPBs"] = label_rows(df_ds, keyword="VPBs")
df_ds
# Out:
#        AE_Feature0   AE_Feature1   AE_Feature2   AE_Feature3  AE_Feature4  \
# 0              0.0  0.000000e+00  3.932203e-19  1.852370e-21          0.0
# 1              0.0  0.000000e+00  2.546635e-17  0.000000e+00          0.0
# 2              0.0  0.000000e+00  2.954583e-17  0.000000e+00          0.0
# 3              0.0  0.000000e+00  1.024744e-21  0.000000e+00          0.0
# 4              0.0  3.425911e-19  4.061079e-23  5.538401e-19          0.0
# ...            ...           ...           ...           ...          ...
# 95050          0.0  0.000000e+00  3.866240e-16  0.000000e+00          0.0
# 95051          0.0  0.000000e+00  1.005664e-16  0.000000e+00          0.0
# 95052          0.0  0.000000e+00  4.722978e-16  0.000000e+00          0.0
# 95053          0.0  0.000000e+00  4.550144e-16  0.000000e+00          0.0
# 95054          0.0  0.000000e+00  7.470648e-17  0.000000e+00          0.0
#
#        AE_Feature5  AE_Feature6  AE_Feature7   AE_Feature8  AE_Feature9  \
# 0         3.103516          0.0          0.0  3.019377e-18          0.0
# 1         1.620998          0.0          0.0  7.543659e-17          0.0
# 2         1.583783          0.0          0.0  4.262290e-17          0.0
# 3         2.136829          0.0          0.0  7.354678e-20          0.0
# 4         4.054713          0.0          0.0  1.264281e-20          0.0
# ...            ...          ...          ...           ...          ...
# 95050     0.000000          0.0          0.0  2.628123e-15          0.0
# 95051     0.000000          0.0          0.0  7.963030e-15          0.0
# 95052     0.000000          0.0          0.0  1.747667e-15          0.0
# 95053     0.000000          0.0          0.0  1.783807e-15          0.0
# 95054     0.000000          0.0          0.0  7.813091e-16          0.0
#
#        AE_Feature10  AE_Feature11 alarms  Record Indices record   VPBs  \
# 0      1.183453e-30           0.0  set()               0   048n  False
# 1      1.406648e-28           0.0  set()               1   048n  False
# 2      9.880747e-29           0.0  set()               2   048n  False
# 3      5.150530e-34           0.0  set()               3   048n  False
# 4      5.815785e-36           0.0  set()               4   048n  False
# ...             ...           ...    ...             ...    ...    ...
# 95050  2.442838e-21           0.0  set()             934   476n  False
# 95051  1.669079e-21           0.0  set()             935   476n  False
# 95052  2.336945e-19           0.0  set()             936   476n  False
# 95053  5.933477e-19           0.0  set()             937   476n  False
# 95054  9.541162e-21           0.0  set()             938   476n  False
#
#        no_alarms
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
# ...          ...
# 95050       True
# 95051       True
# 95052       True
# 95053       True
# 95054       True
#
# [95055 rows x 17 columns]

# %%
df_ds["VPBs"].value_counts()
# Out:
# VPBs
# False    86017
# True      9038
# Name: count, dtype: int64

# %%
def label_true_negative(df_ds):
    return [len(eval(al)) == 0 for al in df_ds["alarms"]]
# label rows with no alarms at all
df_ds["no_alarms"] = label_true_negative(df_ds)
df_ds
# Out:
#        AE_Feature0  AE_Feature1  AE_Feature2  AE_Feature3  AE_Feature4  \
# 0        -0.011905    -0.027025    -0.065444    -0.124951    -0.238980
# 1        -0.011905    -0.027025    -0.065444    -0.124951    -0.238980
# 2        -0.011905    -0.027025    -0.065444    -0.124951    -0.238980
# 3        -0.011905    -0.027025    -0.065444    -0.124951    -0.238980
# 4        -0.011905    -0.027025    -0.065444    -0.124951    -0.238980
# ...            ...          ...          ...          ...          ...
# 81110    -0.011905    -0.027025     0.054268    -0.124951    -0.238980
# 81111    -0.011905    -0.027025     3.253283    -0.124951    -0.238979
# 81112    -0.011905    -0.027025    -0.065444    -0.124951    -0.238980
# 81113    -0.011905    -0.027025    -0.065444    -0.124951    -0.238980
# 81114   106.987645    -0.027025    -0.065444    -0.124951    -0.238979
#
#        AE_Feature5  AE_Feature6  AE_Feature7  AE_Feature8  AE_Feature9  \
# 0        -0.358224    -0.008513    -0.022633    -0.044798    -0.013958
# 1        -0.464522    -0.008513    -0.022633    -0.044798    -0.013958
# 2        -0.467191    -0.008513    -0.022633    -0.044798    -0.013958
# 3        -0.427537    -0.008513    -0.022633    -0.044798    -0.013958
# 4        -0.290022    -0.008513    -0.022633    -0.044798    -0.013958
# ...            ...          ...          ...          ...          ...
# 81110    -0.580750    -0.007995     2.334877     1.797270    -0.013958
# 81111    -0.580750    -0.008471    -0.022633     0.074857    -0.013956
# 81112    -0.580750    -0.008512    -0.022633    10.381570    -0.013958
# 81113    -0.580750    -0.008510    -0.022633    11.181146    -0.013936
# 81114    -0.580750    -0.008513     3.919265    -0.044769    -0.013958
#
#        AE_Feature10  AE_Feature11               alarms  Record Indices record  \
# 0         -0.013638     -0.400549                set()               0   048n
# 1         -0.013638     -0.400549                set()               1   048n
# 2         -0.013638     -0.400549                set()               2   048n
# 3         -0.013638     -0.400549                set()               3   048n
# 4         -0.013638     -0.400549                set()               4   048n
# ...             ...           ...                  ...             ...    ...
# 81110     -0.013638     -0.400549                set()            1413   465n
# 81111     -0.009995     -0.400549  {'*ABP DISCONNECT'}            1414   465n
# 81112     -0.013638     -0.400549                set()            1415   465n
# 81113     -0.013638     -0.400549                set()            1416   465n
# 81114     -0.013638      0.436304  {'*ABP DISCONNECT'}            1417   465n
#
#         VPBs  no_alarms
# 0      False       True
# 1      False       True
# 2      False       True
# 3      False       True
# 4      False       True
# ...      ...        ...
# 81110  False       True
# 81111  False      False
# 81112  False       True
# 81113  False       True
# 81114  False      False
#
# [95055 rows x 17 columns]

# %%
df_ds["no_alarms"].value_counts()
# Out:
# no_alarms
# True     79912
# False    15143
# Name: count, dtype: int64

# %%
if not os.path.exists(fp_downsampled_folder):
    os.makedirs(fp_downsampled_folder)
df_ds.to_csv(fp_downsampled_continuous_ae_file)

# %%
df_ds = pd.read_csv(fp_downsampled_continuous_ae_file, index_col=0)
df_ds
# Out:
#        AE_Feature0  AE_Feature1  AE_Feature2  AE_Feature3  AE_Feature4  \
# 0        -0.011905    -0.027025    -0.065444    -0.124951    -0.238980
# 1        -0.011905    -0.027025    -0.065444    -0.124951    -0.238980
# 2        -0.011905    -0.027025    -0.065444    -0.124951    -0.238980
# 3        -0.011905    -0.027025    -0.065444    -0.124951    -0.238980
# 4        -0.011905    -0.027025    -0.065444    -0.124951    -0.238980
# ...            ...          ...          ...          ...          ...
# 81110    -0.011905    -0.027025     0.054268    -0.124951    -0.238980
# 81111    -0.011905    -0.027025     3.253283    -0.124951    -0.238979
# 81112    -0.011905    -0.027025    -0.065444    -0.124951    -0.238980
# 81113    -0.011905    -0.027025    -0.065444    -0.124951    -0.238980
# 81114   106.987645    -0.027025    -0.065444    -0.124951    -0.238979
#
#        AE_Feature5  AE_Feature6  AE_Feature7  AE_Feature8  AE_Feature9  \
# 0        -0.358224    -0.008513    -0.022633    -0.044798    -0.013958
# 1        -0.464522    -0.008513    -0.022633    -0.044798    -0.013958
# 2        -0.467191    -0.008513    -0.022633    -0.044798    -0.013958
# 3        -0.427537    -0.008513    -0.022633    -0.044798    -0.013958
# 4        -0.290022    -0.008513    -0.022633    -0.044798    -0.013958
# ...            ...          ...          ...          ...          ...
# 81110    -0.580750    -0.007995     2.334877     1.797270    -0.013958
# 81111    -0.580750    -0.008471    -0.022633     0.074857    -0.013956
# 81112    -0.580750    -0.008512    -0.022633    10.381570    -0.013958
# 81113    -0.580750    -0.008510    -0.022633    11.181146    -0.013936
# 81114    -0.580750    -0.008513     3.919265    -0.044769    -0.013958
#
#        AE_Feature10  AE_Feature11               alarms  record_index record  \
# 0         -0.013638     -0.400549                set()             0   048n
# 1         -0.013638     -0.400549                set()             1   048n
# 2         -0.013638     -0.400549                set()             2   048n
# 3         -0.013638     -0.400549                set()             3   048n
# 4         -0.013638     -0.400549                set()             4   048n
# ...             ...           ...                  ...           ...    ...
# 81110     -0.013638     -0.400549                set()          1413   465n
# 81111     -0.009995     -0.400549  {'*ABP DISCONNECT'}          1414   465n
# 81112     -0.013638     -0.400549                set()          1415   465n
# 81113     -0.013638     -0.400549                set()          1416   465n
# 81114     -0.013638      0.436304  {'*ABP DISCONNECT'}          1417   465n
#
#         VPBs  no_alarms
# 0      False       True
# 1      False       True
# 2      False       True
# 3      False       True
# 4      False       True
# ...      ...        ...
# 81110  False       True
# 81111  False      False
# 81112  False       True
# 81113  False       True
# 81114  False      False
#
# [95055 rows x 17 columns]

# %%
feat_set = df_ds.columns.tolist()[0:-5]
feat_set.sort()
print("Features:", feat_set)
# Out:
# Features: ['AE_Feature0', 'AE_Feature1', 'AE_Feature10', 'AE_Feature11', 'AE_Feature2', 'AE_Feature3', 'AE_Feature4', 'AE_Feature5', 'AE_Feature6', 'AE_Feature7', 'AE_Feature8', 'AE_Feature9']

# %% [markdown]
# ## Standardise Data

# %%
def standardise_data(df, train_records, valid_records, test_records, predictors):
    from sklearn.preprocessing import StandardScaler
    df_train, df_valid, df_test = (
        df[df["record"].isin(train_records)], df[df["record"].isin(valid_records)],
        df[df["record"].isin(test_records)]
    )
    scaler = StandardScaler()
    scaler.fit(df_train[predictors])
    df_train[predictors] = scaler.transform(df_train[predictors])
    df_valid[predictors] = scaler.transform(df_valid[predictors])
    df_test[predictors] = scaler.transform(df_test[predictors])
    
    return pd.concat([df_train, df_valid, df_test])

df_ds = standardise_data(df_ds, train_records, valid_records, test_records, list(feat_set))
df_ds
# Out:
# /tmp/ipykernel_5248/579784048.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train[predictors] = scaler.transform(df_train[predictors])
# /tmp/ipykernel_5248/579784048.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_valid[predictors] = scaler.transform(df_valid[predictors])
# /tmp/ipykernel_5248/579784048.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test[predictors] = scaler.transform(df_test[predictors])
#        AE_Feature0  AE_Feature1  AE_Feature2  AE_Feature3  AE_Feature4  \
# 0        -0.011905    -0.027025    -0.065444    -0.124951    -0.238980
# 1        -0.011905    -0.027025    -0.065444    -0.124951    -0.238980
# 2        -0.011905    -0.027025    -0.065444    -0.124951    -0.238980
# 3        -0.011905    -0.027025    -0.065444    -0.124951    -0.238980
# 4        -0.011905    -0.027025    -0.065444    -0.124951    -0.238980
# ...            ...          ...          ...          ...          ...
# 81110    -0.011905    -0.027025     0.054268    -0.124951    -0.238980
# 81111    -0.011905    -0.027025     3.253283    -0.124951    -0.238979
# 81112    -0.011905    -0.027025    -0.065444    -0.124951    -0.238980
# 81113    -0.011905    -0.027025    -0.065444    -0.124951    -0.238980
# 81114   106.987645    -0.027025    -0.065444    -0.124951    -0.238979
#
#        AE_Feature5  AE_Feature6  AE_Feature7  AE_Feature8  AE_Feature9  \
# 0        -0.358224    -0.008513    -0.022633    -0.044798    -0.013958
# 1        -0.464522    -0.008513    -0.022633    -0.044798    -0.013958
# 2        -0.467191    -0.008513    -0.022633    -0.044798    -0.013958
# 3        -0.427537    -0.008513    -0.022633    -0.044798    -0.013958
# 4        -0.290022    -0.008513    -0.022633    -0.044798    -0.013958
# ...            ...          ...          ...          ...          ...
# 81110    -0.580750    -0.007995     2.334877     1.797270    -0.013958
# 81111    -0.580750    -0.008471    -0.022633     0.074857    -0.013956
# 81112    -0.580750    -0.008512    -0.022633    10.381570    -0.013958
# 81113    -0.580750    -0.008510    -0.022633    11.181146    -0.013936
# 81114    -0.580750    -0.008513     3.919265    -0.044769    -0.013958
#
#        AE_Feature10  AE_Feature11               alarms  Record Indices record  \
# 0         -0.013638     -0.400549                set()               0   048n
# 1         -0.013638     -0.400549                set()               1   048n
# 2         -0.013638     -0.400549                set()               2   048n
# 3         -0.013638     -0.400549                set()               3   048n
# 4         -0.013638     -0.400549                set()               4   048n
# ...             ...           ...                  ...             ...    ...
# 81110     -0.013638     -0.400549                set()            1413   465n
# 81111     -0.009995     -0.400549  {'*ABP DISCONNECT'}            1414   465n
# 81112     -0.013638     -0.400549                set()            1415   465n
# 81113     -0.013638     -0.400549                set()            1416   465n
# 81114     -0.013638      0.436304  {'*ABP DISCONNECT'}            1417   465n
#
#         VPBs  no_alarms
# 0      False       True
# 1      False       True
# 2      False       True
# 3      False       True
# 4      False       True
# ...      ...        ...
# 81110  False       True
# 81111  False      False
# 81112  False       True
# 81113  False       True
# 81114  False      False
#
# [95055 rows x 17 columns]

# %%
df_ds.iloc[139-9:139+10]
# Out:
#      AE_Feature0  AE_Feature1  AE_Feature2  AE_Feature3  AE_Feature4  \
# 130    -0.011905    -0.027025    -0.065444    -0.124951     -0.23898
# 131    -0.011905    -0.027025    -0.065444    -0.124951     -0.23898
# 132    -0.011905    -0.027025    -0.065444    -0.124951     -0.23898
# 133    -0.011905    -0.027025    -0.065444    -0.124951     -0.23898
# 134    -0.011905    -0.027025    -0.065444    -0.124951     -0.23898
# 135    -0.011905    -0.027025    -0.065444    -0.124951     -0.23898
# 136    -0.011905    -0.027025    -0.065444    -0.124951     -0.23898
# 137    -0.011905    -0.027025    -0.065444    -0.124951     -0.23898
# 138    -0.011905    -0.027025    -0.065444    -0.124951     -0.23898
# 139    -0.011905    -0.027025    -0.065444    -0.124951     -0.23898
# 140    -0.011905    -0.027025    -0.065444    -0.124951     -0.23898
# 141    -0.011905    -0.027025    -0.065444    -0.124951     -0.23898
# 142    -0.011905    -0.027025    -0.065444    -0.124951     -0.23898
# 143    -0.011905    -0.027025    -0.065444    -0.124951     -0.23898
# 144    -0.011905    -0.027025    -0.065444    -0.124951     -0.23898
# 145    -0.011905    -0.027025    -0.065444    -0.124951     -0.23898
# 146    -0.011905    -0.027025    -0.065444    -0.124951     -0.23898
# 147    -0.011905    -0.027025    -0.065444    -0.124951     -0.23898
# 148    -0.011905    -0.027025    -0.065444    -0.124951     -0.23898
#
#      AE_Feature5  AE_Feature6  AE_Feature7  AE_Feature8  AE_Feature9  \
# 130    -0.062827    -0.008513    -0.022633    -0.044798    -0.013958
# 131    -0.040907    -0.008513    -0.022633    -0.044798    -0.013958
# 132    -0.083936    -0.008513    -0.022633    -0.044798    -0.013958
# 133    -0.204799    -0.008513    -0.022633    -0.044798    -0.013958
# 134    -0.070619    -0.008513    -0.022633    -0.044798    -0.013958
# 135     0.163769    -0.008513    -0.022633    -0.044798    -0.013958
# 136    -0.097734    -0.008513    -0.022633    -0.044798    -0.013958
# 137    -0.075172    -0.008513    -0.022633    -0.044798    -0.013958
# 138    -0.121304    -0.008513    -0.022633    -0.044798    -0.013958
# 139    -0.002759    -0.008513    -0.022633    -0.044798    -0.013958
# 140    -0.043802    -0.008513    -0.022633    -0.044798    -0.013958
# 141     0.024281    -0.008513    -0.022633    -0.044798    -0.013958
# 142     0.222596    -0.008513    -0.022633    -0.044798    -0.013958
# 143    -0.002334    -0.008513    -0.022633    -0.044798    -0.013958
# 144     0.197102    -0.008513    -0.022633    -0.044798    -0.013958
# 145     0.275069    -0.008513    -0.022633    -0.044798    -0.013958
# 146    -0.038268    -0.008513    -0.022633    -0.044798    -0.013958
# 147     0.906450    -0.008513    -0.022633    -0.044798    -0.013958
# 148     0.102194    -0.008513    -0.022633    -0.044798    -0.013958
#
#      AE_Feature10  AE_Feature11              alarms  Record Indices record  \
# 130     -0.013638     -0.400549               set()              44   052n
# 131     -0.013638     -0.400549               set()              45   052n
# 132     -0.013638     -0.400549               set()              46   052n
# 133     -0.013638     -0.400549               set()              47   052n
# 134     -0.013638     -0.400549               set()              48   052n
# 135     -0.013638     -0.400549               set()              49   052n
# 136     -0.013638     -0.400549  {'ABP  198 > 180'}              50   052n
# 137     -0.013638     -0.400549               set()              51   052n
# 138     -0.013638     -0.400549               set()              52   052n
# 139     -0.013638     -0.400549               set()              53   052n
# 140     -0.013638     -0.400549               set()              54   052n
# 141     -0.013638     -0.400549               set()              55   052n
# 142     -0.013638     -0.400549               set()              56   052n
# 143     -0.013638     -0.400549               set()              57   052n
# 144     -0.013638     -0.400549               set()              58   052n
# 145     -0.013638     -0.400549               set()              59   052n
# 146     -0.013638     -0.400549               set()              60   052n
# 147     -0.013638     -0.400549               set()              61   052n
# 148     -0.013638     -0.400549               set()              62   052n
#
#       VPBs  no_alarms
# 130  False       True
# 131  False       True
# 132  False       True
# 133  False       True
# 134  False       True
# 135  False       True
# 136  False      False
# 137  False       True
# 138  False       True
# 139  False       True
# 140  False       True
# 141  False       True
# 142  False       True
# 143  False       True
# 144  False       True
# 145  False       True
# 146  False       True
# 147  False       True
# 148  False       True

# %%
df_ds["no_alarms"].value_counts()
# Out:
# no_alarms
# True     79912
# False    15143
# Name: count, dtype: int64

# %% [markdown]
# ## Flatten Data and Generate Positive and Negative Cases for Training

# %%
def generate_all_possible_pos_neg_data(df_ds, feat_set, input_days, prediction_day, pred_col):
    # The flattened features for past input_days
    new_feat_set = [feat + " " + str(i) for i in range(input_days) for feat in feat_set] + ["target"] + ["target_index"] + ["record"]
    data = []
    num_pred = 0
    record_groups = df_ds.groupby("record")
    first_pos_index = input_days + prediction_day - 1
    for record, df in tqdm(record_groups):
        df = df.set_index("record_index")
        for pred_index in df.index.tolist():
            if pred_index < first_pos_index: 
                continue
            num_pred += 1
#             print(df.loc[pred_index])
            pred_row = df.loc[pred_index]
            # if this is not positive and not negative case
            if (not pred_row[pred_col]) and (not pred_row["no_alarms"]):
                continue
            # else, add to data set
            start_input, end_input = pred_index - prediction_day - input_days + 1, pred_index - prediction_day
            feat_list = list(df[feat_set].loc[start_input:end_input].values.flatten())
            if len(feat_list) == input_days*len(feat_set):
                new_row = (
                    feat_list +
                    [pred_row[pred_col], pred_row.name, pred_row["record"]]
                )
                data.append(new_row)
#             else:
#                 print(len(feat_list))
    print(num_pred)
    return pd.DataFrame(data, columns=new_feat_set)

def generate_all_possible_pos_neg_data_inNearFuture(df_ds, feat_set, input_days, prediction_day, pred_col):
    # The flattened features for past input_days
    new_feat_set = [feat + " " + str(i) for i in range(input_days) for feat in feat_set] + ["target"] + ["target_index"] + ["record"]
    data = []
    record_groups = df_ds.groupby("record")
    for record, df in tqdm(record_groups):
        df = df.set_index("record_index")
        for last_input_day in range(input_days-1, len(df)-prediction_day):
            # change ilocs to loc
            prediction_df = df.iloc[last_input_day+1:last_input_day+prediction_day+1]
            # no_alarms for all prediction days
            is_negative_case = prediction_df["no_alarms"].all()
            # alarm in any of the prediction days
            is_positive_case = prediction_df[pred_col].any()
            if is_negative_case and is_positive_case:
                raise Exception("Positive and negative case!")
            # if this is no positive in the near future and not negative case
            if (not is_positive_case) and (not is_negative_case):
                continue
            # else, add to data set
            start_input, end_input = last_input_day-input_days+1, last_input_day
            new_row = (
                list(df[feat_set].iloc[start_input:end_input+1].values.flatten()) +
                [is_positive_case, prediction_df.index.values[0], record]
            )
            data.append(new_row)
    return pd.DataFrame(data, columns=new_feat_set)

pos_neg = generate_all_possible_pos_neg_data(df_ds, feat_set, input_days=5, prediction_day=5, pred_col="VPBs")      
pos_neg
# Out:
# 100%|███████████████████████████████████████████| 57/57 [00:26<00:00,  2.15it/s]
# 94542
#        AE_Feature0 0  AE_Feature1 0  AE_Feature10 0  AE_Feature11 0  \
# 0          -0.011905      -0.027025       -0.013638       -0.400549
# 1          -0.011905      -0.027025       -0.013638       -0.400549
# 2          -0.011905      -0.027025       -0.013638       -0.400549
# 3          -0.011905      -0.027025       -0.013638       -0.400549
# 4          -0.011905      -0.027025       -0.013638       -0.400549
# ...              ...            ...             ...             ...
# 87777      -0.011905      -0.027025       -0.013638       -0.400549
# 87778      -0.011905      -0.027025       -0.013638       -0.400549
# 87779      -0.011905      -0.027025       -0.013638       -0.400549
# 87780      -0.011905      -0.027025       -0.013638       -0.400549
# 63405      -0.013958   False           140    418n
# 64745      -0.013958   False           140    427n
# 65218      -0.013958    True           140    442n
# 66850      -0.013958   False           140    449n
# 69279      -0.013958   False           140    455n
# 72054      -0.013958   False           140    457n
# 72584      -0.013958   False           140    464n
# 74001      -0.013958   False           140    465n
# 75340      -0.013958   False           140    466n
# 79059      -0.013958   False           140    467n
# 81802      -0.013958   False           140    471n
# 84800      -0.013958   False           140    472n
# 87085      -0.013958   False           140    476n
#
# [48 rows x 63 columns]

# %%
pos_neg["target"].value_counts()
# Out:
# target
# False    78855
# True      8927
# Name: count, dtype: int64

# %% [markdown]
# ## Remove Rows With NaN Values

# %%
pos_neg_dropna = pos_neg.dropna()
pos_neg_dropna["target"].value_counts()
# Out:
# target
# False    78855
# True      8927
# Name: count, dtype: int64

# %%
pos_neg_dropna
# Out:
#        AE_Feature0 0  AE_Feature1 0  AE_Feature10 0  AE_Feature11 0  \
# 0          -0.011905      -0.027025       -0.013638       -0.400549
# 1          -0.011905      -0.027025       -0.013638       -0.400549
# 2          -0.011905      -0.027025       -0.013638       -0.400549
# 3          -0.011905      -0.027025       -0.013638       -0.400549
# 4          -0.011905      -0.027025       -0.013638       -0.400549
# ...              ...            ...             ...             ...
# 87777      -0.011905      -0.027025       -0.013638       -0.400549
# 87778      -0.011905      -0.027025       -0.013638       -0.400549
# 87779      -0.011905      -0.027025       -0.013638       -0.400549
# 87780      -0.011905      -0.027025       -0.013638       -0.400549
# 87781      -0.011905      -0.027025       -0.013638       -0.400549
#
#        AE_Feature2 0  AE_Feature3 0  AE_Feature4 0  AE_Feature5 0  \
# 0          -0.065444      -0.124951       -0.23898      -0.358224
# 1          -0.065444      -0.124951       -0.23898      -0.464522
# 2          -0.065444      -0.124951       -0.23898      -0.467191
# 3          -0.065444      -0.124951       -0.23898      -0.427537
# 4          -0.065444      -0.124951       -0.23898      -0.290022
# ...              ...            ...            ...            ...
# 87777      -0.065444      -0.124951       -0.23898      -0.580750
# 87778      -0.065444      -0.124951       -0.23898      -0.580750
# 87779      -0.065444      -0.124951       -0.23898      -0.580750
# 87780      -0.065444      -0.124951       -0.23898      -0.580750
# 87781      -0.065444      -0.124951       -0.23898      -0.580750
#
#        AE_Feature6 0  AE_Feature7 0  ...  AE_Feature3 4  AE_Feature4 4  \
# 0          -0.008513      -0.022633  ...      -0.124951       -0.23898
# 1          -0.008513      -0.022633  ...      -0.124951       -0.23898
# 2          -0.008513      -0.022633  ...      -0.124951       -0.23898
# 3          -0.008513      -0.022633  ...      -0.124951       -0.23898
# 4          -0.008513      -0.022633  ...      -0.124951       -0.23898
# ...              ...            ...  ...            ...            ...
# 87777      -0.008513      -0.022633  ...      -0.124951       -0.23898
# 87778      -0.008513      -0.022633  ...      -0.124951       -0.23898
# 87779      -0.008513      -0.022633  ...      -0.124951       -0.23898
# 87780      -0.008513      -0.022633  ...      -0.124951       -0.23898
# 87781      -0.008513      -0.022633  ...      -0.124951       -0.23898
#
#        AE_Feature5 4  AE_Feature6 4  AE_Feature7 4  AE_Feature8 4  \
# 0          -0.290022      -0.008513      -0.022633      -0.044798
# 1          -0.442634      -0.008513      -0.022633      -0.044798
# 2          -0.445566      -0.008513      -0.022633      -0.044798
# 3          -0.370654      -0.008513      -0.022633      -0.044798
# 4          -0.172893      -0.008513      -0.022633      -0.044798
# ...              ...            ...            ...            ...
# 87777      -0.580750      -0.008513      -0.022633      -0.044798
# 87778      -0.580750      -0.008513      -0.022633      -0.044798
# 87779      -0.580750      -0.008513      -0.022633      -0.044798
# 87780      -0.580750      -0.008513      -0.022633      -0.044798
# 87781      -0.580750      -0.008513      -0.022633      -0.044798
#
#        AE_Feature9 4  target  target_index  record
# 0          -0.013958   False             9    048n
# 1          -0.013958   False            10    048n
# 2          -0.013958   False            11    048n
# 3          -0.013958   False            12    048n
# 4          -0.013958   False            13    048n
# ...              ...     ...           ...     ...
# 87777      -0.013958   False           934    476n
# 87778      -0.013958   False           935    476n
# 87779      -0.013958   False           936    476n
# 87780      -0.013958   False           937    476n
# 87781      -0.013958   False           938    476n
#
# [87782 rows x 63 columns]

# %%
def label_train_valid_test_samples(df, train_records, valid_records, test_records):
    df = df.copy()
    df["train"] = df["record"].isin(train_records)
    df["valid"] = df["record"].isin(valid_records)
    df["test"] = df["record"].isin(test_records)
    return df

pos_neg_dropna = label_train_valid_test_samples(pos_neg_dropna, train_records, valid_records, test_records)
pos_neg_dropna
# Out:
#        AE_Feature0 0  AE_Feature1 0  AE_Feature10 0  AE_Feature11 0  \
# 0          -0.011905      -0.027025       -0.013638       -0.400549
# 1          -0.011905      -0.027025       -0.013638       -0.400549
# 2          -0.011905      -0.027025       -0.013638       -0.400549
# 3          -0.011905      -0.027025       -0.013638       -0.400549
# 4          -0.011905      -0.027025       -0.013638       -0.400549
# ...              ...            ...             ...             ...
# 87777      -0.011905      -0.027025       -0.013638       -0.400549
# 87778      -0.011905      -0.027025       -0.013638       -0.400549
# 87779      -0.011905      -0.027025       -0.013638       -0.400549
# 87780      -0.011905      -0.027025       -0.013638       -0.400549
# 87781      -0.011905      -0.027025       -0.013638       -0.400549
#
#        AE_Feature2 0  AE_Feature3 0  AE_Feature4 0  AE_Feature5 0  \
# 0          -0.065444      -0.124951       -0.23898      -0.358224
# 1          -0.065444      -0.124951       -0.23898      -0.464522
# 2          -0.065444      -0.124951       -0.23898      -0.467191
# 3          -0.065444      -0.124951       -0.23898      -0.427537
# 4          -0.065444      -0.124951       -0.23898      -0.290022
# ...              ...            ...            ...            ...
# 87777      -0.065444      -0.124951       -0.23898      -0.580750
# 87778      -0.065444      -0.124951       -0.23898      -0.580750
# 87779      -0.065444      -0.124951       -0.23898      -0.580750
# 87780      -0.065444      -0.124951       -0.23898      -0.580750
# 87781      -0.065444      -0.124951       -0.23898      -0.580750
#
#        AE_Feature6 0  AE_Feature7 0  ...  AE_Feature6 4  AE_Feature7 4  \
# 0          -0.008513      -0.022633  ...      -0.008513      -0.022633
# 1          -0.008513      -0.022633  ...      -0.008513      -0.022633
# 2          -0.008513      -0.022633  ...      -0.008513      -0.022633
# 3          -0.008513      -0.022633  ...      -0.008513      -0.022633
# 4          -0.008513      -0.022633  ...      -0.008513      -0.022633
# ...              ...            ...  ...            ...            ...
# 87777      -0.008513      -0.022633  ...      -0.008513      -0.022633
# 87778      -0.008513      -0.022633  ...      -0.008513      -0.022633
# 87779      -0.008513      -0.022633  ...      -0.008513      -0.022633
# 87780      -0.008513      -0.022633  ...      -0.008513      -0.022633
# 87781      -0.008513      -0.022633  ...      -0.008513      -0.022633
#
#        AE_Feature8 4  AE_Feature9 4  target  target_index  record  train  \
# 0          -0.044798      -0.013958   False             9    048n   True
# 1          -0.044798      -0.013958   False            10    048n   True
# 2          -0.044798      -0.013958   False            11    048n   True
# 3          -0.044798      -0.013958   False            12    048n   True
# 4          -0.044798      -0.013958   False            13    048n   True
# ...              ...            ...     ...           ...     ...    ...
# 87777      -0.044798      -0.013958   False           934    476n   True
# 87778      -0.044798      -0.013958   False           935    476n   True
# 87779      -0.044798      -0.013958   False           936    476n   True
# 87780      -0.044798      -0.013958   False           937    476n   True
# 87781      -0.044798      -0.013958   False           938    476n   True
#
#        valid   test
# 0      False  False
# 1      False  False
# 2      False  False
# 3      False  False
# 4      False  False
# ...      ...    ...
# 87777  False  False
# 87778  False  False
# 87779  False  False
# 87780  False  False
# 87781  False  False
#
# [87782 rows x 66 columns]

# %%
pos_neg_dropna.columns
# Out:
# Index(['AE_Feature0 0', 'AE_Feature1 0', 'AE_Feature10 0', 'AE_Feature11 0',
#        'AE_Feature2 0', 'AE_Feature3 0', 'AE_Feature4 0', 'AE_Feature5 0',
#        'AE_Feature6 0', 'AE_Feature7 0', 'AE_Feature8 0', 'AE_Feature9 0',
#        'AE_Feature0 1', 'AE_Feature1 1', 'AE_Feature10 1', 'AE_Feature11 1',
#        'AE_Feature2 1', 'AE_Feature3 1', 'AE_Feature4 1', 'AE_Feature5 1',
#        'AE_Feature6 1', 'AE_Feature7 1', 'AE_Feature8 1', 'AE_Feature9 1',
#        'AE_Feature0 2', 'AE_Feature1 2', 'AE_Feature10 2', 'AE_Feature11 2',
#        'AE_Feature2 2', 'AE_Feature3 2', 'AE_Feature4 2', 'AE_Feature5 2',
#        'AE_Feature6 2', 'AE_Feature7 2', 'AE_Feature8 2', 'AE_Feature9 2',
#        'AE_Feature0 3', 'AE_Feature1 3', 'AE_Feature10 3', 'AE_Feature11 3',
#        'AE_Feature2 3', 'AE_Feature3 3', 'AE_Feature4 3', 'AE_Feature5 3',
#        'AE_Feature6 3', 'AE_Feature7 3', 'AE_Feature8 3', 'AE_Feature9 3',
#        'AE_Feature0 4', 'AE_Feature1 4', 'AE_Feature10 4', 'AE_Feature11 4',
#        'AE_Feature2 4', 'AE_Feature3 4', 'AE_Feature4 4', 'AE_Feature5 4',
#        'AE_Feature6 4', 'AE_Feature7 4', 'AE_Feature8 4', 'AE_Feature9 4',
#        'target', 'target_index', 'record', 'train', 'valid', 'test'],
#       dtype='object')

# %%
def display_pca(df, num_features, label_col):
    X, y = df.iloc[:,:num_features], df[label_col]
    from sklearn.decomposition import PCA
    pca = PCA()
    Xt = pca.fit_transform(X)
    plot = plt.scatter(Xt[:,0], Xt[:,1], c=y)
    plt.legend(handles=plot.legend_elements()[0], labels=[0,1])
    plt.show()

display_pca(pos_neg_dropna, num_features=60, label_col="target")

# %%
pos_neg_dropna.to_csv(fp_downsampled_dropna_file)
