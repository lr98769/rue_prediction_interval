# %% [markdown]
# # Data Preprocessing

# %%
# Important libraries
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
import csv
from wordcloud import WordCloud
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt

# File paths
fp_notebooks_folder = "./"
fp_code_folder = "../"
fp_processed_folder = os.path.join(fp_code_folder, "../processed_data")
fp_converted_folder = os.path.join(fp_processed_folder, "converted_to_csv")
fp_downsampled_folder = os.path.join(fp_processed_folder, "downsampled")
fp_downsampled_continuous_file = os.path.join(fp_downsampled_folder, "continous.csv")
fp_downsampled_dropna_file = os.path.join(fp_downsampled_folder, "dropna.csv")
fp_fields_file = os.path.join(fp_converted_folder, "fields.csv")

# %%
# Get fields file to analyse
fields_df = pd.read_csv(fp_fields_file, quoting=csv.QUOTE_NONE, escapechar='/', index_col=0)
fields_df
# Out:
#            fs  sig_len  n_sig   base_date base_time  \
# 0    0.976562    51138      7  1994-12-13  08:38:53
# 1    0.976562    77038      7  1995-02-22  13:08:55
# 2    0.976562   141796      7  1995-02-24  09:44:42
# 3    0.976562   131250     12  1995-03-02  15:36:24
# 4    0.976562     4606      5  1995-01-24  08:22:11
# ..        ...      ...    ...         ...       ...
# 111  0.976562   151176     14  1996-04-06  15:26:26
# 112  0.976562   147656     15  1996-04-22  17:35:49
# 113  0.976562   154687     12  1996-04-29  14:48:52
# 114  0.976562   193946     18  1996-05-02  11:54:49
# 115  0.976562   178121      4  1996-06-23  15:01:25
#
#                                                  units  \
# 0    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 1    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 2    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 3    ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 4                 ['mmHg', 'mmHg', 'mmHg', 'bpm', '%']
# ..                                                 ...
# 111  ['mmHg', 'mmHg', 'mmHg', 'lpm', 'mmHg', 'bpm',...
# 112  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'lpm', 'mmHg',...
# 113  ['mmHg', 'mmHg', 'mmHg', 'lpm', 'mmHg', 'bpm',...
# 114  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'lpm', 'mmHg',...
# 115                        ['lpm', 'bpm', '%', 'degC']
#
#                                               sig_name comments  \
# 0    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 1    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 2    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 3    ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 4     ['NBPmean', 'NBPsys', 'NBPdias', 'RESP', 'SpO2']       []
# ..                                                 ...      ...
# 111  ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'CVP'...       []
# 112  ['ABPmean', 'ABPsys', 'ABPdias', 'AWRR', 'C.O....       []
# 113  ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'CVP'...       []
# 114  ['ABPmean', 'ABPsys', 'ABPdias', 'AWRR', 'C.O....       []
# 115                 ['C.O.', 'RESP', 'SpO2', 'Tblood']       []
#
#                                          unique_alarms record
# 0    {'*ASYSTOLE': 23, '*TACHY 216 > 180': 9, '*VEN...   048n
# 1    {'ABP  184 > 180': 115, 'ABP  182 > 180': 115,...   052n
# 2    {'PAIR VPBs': 982, 'HR  53 <  55': 560, 'MULTI...   054n
# 3    {'VPBs > 5/MIN': 1661, 'PAIR VPBs': 1584, 'MUL...   055n
# 4                             {'MULTIFORM VPBs': 4600}   208n
# ..                                                 ...    ...
# 111  {'VPBs > 5/MIN': 20341, 'VPBs > 11/MIN': 1085,...   482n
# 112  {'IRREGULAR HR': 19031, 'MULTIFORM VPBs': 1982...   484n
# 113  {'PAIR VPBs': 731, 'VPBs > 11/MIN': 567, 'IRRE...   485n
# 114  {'PAIR VPBs': 4158, 'RUN VPBs 3 - 9': 1688, 'M...   486n
# 115  {'ABP   80 < 85': 234, 'RUN VPBs 3 - 9': 199, ...   488n
#
# [116 rows x 10 columns]

# %%
def add_feat_names(fields_df):
    feat_names = []
    for i in range(len(fields_df)):
        row = fields_df.iloc[i]
        units_list, sig_list = eval(row["units"]), eval(row["sig_name"])
        cur_feat_names = {sig_list[j] + " (" + units_list[j] + ")" for j in range(len(units_list))}
        feat_names.append(cur_feat_names)
    return feat_names

fields_df["feat_cols"] = add_feat_names(fields_df)
fields_df
# Out:
#            fs  sig_len  n_sig   base_date base_time  \
# 0    0.976562    51138      7  1994-12-13  08:38:53
# 1    0.976562    77038      7  1995-02-22  13:08:55
# 2    0.976562   141796      7  1995-02-24  09:44:42
# 3    0.976562   131250     12  1995-03-02  15:36:24
# 4    0.976562     4606      5  1995-01-24  08:22:11
# ..        ...      ...    ...         ...       ...
# 111  0.976562   151176     14  1996-04-06  15:26:26
# 112  0.976562   147656     15  1996-04-22  17:35:49
# 113  0.976562   154687     12  1996-04-29  14:48:52
# 114  0.976562   193946     18  1996-05-02  11:54:49
# 115  0.976562   178121      4  1996-06-23  15:01:25
#
#                                                  units  \
# 0    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 1    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 2    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 3    ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 4                 ['mmHg', 'mmHg', 'mmHg', 'bpm', '%']
# ..                                                 ...
# 111  ['mmHg', 'mmHg', 'mmHg', 'lpm', 'mmHg', 'bpm',...
# 112  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'lpm', 'mmHg',...
# 113  ['mmHg', 'mmHg', 'mmHg', 'lpm', 'mmHg', 'bpm',...
# 114  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'lpm', 'mmHg',...
# 115                        ['lpm', 'bpm', '%', 'degC']
#
#                                               sig_name comments  \
# 0    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 1    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 2    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 3    ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 4     ['NBPmean', 'NBPsys', 'NBPdias', 'RESP', 'SpO2']       []
# ..                                                 ...      ...
# 111  ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'CVP'...       []
# 112  ['ABPmean', 'ABPsys', 'ABPdias', 'AWRR', 'C.O....       []
# 113  ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'CVP'...       []
# 114  ['ABPmean', 'ABPsys', 'ABPdias', 'AWRR', 'C.O....       []
# 115                 ['C.O.', 'RESP', 'SpO2', 'Tblood']       []
#
#                                          unique_alarms record  \
# 0    {'*ASYSTOLE': 23, '*TACHY 216 > 180': 9, '*VEN...   048n
# 1    {'ABP  184 > 180': 115, 'ABP  182 > 180': 115,...   052n
# 2    {'PAIR VPBs': 982, 'HR  53 <  55': 560, 'MULTI...   054n
# 3    {'VPBs > 5/MIN': 1661, 'PAIR VPBs': 1584, 'MUL...   055n
# 4                             {'MULTIFORM VPBs': 4600}   208n
# ..                                                 ...    ...
# 111  {'VPBs > 5/MIN': 20341, 'VPBs > 11/MIN': 1085,...   482n
# 112  {'IRREGULAR HR': 19031, 'MULTIFORM VPBs': 1982...   484n
# 113  {'PAIR VPBs': 731, 'VPBs > 11/MIN': 567, 'IRRE...   485n
# 114  {'PAIR VPBs': 4158, 'RUN VPBs 3 - 9': 1688, 'M...   486n
# 115  {'ABP   80 < 85': 234, 'RUN VPBs 3 - 9': 199, ...   488n
#
#                                              feat_cols
# 0    {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...
# 1    {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...
# 2    {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...
# 3    {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...
# 4    {NBPsys (mmHg), NBPdias (mmHg), NBPmean (mmHg)...
# ..                                                 ...
# 111  {ST1 (mV), ABPmean (mmHg), HR (bpm), ABPsys (m...
# 112  {ABPmean (mmHg), ETCO2 (mmHg), HR (bpm), ABPsy...
# 113  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...
# 114  {ST1 (mV), ABPmean (mmHg), ETCO2 (mmHg), HR (b...
# 115  {SpO2 (%), RESP (bpm), Tblood (degC), C.O. (lpm)}
#
# [116 rows x 11 columns]

# %% [markdown]
# ## Select Feature Set

# %%
# Check what are the most common subset of features
def most_comment_subset_of_features(fields_df):
    feat_set_series = fields_df["feat_cols"]
    feat_set_counts = feat_set_series.value_counts().reset_index()
    feat_set_counts.columns = ["feat_set", "count"]
    feat_set_counts["num_features"] = [len(feat_set) for feat_set in feat_set_counts["feat_set"]]
    feat_set_counts = feat_set_counts.sort_values("num_features", ascending=True)
    num_unique_feat_sets = len(feat_set_counts)
    
    feat_set_inc_list = []
    for i in range(num_unique_feat_sets):
        total_count = 0
        potential_subset = feat_set_counts["feat_set"].iloc[i]
        for j in range(i,num_unique_feat_sets):
            potential_superset, count = feat_set_counts[["feat_set","count"]].iloc[j].values
            if potential_subset.issubset(potential_superset):
                total_count += count
        feat_set_inc_list.append({"feat_set": potential_subset, "inc_count": total_count})
    
    feat_set_inc_df = pd.DataFrame(feat_set_inc_list)
    
    return feat_set_counts, feat_set_inc_df.sort_values("inc_count", ascending=False)
feat_set_stats = most_comment_subset_of_features(fields_df)
display(feat_set_stats[0])
display(feat_set_stats[1])
# Out:
#                                              feat_set  count  num_features
# 39                                       {RESP (bpm)}      1             1
# 1                              {SpO2 (%), RESP (bpm)}     12             2
# 35              {SpO2 (%), Tblood (degC), C.O. (lpm)}      1             3
# 4   {SpO2 (%), RESP (bpm), Tblood (degC), C.O. (lpm)}      6             4
# 32  {AWRR (bpm), RESP (bpm), IMCO2 (mmHg), ETCO2 (...      1             5
# 5   {NBPsys (mmHg), NBPdias (mmHg), NBPmean (mmHg)...      4             5
# 10  {RESP (bpm), PAWP (mmHg), SpO2 (%), C.O. (lpm)...      2             5
# 16  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), RESP...      2             6
# 40  {NBPsys (mmHg), NBPdias (mmHg), HR (bpm), NBPm...      1             6
# 14  {NBPsys (mmHg), NBPdias (mmHg), HR (bpm), NBPm...      2             7
# 37  {NBPsys (mmHg), NBPdias (mmHg), NBPmean (mmHg)...      1             7
# 0   {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...     15             7
# 20  {UAPdias (mmHg), RESP (bpm), UAPmean (mmHg), S...      1             7
# 15  {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...      2             9
# 19  {ST1 (mV), ABPmean (mmHg), HR (bpm), ABPsys (m...      1             9
# 44  {HR (bpm), PAPdias (mmHg), PAPsys (mmHg), PAPm...      1             9
# 45  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...      1             9
# 29  {NBPsys (mmHg), NBPdias (mmHg), HR (bpm), NBPm...      1            10
# 46  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...      1            10
# 6   {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...      4            10
# 3   {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...      7            10
# 48  {CPP (mmHg), ST1 (mV), ABPmean (mmHg), HR (bpm...      1            11
# 41  {NBPsys (mmHg), NBPdias (mmHg), HR (bpm), ABPm...      1            11
# 31  {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...      1            12
# 52  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...      1            12
# 12  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...      2            12
# 38  {NBPsys (mmHg), NBPdias (mmHg), HR (bpm), NBPm...      1            13
# 2   {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...      9            13
# 23  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...      1            13
# 33  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...      1            13
# 13  {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...      2            13
# 50  {ARTdias (mmHg), ABPmean (mmHg), HR (bpm), ABP...      1            14
# 9   {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...      2            14
# 42  {NBPsys (mmHg), NBPdias (mmHg), ST1 (mV), ABPm...      1            14
# 22  {ST1 (mV), ABPmean (mmHg), HR (bpm), ABPsys (m...      1            14
# 26  {ST1 (mV), ABPmean (mmHg), HR (bpm), ST3 (mV),...      1            15
# 21  {ABPmean (mmHg), ETCO2 (mmHg), HR (bpm), ABPsy...      1            15
# 36  {ARTdias (mmHg), ABPmean (mmHg), HR (bpm), ABP...      1            16
# 51  {NBPsys (mmHg), NBPdias (mmHg), ST1 (mV), ABPm...      1            16
# 27  {ARTdias (mmHg), ABPmean (mmHg), HR (bpm), ABP...      1            16
# 8   {ST1 (mV), ABPmean (mmHg), HR (bpm), ST3 (mV),...      3            16
# 28  {ST1 (mV), ABPmean (mmHg), HR (bpm), ST3 (mV),...      1            16
# 17  {NBPsys (mmHg), NBPdias (mmHg), ARTdias (mmHg)...      2            16
# 11  {ST1 (mV), ABPmean (mmHg), HR (bpm), ST3 (mV),...      2            16
# 43  {NBPsys (mmHg), NBPdias (mmHg), ST1 (mV), ABPm...      1            17
# 18  {ST1 (mV), ABPmean (mmHg), HR (bpm), ST3 (mV),...      1            17
# 7   {ST1 (mV), ABPmean (mmHg), ETCO2 (mmHg), HR (b...      3            18
# 25  {ST1 (mV), ABPmean (mmHg), ETCO2 (mmHg), HR (b...      1            18
# 30  {ST1 (mV), ABPmean (mmHg), HR (bpm), ST3 (mV),...      1            19
# 34  {ST1 (mV), ABPmean (mmHg), HR (bpm), ST3 (mV),...      1            19
# 47  {ST1 (mV), ABPmean (mmHg), HR (bpm), ST3 (mV),...      1            19
# 24  {ST1 (mV), ABPmean (mmHg), HR (bpm), ST3 (mV),...      1            20
# 49  {ST1 (mV), ABPmean (mmHg), HR (bpm), ST3 (mV),...      1            22
#                                              feat_set  inc_count
# 0                                        {RESP (bpm)}         90
# 1                              {SpO2 (%), RESP (bpm)}         88
# 7   {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), RESP...         57
# 11  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...         48
# 2               {SpO2 (%), Tblood (degC), C.O. (lpm)}         37
# 16  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...         35
# 5   {NBPsys (mmHg), NBPdias (mmHg), NBPmean (mmHg)...         32
# 20  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...         27
# 8   {NBPsys (mmHg), NBPdias (mmHg), HR (bpm), NBPm...         24
# 9   {NBPsys (mmHg), NBPdias (mmHg), HR (bpm), NBPm...         23
# 13  {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...         23
# 19  {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...         19
# 24  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...         19
# 3   {SpO2 (%), RESP (bpm), Tblood (degC), C.O. (lpm)}         18
# 17  {NBPsys (mmHg), NBPdias (mmHg), HR (bpm), NBPm...         16
# 34  {ST1 (mV), ABPmean (mmHg), HR (bpm), ABPsys (m...         16
# 23  {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...         16
# 35  {ST1 (mV), ABPmean (mmHg), HR (bpm), ST3 (mV),...         15
# 27  {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...         14
# 18  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...         10
# 46  {ST1 (mV), ABPmean (mmHg), ETCO2 (mmHg), HR (b...          7
# 28  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...          7
# 30  {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...          6
# 6   {RESP (bpm), PAWP (mmHg), SpO2 (%), C.O. (lpm)...          6
# 40  {ST1 (mV), ABPmean (mmHg), HR (bpm), ST3 (mV),...          6
# 25  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...          5
# 15  {HR (bpm), PAPdias (mmHg), PAPsys (mmHg), PAPm...          5
# 14  {ST1 (mV), ABPmean (mmHg), HR (bpm), ABPsys (m...          4
# 43  {ST1 (mV), ABPmean (mmHg), HR (bpm), ST3 (mV),...          4
# 36  {ABPmean (mmHg), ETCO2 (mmHg), HR (bpm), ABPsy...          3
# 32  {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...          3
# 33  {NBPsys (mmHg), NBPdias (mmHg), ST1 (mV), ABPm...          3
# 26  {NBPsys (mmHg), NBPdias (mmHg), HR (bpm), NBPm...          3
# 4   {AWRR (bpm), RESP (bpm), IMCO2 (mmHg), ETCO2 (...          3
# 10  {NBPsys (mmHg), NBPdias (mmHg), NBPmean (mmHg)...          2
# 49  {ST1 (mV), ABPmean (mmHg), HR (bpm), ST3 (mV),...          2
# 48  {ST1 (mV), ABPmean (mmHg), HR (bpm), ST3 (mV),...          2
# 39  {ARTdias (mmHg), ABPmean (mmHg), HR (bpm), ABP...          2
# 47  {ST1 (mV), ABPmean (mmHg), ETCO2 (mmHg), HR (b...          2
# 41  {ST1 (mV), ABPmean (mmHg), HR (bpm), ST3 (mV),...          2
# 42  {NBPsys (mmHg), NBPdias (mmHg), ARTdias (mmHg)...          2
# 29  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...          2
# 45  {ST1 (mV), ABPmean (mmHg), HR (bpm), ST3 (mV),...          1
# 51  {ST1 (mV), ABPmean (mmHg), HR (bpm), ST3 (mV),...          1
# 50  {ST1 (mV), ABPmean (mmHg), HR (bpm), ST3 (mV),...          1
# 31  {ARTdias (mmHg), ABPmean (mmHg), HR (bpm), ABP...          1
# 44  {NBPsys (mmHg), NBPdias (mmHg), ST1 (mV), ABPm...          1
# 12  {UAPdias (mmHg), RESP (bpm), UAPmean (mmHg), S...          1
# 38  {NBPsys (mmHg), NBPdias (mmHg), ST1 (mV), ABPm...          1
# 37  {ARTdias (mmHg), ABPmean (mmHg), HR (bpm), ABP...          1
# 21  {CPP (mmHg), ST1 (mV), ABPmean (mmHg), HR (bpm...          1
# 22  {NBPsys (mmHg), NBPdias (mmHg), HR (bpm), ABPm...          1
# 52  {ST1 (mV), ABPmean (mmHg), HR (bpm), ST3 (mV),...          1

# %%
feat_set = feat_set_stats[1].iloc[2][0]
# Check above count
def check_feat_set_count(fields_df, cur_feat_set):
    feat_set_series = fields_df["feat_cols"]
    count = 0
    for fs in feat_set_series:
        if cur_feat_set.issubset(fs):
            count += 1
    return count
check_feat_set_count(fields_df, cur_feat_set=feat_set)
# Out:
# 57

# %%
# Shortlist patients with feat_set
def shortlist_patients_with_feat_set(fields_df, cur_feat_set):
    feat_set_series = fields_df["feat_cols"]
    records = []
    for i, fs in enumerate(feat_set_series):
        if cur_feat_set.issubset(fs):
            records.append(fields_df["record"].iloc[i])
    return records
shortlisted_records = shortlist_patients_with_feat_set(fields_df, cur_feat_set=feat_set)
print(len(shortlisted_records), "Records:", shortlisted_records)
# Out:
# 57 Records: ['048n', '052n', '054n', '055n', '211n', '212n', '213n', '214n', '216n', '220n', '221n', '226n', '230n', '231n', '232n', '235n', '237n', '240n', '241n', '242n', '243n', '245n', '248n', '252n', '253n', '254n', '259n', '260n', '264n', '267n', '268n', '269n', '271n', '291n', '293n', '401n', '403n', '408n', '409n', '413n', '414n', '415n', '417n', '418n', '427n', '442n', '449n', '455n', '457n', '464n', '465n', '466n', '467n', '471n', '472n', '474n', '476n']

# %%
fields_df_shortlisted = fields_df[fields_df["record"].isin(shortlisted_records)]
fields_df_shortlisted
# Out:
#            fs  sig_len  n_sig   base_date base_time  \
# 0    0.976562    51138      7  1994-12-13  08:38:53
# 1    0.976562    77038      7  1995-02-22  13:08:55
# 2    0.976562   141796      7  1995-02-24  09:44:42
# 3    0.976562   131250     12  1995-03-02  15:36:24
# 7    0.976562    75991      6  1995-01-26  14:34:07
# 8    0.976562   145275     10  1995-04-04  14:00:03
# 9    0.976562   171093      7  1995-04-06  09:17:44
# 10   0.976562    90157     10  1995-04-19  07:14:25
# 12   0.976562    95654     16  1995-05-07  14:11:32
# 15   0.976562     4101      7  1995-05-17  08:26:10
# 16   0.976562    83362      7  1995-05-18  11:50:31
# 20   0.976562   112500      7  1995-06-05  07:46:28
# 21   0.976562    66796     13  1995-06-20  12:43:49
# 22   0.976562   150000     10  1995-06-23  09:44:09
# 23   0.976562    92799      7  1995-06-29  07:25:01
# 25   0.976562   166999     11  1995-07-13  13:30:04
# 26   0.976562   150000     13  1995-07-20  12:40:36
# 27   0.976562   107226     14  1995-08-24  11:47:32
# 28   0.976562    70163     14  1995-08-28  12:43:36
# 29   0.976562   149414     13  1995-08-29  09:03:14
# 30   0.976562   164063     10  1995-09-27  13:36:48
# 31   0.976562   150585     10  1995-10-24  13:31:03
# 32   0.976562   120116     10  1995-11-10  10:55:33
# 33   0.976562    99023     10  1995-11-19  19:40:47
# 34   0.976562   149414     14  1995-11-22  07:16:04
# 35   0.976562   149415     17  1995-11-24  14:00:57
# 37   0.976562   165224     12  1995-12-11  10:17:51
# 38   0.976562    46289     13  1995-12-15  07:23:50
# 40   0.976562   162346     13  1996-01-04  12:40:13
# 41   0.976562   161541     13  1996-01-13  11:17:31
# 42   0.976562   130155     13  1996-01-15  10:31:12
# 43   0.976562   151700     10  1996-01-17  00:30:30
# 44   0.976562   110884     13  1996-01-19  08:29:27
# 55   0.976562    75788      6  1996-04-04  10:40:44
# 56   0.976562   176367     10  1996-04-06  16:07:55
# 57   0.976562    88387      7  1995-01-25  12:41:44
# 58   0.976562   149999      7  1995-01-26  14:20:11
# 61   0.976562   169814      7  1995-05-03  05:19:47
# 62   0.976562   152343      7  1995-05-05  11:35:21
# 65   0.976562    75124      7  1995-05-18  14:17:54
# 66   0.976562    88094      7  1995-05-19  13:14:10
# 67   0.976562   147655     13  1995-05-22  12:45:31
# 68   0.976562    42773     16  1995-05-26  07:40:48
# 69   0.976562    95162     16  1995-06-01  09:13:34
# 71   0.976562   205664     16  1995-06-23  13:02:51
# 82   0.976562   123555      7  1995-11-07  11:08:32
# 87   0.976562   149433      9  1995-12-02  13:39:23
# 93   0.976562   171097     17  1996-01-07  18:55:39
# 95   0.976562   202734     16  1996-01-15  10:18:48
# 98   0.976562    93737     10  1996-01-31  08:04:57
# 99   0.976562   222655     10  1996-02-01  11:10:52
# 100  0.976562   241406     10  1996-02-08  12:32:05
# 101  0.976562   193946     13  1996-02-13  08:58:09
# 103  0.976562   220312     13  1996-03-05  08:27:37
# 104  0.976562    30469     13  1996-03-11  08:33:09
# 105  0.976562   135352     20  1996-03-12  23:17:36
# 106  0.976562    62109     18  1996-03-15  22:42:01
#
#                                                  units  \
# 0    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 1    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 2    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 3    ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 7          ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', '%']
# 8    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 9    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 10   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 12   ['mmHg', 'mmHg', 'mmHg', 'mmHg', 'mmHg', 'mmHg...
# 15   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 16   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 20   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 21   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 22   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 23   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 25   ['mmHg', 'mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg'...
# 26   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 27   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 28   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 29   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 30   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 31   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 32   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 33   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 34   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 35   ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 37   ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 38   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 40   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 41   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 42   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 43   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 44   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 55         ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', '%']
# 56   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 57   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 58   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 61   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 62   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 65   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 66   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 67   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 68   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 69   ['mmHg', 'mmHg', 'mmHg', 'mmHg', 'mmHg', 'mmHg...
# 71   ['mmHg', 'mmHg', 'mmHg', 'mmHg', 'mmHg', 'mmHg...
# 82   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 87   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 93   ['mmHg', 'mmHg', 'mmHg', 'lpm', 'mmHg', 'bpm',...
# 95   ['mmHg', 'mmHg', 'mmHg', 'lpm', 'mmHg', 'bpm',...
# 98   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 99   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 100  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 101  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 103  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 104  ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 105  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'lpm', 'mmHg',...
# 106  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'lpm', 'mmHg',...
#
#                                               sig_name comments  \
# 0    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 1    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 2    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 3    ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 7    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'RESP',...       []
# 8    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 9    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 10   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 12   ['ABPmean', 'ABPsys', 'ABPdias', 'ARTmean', 'A...       []
# 15   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 16   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 20   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 21   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 22   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 23   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 25   ['ABPmean', 'ABPsys', 'ABPdias', 'CVP', 'HR', ...       []
# 26   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 27   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 28   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 29   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 30   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 31   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 32   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 33   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 34   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 35   ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 37   ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 38   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 40   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 41   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 42   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 43   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 44   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 55   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'RESP',...       []
# 56   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 57   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 58   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 61   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 62   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 65   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 66   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 67   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 68   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 69   ['ABPmean', 'ABPsys', 'ABPdias', 'ARTmean', 'A...       []
# 71   ['ABPmean', 'ABPsys', 'ABPdias', 'ARTmean', 'A...       []
# 82   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 87   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 93   ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'CVP'...       []
# 95   ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'CVP'...       []
# 98   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 99   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 100  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 101  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 103  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 104  ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 105  ['ABPmean', 'ABPsys', 'ABPdias', 'AWRR', 'C.O....       []
# 106  ['ABPmean', 'ABPsys', 'ABPdias', 'AWRR', 'C.O....       []
#
#                                          unique_alarms record  \
# 0    {'*ASYSTOLE': 23, '*TACHY 216 > 180': 9, '*VEN...   048n
# 1    {'ABP  184 > 180': 115, 'ABP  182 > 180': 115,...   052n
# 2    {'PAIR VPBs': 982, 'HR  53 <  55': 560, 'MULTI...   054n
# 3    {'VPBs > 5/MIN': 1661, 'PAIR VPBs': 1584, 'MUL...   055n
# 7    {'PAIR VPBs': 328, 'HR 126 > 120': 99, 'ABP  2...   211n
# 8    {'VPBs >  5/MIN': 11644, 'MISSED BEATS': 10580...   212n
# 9    {'VPBs >  5/MIN': 3536, 'ABP   87 < 90': 717, ...   213n
# 10   {'RUN VPBs > 2': 3855, 'PAIR VPBs': 2566, 'VEN...   214n
# 12   {'VENT TRIGEMINY': 483, 'VPBs >  5/MIN': 389, ...   216n
# 15                             {'MULTIFORM VPBs': 309}   220n
# 16   {'PAIR VPBs': 793, 'MULTIFORM VPBs': 565, 'ABP...   221n
# 20   {'HR 141 > 140': 1655, 'MISSED BEATS': 625, 'V...   226n
# 21   {'VPBs >  5/MIN': 2331, 'PAIR VPBs': 1673, 'IR...   230n
# 22   {'PAIR VPBs': 6251, 'MULTIFORM VPBs': 1619, 'M...   231n
# 23   {'PAIR VPBs': 21307, 'IRREGULAR HR': 10410, 'V...   232n
# 25   {'HR 121 > 120': 1959, 'HR 130 > 125': 1746, '...   235n
# 26   {'MULTIFORM VPBs': 9554, 'VPBs >  5/MIN': 8578...   237n
# 27   {'ABP   78 < 90': 286, 'MISSED BEATS': 268, 'A...   240n
# 28   {'MULTIFORM VPBs': 13232, 'PAIR VPBs': 11212, ...   241n
# 29   {'MULTIFORM VPBs': 26064, 'PAIR VPBs': 10354, ...   242n
# 30   {'HR 151 > 150': 803, 'HR 152 > 150': 549, 'HR...   243n
# 31   {'MISSED BEATS': 12082, 'RUN VPBs > 2': 285, '...   245n
# 32   {'MULTIFORM VPBs': 7413, 'PAIR VPBs': 2154, 'H...   248n
# 33   {'R-ON-T VPBs': 335, 'ABP   45 < 80': 31, 'ABP...   252n
# 34   {'R-ON-T VPBs': 370, 'MULTIFORM VPBs': 276, 'A...   253n
# 35   {'PAIR VPBs': 459, 'ABP   75 < 90': 321, '*VEN...   254n
# 37   {'PAIR VPBs': 2421, 'RUN VPBs > 2': 2139, 'R-O...   259n
# 38   {'PAIR VPBs': 574, 'R-ON-T VPBs': 293, 'RUN VP...   260n
# 40   {'VPBs >  8/MIN': 94262, 'MISSED BEATS': 10998...   264n
# 41   {'PAIR VPBs': 8237, 'MULTIFORM VPBs': 1093, 'V...   267n
# 42   {'HR 169 > 155': 287, 'PAP   46 > 40': 76, 'MI...   268n
# 43   {'PAIR VPBs': 25488, 'RUN VPBs > 2': 25332, 'V...   269n
# 44   {'VPBs >  5/MIN': 4308, 'PAIR VPBs': 3330, 'RU...   271n
# 55   {'ABP  320 > 150': 8, 'ABP   67 < 90': 3, 'ABP...   291n
# 56                              {'NBP  166 > 160': 46}   293n
# 57   {'ABP  222 > 195': 17, 'ABP  198 > 195': 15, '...   401n
# 58   {'ABP   79 < 80': 64, 'ABP   78 < 80': 28, '*A...   403n
# 61   {'IRREGULAR HR': 2290, 'MULTIFORM VPBs': 681, ...   408n
# 62   {'IRREGULAR HR': 28905, 'MULTIFORM VPBs': 9678...   409n
# 65   {'MULTIFORM VPBs': 9862, 'MISSED BEATS': 9671,...   413n
# 66   {'MULTIFORM VPBs': 18499, 'MISSED BEATS': 9796...   414n
# 67   {'MISSED BEATS': 281, 'ABP  171 > 160': 23, 'P...   415n
# 68   {'MULTIFORM VPBs': 288, 'MISSED BEATS': 106, '...   417n
# 69   {'R-ON-T VPBs': 1209, 'ABP   55 < 60': 17, 'PA...   418n
# 71   {'VPBs >  5/MIN': 2338, 'HR 111 > 110': 534, '...   427n
# 82   {'MULTIFORM VPBs': 25724, 'PAIR VPBs': 22615, ...   442n
# 87   {'ABP   84 < 85': 123, 'ABP   83 < 85': 98, 'A...   449n
# 93   {'PAIR VPBs': 3514, 'MULTIFORM VPBs': 2186, 'H...   455n
# 95   {'HR 170 > 120': 2410, 'HR 150 > 120': 908, 'H...   457n
# 98   {'VENT BIGEMINY': 1184, 'PAP  240 > 40': 510, ...   464n
# 99   {'PACER NOT CAPT': 4996, 'IRREGULAR HR': 4783,...   465n
# 100  {'IRREGULAR HR': 1627, 'PAP   53 > 50': 505, '...   466n
# 101  {'MULTIFORM VPBs': 15456, 'PAIR VPBs': 6949, '...   467n
# 103  {'IRREGULAR HR': 23790, 'VPBs >  5/MIN': 7678,...   471n
# 104  {'PAIR VPBs': 1887, 'VPBs > 11/MIN': 1818, 'MU...   472n
# 105  {'IRREGULAR HR': 2457, 'HR  64 <  65': 448, 'H...   474n
# 106  {'ST2   0.9>0.6': 776, 'ST3   0.8>0.6': 742, '...   476n
#
#                                              feat_cols
# 0    {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...
# 1    {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...
# 2    {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...
# 3    {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...
# 7    {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), RESP...
# 8    {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...
# 9    {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...
# 10   {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...
# 12   {NBPsys (mmHg), NBPdias (mmHg), ARTdias (mmHg)...
# 15   {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...
# 16   {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...
# 20   {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...
# 21   {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...
# 22   {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...
# 23   {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...
# 25   {NBPsys (mmHg), NBPdias (mmHg), HR (bpm), ABPm...
# 26   {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...
# 27   {NBPsys (mmHg), NBPdias (mmHg), ST1 (mV), ABPm...
# 28   {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...
# 29   {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...
# 30   {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...
# 31   {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...
# 32   {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...
# 33   {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...
# 34   {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...
# 35   {NBPsys (mmHg), NBPdias (mmHg), ST1 (mV), ABPm...
# 37   {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...
# 38   {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...
# 40   {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...
# 41   {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...
# 42   {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...
# 43   {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...
# 44   {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...
# 55   {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), RESP...
# 56   {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...
# 57   {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...
# 58   {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...
# 61   {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...
# 62   {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...
# 65   {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...
# 66   {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...
# 67   {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...
# 68   {NBPsys (mmHg), NBPdias (mmHg), ST1 (mV), ABPm...
# 69   {NBPsys (mmHg), NBPdias (mmHg), ARTdias (mmHg)...
# 71   {ARTdias (mmHg), ABPmean (mmHg), HR (bpm), ABP...
# 82   {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...
# 87   {ST1 (mV), ABPmean (mmHg), HR (bpm), ABPsys (m...
# 93   {ST1 (mV), ABPmean (mmHg), HR (bpm), ST3 (mV),...
# 95   {ST1 (mV), ABPmean (mmHg), HR (bpm), ST3 (mV),...
# 98   {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...
# 99   {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...
# 100  {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...
# 101  {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...
# 103  {NBPsys (mmHg), NBPdias (mmHg), ABPmean (mmHg)...
# 104  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...
# 105  {ST1 (mV), ABPmean (mmHg), HR (bpm), ST3 (mV),...
# 106  {ST1 (mV), ABPmean (mmHg), ETCO2 (mmHg), HR (b...

# %%
fields_df_shortlisted.head()
# Out:
#          fs  sig_len  n_sig   base_date base_time  \
# 0  0.976562    51138      7  1994-12-13  08:38:53
# 1  0.976562    77038      7  1995-02-22  13:08:55
# 2  0.976562   141796      7  1995-02-24  09:44:42
# 3  0.976562   131250     12  1995-03-02  15:36:24
# 7  0.976562    75991      6  1995-01-26  14:34:07
#
#                                                units  \
# 0  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 1  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 2  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 3  ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 7        ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', '%']
#
#                                             sig_name comments  \
# 0  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 1  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 2  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 3  ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 7  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'RESP',...       []
#
#                                        unique_alarms record  \
# 0  {'*ASYSTOLE': 23, '*TACHY 216 > 180': 9, '*VEN...   048n
# 1  {'ABP  184 > 180': 115, 'ABP  182 > 180': 115,...   052n
# 2  {'PAIR VPBs': 982, 'HR  53 <  55': 560, 'MULTI...   054n
# 3  {'VPBs > 5/MIN': 1661, 'PAIR VPBs': 1584, 'MUL...   055n
# 7  {'PAIR VPBs': 328, 'HR 126 > 120': 99, 'ABP  2...   211n
#
#                                            feat_cols
# 0  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...
# 1  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...
# 2  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...
# 3  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...
# 7  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), RESP...

# %% [markdown]
# ## Select Alarms to Predict

# %%
def most_common_alarms(fields_df_shortlisted):
    alarm_col = fields_df_shortlisted["unique_alarms"]
    alarm_count = {}
    num_shortlisted = len(fields_df_shortlisted)
    for i in range(num_shortlisted):
        unique_alarms_dict = eval(alarm_col.iloc[i])
        for alarm, count in unique_alarms_dict.items():
            alarm = alarm.strip()
            if alarm in alarm_count:
                alarm_count[alarm] += count
            else:
                alarm_count[alarm] = count
    alarm_series = pd.Series(alarm_count).sort_values(ascending=False).reset_index()
    alarm_series["index"] = alarm_series["index"]
    alarm_series.columns = ["alarms", "count"]
    return alarm_series

alarm_count = most_common_alarms(fields_df_shortlisted)
alarm_count.head(10)
# Out:
#            alarms   count
# 0       PAIR VPBs  165344
# 1  MULTIFORM VPBs  159343
# 2    IRREGULAR HR   96848
# 3   VPBs >  5/MIN   95106
# 4   VPBs >  8/MIN   94262
# 5    MISSED BEATS   61802
# 6    RUN VPBs > 2   47527
# 7     VENT RHYTHM   10349
# 8     *VENT TACHY   10286
# 9     R-ON-T VPBs    7655

# %%
# Show word cloud of alarms
def generate_alarm_wordcloud(alarm_count):
    text = " ".join(alarm for alarm, count in alarm_count[["alarms", "count"]].values for j in range(count))
    stopwords = set(STOPWORDS)
    wordcloud = WordCloud(
        width=1000, height=500, stopwords=stopwords, background_color="white", collocations=False, max_words=20).generate(text)
    plt.figure(figsize=(6,3))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()
generate_alarm_wordcloud(alarm_count)

# %%
# find out how many alarms with "VPB" in it
def query_alarm_count(alarm_count, keyword):
    alarm_list = []
    total_count = 0
    for alarm, count in alarm_count[["alarms", "count"]].values:
        if keyword in alarm:
            alarm_list.append(alarm)
            total_count += count 
    return alarm_count[alarm_count["alarms"].isin(alarm_list)], total_count
vpb_alarm_stats = query_alarm_count(alarm_count, keyword="VPB")
print(vpb_alarm_stats[1], "VPBs:")
display(vpb_alarm_stats[0])
# Out:
# 584358 VPBs:
#               alarms   count
# 0          PAIR VPBs  165344
# 1     MULTIFORM VPBs  159343
# 3      VPBs >  5/MIN   95106
# 4      VPBs >  8/MIN   94262
# 6       RUN VPBs > 2   47527
# 9        R-ON-T VPBs    7655
# 10      VPBs > 5/MIN    6642
# 14    RUN VPBs 3 - 9    4397
# 22     VPBs > 11/MIN    2172
# 24      RUN VPBs > 5    1900
# 749     RUN VPBs > 9       9
# 1357   VPBs > 23/MIN       1

# %%
# How many patients have vpb
def query_records_with_alarm_keyword(fields_df_shortlisted, keyword_list):
    df_list = []
    for keyword in keyword_list:
        count = 0
        record_list = []
        for record, alarm_str in fields_df_shortlisted[["record","unique_alarms"]].values:
            if keyword in alarm_str:
                count += 1
                record_list.append(record)
        df_list.append({"keyword": keyword, "count":count, "records": record_list})
    return pd.DataFrame(df_list)
vbp_record_stats = query_records_with_alarm_keyword(fields_df_shortlisted, keyword_list=["VPB"]+vpb_alarm_stats[0]["alarms"].tolist())
vbp_record_stats
# Out:
#            keyword  count                                            records
# 0              VPB     49  [048n, 054n, 055n, 211n, 212n, 213n, 214n, 216...
# 1        PAIR VPBs     39  [048n, 054n, 055n, 211n, 213n, 214n, 216n, 221...
# 2   MULTIFORM VPBs     33  [054n, 055n, 213n, 214n, 220n, 221n, 226n, 230...
# 3    VPBs >  5/MIN     26  [211n, 212n, 213n, 214n, 216n, 230n, 231n, 232...
# 4    VPBs >  8/MIN      1                                             [264n]
# 5     RUN VPBs > 2     22  [212n, 213n, 214n, 230n, 232n, 235n, 237n, 240...
# 6      R-ON-T VPBs     13  [214n, 232n, 245n, 252n, 253n, 259n, 260n, 418...
# 7     VPBs > 5/MIN      7         [055n, 226n, 408n, 409n, 442n, 457n, 472n]
# 8   RUN VPBs 3 - 9      9  [048n, 055n, 226n, 408n, 442n, 455n, 457n, 472...
# 9    VPBs > 11/MIN      3                                 [409n, 457n, 472n]
# 10    RUN VPBs > 5      1                                             [264n]
# 11    RUN VPBs > 9      2                                       [455n, 457n]
# 12   VPBs > 23/MIN      1                                             [457n]

# %%
# Shortlist patients with alarm
def shortlist_patients_with_alarm(vbp_record_stats, keyword):
    record_list = vbp_record_stats[vbp_record_stats["keyword"]==keyword]["records"][0]
    return record_list
shortlisted_records_alarm = shortlist_patients_with_alarm(vbp_record_stats, keyword="VPB")
fields_df_shortlisted_alarm = fields_df_shortlisted[fields_df_shortlisted["record"].isin(shortlisted_records_alarm)]
display(fields_df_shortlisted_alarm.head())
print(fields_df_shortlisted_alarm.shape)
# Out:
#          fs  sig_len  n_sig   base_date base_time  \
# 0  0.976562    51138      7  1994-12-13  08:38:53
# 2  0.976562   141796      7  1995-02-24  09:44:42
# 3  0.976562   131250     12  1995-03-02  15:36:24
# 7  0.976562    75991      6  1995-01-26  14:34:07
# 8  0.976562   145275     10  1995-04-04  14:00:03
#
#                                                units  \
# 0  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 2  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 3  ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 7        ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', '%']
# 8  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
#
#                                             sig_name comments  \
# 0  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 2  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 3  ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 7  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'RESP',...       []
# 8  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
#
#                                        unique_alarms record  \
# 0  {'*ASYSTOLE': 23, '*TACHY 216 > 180': 9, '*VEN...   048n
# 2  {'PAIR VPBs': 982, 'HR  53 <  55': 560, 'MULTI...   054n
# 3  {'VPBs > 5/MIN': 1661, 'PAIR VPBs': 1584, 'MUL...   055n
# 7  {'PAIR VPBs': 328, 'HR 126 > 120': 99, 'ABP  2...   211n
# 8  {'VPBs >  5/MIN': 11644, 'MISSED BEATS': 10580...   212n
#
#                                            feat_cols
# 0  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...
# 2  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PULS...
# 3  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...
# 7  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), RESP...
# 8  {ABPmean (mmHg), HR (bpm), ABPsys (mmHg), PAPd...
# (49, 11)

# %%
# 6.22 million rows in total (with nan values)
fields_df_shortlisted_alarm["sig_len"].sum()
# Out:
# 6227307

# %% [markdown]
# ## Downsample Time Series Data

# %%
def downsample_all_csvs(fp_converted_folder, feat_set, fields_df_shortlisted, window=60):
    df_list = []
    records = fields_df_shortlisted["record"].tolist()
    for record in tqdm(records):
        fp_csv = os.path.join(fp_converted_folder, record+".csv")
        df = pd.read_csv(fp_csv)
        df = downsample_ts(df, window, feat_set)
        df["record"] = record
        df_list.append(df)
    all_df = pd.concat(df_list).reset_index()
    all_df.columns = ["record_index"] + all_df.columns[1:].to_list()
    return all_df

def downsample_ts(df, window, feat_set, alarm_col="alarms"):
    df[alarm_col] = df[alarm_col].str.strip()
    feat_set = list(feat_set)
    all_feat = feat_set + [alarm_col]
    df_feat_sel = df[all_feat]
    grouped = df_feat_sel.groupby((df_feat_sel.index/window).astype('i'))
    df_downsampled = grouped[feat_set].mean()
    alarm_list = []
    for group, alarms in grouped[alarm_col]:
        list_of_alarms = [eval(al) for al in alarms[alarms.notna()]]
        alarm_set = set().union(*list_of_alarms)
        alarm_list.append(alarm_set)
    df_downsampled["alarms"] = alarm_list
    
    return df_downsampled

df_ds = downsample_all_csvs(fp_converted_folder, feat_set, fields_df_shortlisted, window=60)
df_ds
# Out:
#   2%|█▉                                                                                                           | 1/57 [00:00<00:05,  9.63it/s]C:\Users\WLR\AppData\Local\Temp\ipykernel_21188\1352365828.py:6: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv)
#   5%|█████▋                                                                                                       | 3/57 [00:00<00:12,  4.27it/s]C:\Users\WLR\AppData\Local\Temp\ipykernel_21188\1352365828.py:6: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv)
#  21%|██████████████████████▋                                                                                     | 12/57 [00:03<00:10,  4.33it/s]C:\Users\WLR\AppData\Local\Temp\ipykernel_21188\1352365828.py:6: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv)
#  23%|████████████████████████▋                                                                                   | 13/57 [00:03<00:09,  4.51it/s]C:\Users\WLR\AppData\Local\Temp\ipykernel_21188\1352365828.py:6: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv)
#  30%|████████████████████████████████▏                                                                           | 17/57 [00:05<00:16,  2.45it/s]C:\Users\WLR\AppData\Local\Temp\ipykernel_21188\1352365828.py:6: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv)
#  40%|███████████████████████████████████████████▌                                                                | 23/57 [00:07<00:13,  2.46it/s]C:\Users\WLR\AppData\Local\Temp\ipykernel_21188\1352365828.py:6: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv)
#  60%|████████████████████████████████████████████████████████████████▍                                           | 34/57 [00:12<00:08,  2.61it/s]C:\Users\WLR\AppData\Local\Temp\ipykernel_21188\1352365828.py:6: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv)
#  72%|█████████████████████████████████████████████████████████████████████████████▋                              | 41/57 [00:14<00:06,  2.40it/s]C:\Users\WLR\AppData\Local\Temp\ipykernel_21188\1352365828.py:6: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv)
#  77%|███████████████████████████████████████████████████████████████████████████████████▎                        | 44/57 [00:15<00:03,  3.33it/s]C:\Users\WLR\AppData\Local\Temp\ipykernel_21188\1352365828.py:6: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv)
#  81%|███████████████████████████████████████████████████████████████████████████████████████▏                    | 46/57 [00:16<00:04,  2.21it/s]C:\Users\WLR\AppData\Local\Temp\ipykernel_21188\1352365828.py:6: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv)
#  82%|█████████████████████████████████████████████████████████████████████████████████████████                   | 47/57 [00:17<00:04,  2.33it/s]C:\Users\WLR\AppData\Local\Temp\ipykernel_21188\1352365828.py:6: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv)
#  88%|██████████████████████████████████████████████████████████████████████████████████████████████▋             | 50/57 [00:18<00:02,  2.40it/s]C:\Users\WLR\AppData\Local\Temp\ipykernel_21188\1352365828.py:6: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv)
#  96%|████████████████████████████████████████████████████████████████████████████████████████████████████████▏   | 55/57 [00:21<00:00,  2.16it/s]C:\Users\WLR\AppData\Local\Temp\ipykernel_21188\1352365828.py:6: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv)
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 57/57 [00:21<00:00,  2.60it/s]
#         record_index  ABPmean (mmHg)   HR (bpm)  ABPsys (mmHg)  RESP (bpm)  \
# 0                  0       84.800000  63.850000     120.483333         0.0
# 1                  1       86.033333  83.416667     127.183333         0.0
# 2                  2       83.350000  82.466667     125.050000         0.0
# 3                  3       88.850000  83.950000     131.766667         0.0
# 4                  4      109.400000  87.183333     156.550000         0.0
# ...              ...             ...        ...            ...         ...
# 120149          1031             NaN  91.900000            NaN         NaN
# 120150          1032             NaN  81.150000            NaN         NaN
# 120151          1033             NaN  96.366667            NaN         NaN
# 120152          1034             NaN  94.850000            NaN         NaN
# 120153          1035             NaN   0.000000            NaN         NaN
#
#          SpO2 (%)  ABPdias (mmHg)          alarms record
# 0       96.300000       67.416667              {}   048n
# 1       93.600000       63.300000              {}   048n
# 2       93.366667       59.100000              {}   048n
# 3       93.150000       63.833333              {}   048n
# 4       82.400000       86.066667              {}   048n
# ...           ...             ...             ...    ...
# 120149  96.716667             NaN              {}   476n
# 120150  97.100000             NaN  {IRREGULAR HR}   476n
# 120151  96.650000             NaN  {IRREGULAR HR}   476n
# 120152  96.716667             NaN  {IRREGULAR HR}   476n
# 120153  96.000000             NaN              {}   476n
#
# [120154 rows x 9 columns]

# %%
df_ds["alarms"].value_counts()
# Out:
# alarms
# {}                                                              101973
# {PAIR VPBs}                                                       2810
# {MULTIFORM VPBs}                                                  2724
# {IRREGULAR HR}                                                    1659
# {VPBs >  5/MIN}                                                   1605
#                                                                  ...
# {VPBs >  8/MIN, ABP   81 < 90}                                       1
# {ABP   81 < 90, ABP   84 < 90, VPBs >  8/MIN, ABP   82 < 90}         1
# {ABP   78 < 90, ABP   76 < 90, VPBs >  8/MIN, MISSED BEATS}          1
# {ABP   48 < 90, MISSED BEATS}                                        1
# {HR 126 > 120, HR 123 > 120, HR 132 > 120}                           1
# Name: count, Length: 2059, dtype: int64

# %%
def label_rows(df_ds, keyword):
    return [(keyword in str(al)) for al in df_ds["alarms"]]
df_ds["VPBs"] = label_rows(df_ds, keyword="VPBs")
df_ds
# Out:
#         record_index  ABPmean (mmHg)   HR (bpm)  ABPsys (mmHg)  RESP (bpm)  \
# 0                  0       84.800000  63.850000     120.483333         0.0
# 1                  1       86.033333  83.416667     127.183333         0.0
# 2                  2       83.350000  82.466667     125.050000         0.0
# 3                  3       88.850000  83.950000     131.766667         0.0
# 4                  4      109.400000  87.183333     156.550000         0.0
# ...              ...             ...        ...            ...         ...
# 120149          1031             NaN  91.900000            NaN         NaN
# 120150          1032             NaN  81.150000            NaN         NaN
# 120151          1033             NaN  96.366667            NaN         NaN
# 120152          1034             NaN  94.850000            NaN         NaN
# 120153          1035             NaN   0.000000            NaN         NaN
#
#          SpO2 (%)  ABPdias (mmHg)          alarms record   VPBs
# 0       96.300000       67.416667              {}   048n  False
# 1       93.600000       63.300000              {}   048n  False
# 2       93.366667       59.100000              {}   048n  False
# 3       93.150000       63.833333              {}   048n  False
# 4       82.400000       86.066667              {}   048n  False
# ...           ...             ...             ...    ...    ...
# 120149  96.716667             NaN              {}   476n  False
# 120150  97.100000             NaN  {IRREGULAR HR}   476n  False
# 120151  96.650000             NaN  {IRREGULAR HR}   476n  False
# 120152  96.716667             NaN  {IRREGULAR HR}   476n  False
# 120153  96.000000             NaN              {}   476n  False
#
# [120154 rows x 10 columns]

# %%
df_ds["VPBs"].value_counts()
# Out:
# VPBs
# False    109010
# True      11144
# Name: count, dtype: int64

# %%
def label_true_negative(df_ds):
    return [len(al) == 0 for al in df_ds["alarms"]]
# label rows with no alarms at all
df_ds["no_alarms"] = label_true_negative(df_ds)
df_ds
# Out:
#         record_index  ABPmean (mmHg)   HR (bpm)  ABPsys (mmHg)  RESP (bpm)  \
# 0                  0       84.800000  63.850000     120.483333         0.0
# 1                  1       86.033333  83.416667     127.183333         0.0
# 2                  2       83.350000  82.466667     125.050000         0.0
# 3                  3       88.850000  83.950000     131.766667         0.0
# 4                  4      109.400000  87.183333     156.550000         0.0
# ...              ...             ...        ...            ...         ...
# 120149          1031             NaN  91.900000            NaN         NaN
# 120150          1032             NaN  81.150000            NaN         NaN
# 120151          1033             NaN  96.366667            NaN         NaN
# 120152          1034             NaN  94.850000            NaN         NaN
# 120153          1035             NaN   0.000000            NaN         NaN
#
#          SpO2 (%)  ABPdias (mmHg)          alarms record   VPBs  no_alarms
# 0       96.300000       67.416667              {}   048n  False       True
# 1       93.600000       63.300000              {}   048n  False       True
# 2       93.366667       59.100000              {}   048n  False       True
# 3       93.150000       63.833333              {}   048n  False       True
# 4       82.400000       86.066667              {}   048n  False       True
# ...           ...             ...             ...    ...    ...        ...
# 120149  96.716667             NaN              {}   476n  False       True
# 120150  97.100000             NaN  {IRREGULAR HR}   476n  False      False
# 120151  96.650000             NaN  {IRREGULAR HR}   476n  False      False
# 120152  96.716667             NaN  {IRREGULAR HR}   476n  False      False
# 120153  96.000000             NaN              {}   476n  False       True
#
# [120154 rows x 11 columns]

# %%
df_ds["no_alarms"].value_counts()
# Out:
# no_alarms
# True     101973
# False     18181
# Name: count, dtype: int64

# %%
if not os.path.exists(fp_downsampled_folder):
    os.makedirs(fp_downsampled_folder)
df_ds.to_csv(fp_downsampled_continuous_file)

# %%
df_ds = pd.read_csv(fp_downsampled_continuous_file, index_col=0)
df_ds
# Out:
#         record_index  ABPmean (mmHg)   HR (bpm)  ABPsys (mmHg)  RESP (bpm)  \
# 0                  0       84.800000  63.850000     120.483333         0.0
# 1                  1       86.033333  83.416667     127.183333         0.0
# 2                  2       83.350000  82.466667     125.050000         0.0
# 3                  3       88.850000  83.950000     131.766667         0.0
# 4                  4      109.400000  87.183333     156.550000         0.0
# ...              ...             ...        ...            ...         ...
# 120149          1031             NaN  91.900000            NaN         NaN
# 120150          1032             NaN  81.150000            NaN         NaN
# 120151          1033             NaN  96.366667            NaN         NaN
# 120152          1034             NaN  94.850000            NaN         NaN
# 120153          1035             NaN   0.000000            NaN         NaN
#
#          SpO2 (%)  ABPdias (mmHg)            alarms record   VPBs  no_alarms
# 0       96.300000       67.416667             set()   048n  False       True
# 1       93.600000       63.300000             set()   048n  False       True
# 2       93.366667       59.100000             set()   048n  False       True
# 3       93.150000       63.833333             set()   048n  False       True
# 4       82.400000       86.066667             set()   048n  False       True
# ...           ...             ...               ...    ...    ...        ...
# 120149  96.716667             NaN             set()   476n  False       True
# 120150  97.100000             NaN  {'IRREGULAR HR'}   476n  False      False
# 120151  96.650000             NaN  {'IRREGULAR HR'}   476n  False      False
# 120152  96.716667             NaN  {'IRREGULAR HR'}   476n  False      False
# 120153  96.000000             NaN             set()   476n  False       True
#
# [120154 rows x 11 columns]

# %%
df_ds.iloc[139-9:139+10]
# Out:
#      record_index  ABPmean (mmHg)    HR (bpm)  ABPsys (mmHg)  RESP (bpm)  \
# 130           130             NaN   77.483333            NaN   22.366667
# 131           131             NaN   81.866667            NaN   21.066667
# 132           132             NaN   81.466667            NaN   20.333333
# 133           133             NaN   79.733333            NaN   18.366667
# 134           134             NaN   79.716667            NaN   11.700000
# 135           135             NaN   79.850000            NaN   13.516667
# 136           136             NaN   78.833333            NaN   22.533333
# 137           137             NaN   78.400000            NaN   21.800000
# 138           138             NaN   78.633333            NaN   12.983333
# 139           139             NaN  138.883333            NaN   13.833333
# 140           140             NaN   77.166667            NaN   21.800000
# 141           141             NaN   76.216667            NaN   22.583333
# 142           142             NaN   78.316667            NaN   21.200000
# 143           143             NaN   81.233333            NaN   17.833333
# 144           144             NaN   80.650000            NaN   14.116667
# 145           145             NaN   81.183333            NaN   12.800000
# 146           146             NaN   81.416667            NaN   12.966667
# 147           147             NaN   83.650000            NaN   19.700000
# 148           148             NaN   81.916667            NaN   10.150000
#
#        SpO2 (%)  ABPdias (mmHg)  \
# 130   97.400000             NaN
# 131   98.300000             NaN
# 132   99.000000             NaN
# 133   98.900000             NaN
# 134   99.966667             NaN
# 135   99.383333             NaN
# 136  100.000000             NaN
# 137   99.850000             NaN
# 138  100.000000             NaN
# 139  100.000000             NaN
# 140  100.000000             NaN
# 141   98.816667             NaN
# 142   97.350000             NaN
# 143   98.933333             NaN
# 144   98.050000             NaN
# 145   98.566667             NaN
# 146   98.566667             NaN
# 147   98.466667             NaN
# 148   97.750000             NaN
#
#                                                 alarms record   VPBs  \
# 130                                              set()   048n  False
# 131                                              set()   048n  False
# 132                                              set()   048n  False
# 133                                              set()   048n  False
# 134                                              set()   048n  False
# 135                                              set()   048n  False
# 136                                              set()   048n  False
# 137                                              set()   048n  False
# 138                                              set()   048n  False
# 139  {'*TACHY 215 > 180', '*TACHY 216 > 180', 'PAIR...   048n   True
# 140                                              set()   048n  False
# 141                                              set()   048n  False
# 142                                              set()   048n  False
# 143                                              set()   048n  False
# 144                                              set()   048n  False
# 145                                              set()   048n  False
# 146                                              set()   048n  False
# 147                                              set()   048n  False
# 148                                              set()   048n  False
#
#      no_alarms
# 130       True
# 131       True
# 132       True
# 133       True
# 134       True
# 135       True
# 136       True
# 137       True
# 138       True
# 139      False
# 140       True
# 141       True
# 142       True
# 143       True
# 144       True
# 145       True
# 146       True
# 147       True
# 148       True

# %% [markdown]
# ## Generate Training/Validation Data

# %%
feat_set = df_ds.columns.tolist()[1:7]
feat_set.sort()
print("Features:", feat_set)
# Out:
# Features: ['ABPdias (mmHg)', 'ABPmean (mmHg)', 'ABPsys (mmHg)', 'HR (bpm)', 'RESP (bpm)', 'SpO2 (%)']

# %%
def generate_all_possible_pos_neg_data(df_ds, feat_set, input_days, prediction_day, pred_col):
    # The flattened features for past input_days
    new_feat_set = [feat + " " + str(i) for i in range(input_days) for feat in feat_set] + ["target"] + ["target_index"]
    data = []
    record_groups = df_ds.groupby("record")
    first_pos_index = input_days + prediction_day - 1
    for record, df in tqdm(record_groups):
        for pred_index in range(first_pos_index, len(df)):
            pred_row = df.iloc[pred_index]
            # if this is not positive and not negative case
            if (not pred_row[pred_col]) and (not pred_row["no_alarms"]):
                continue
            # else, add to data set
            start_input, end_input = pred_index - prediction_day - input_days + 1, pred_index - prediction_day
            new_row = list(df[feat_set].iloc[start_input:end_input+1].values.flatten()) + [pred_row[pred_col],pred_row.name]
            data.append(new_row)
    return pd.DataFrame(data, columns=new_feat_set)

pos_neg = generate_all_possible_pos_neg_data(df_ds, feat_set, input_days=5, prediction_day=5, pred_col="VPBs")      
pos_neg
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 57/57 [00:35<00:00,  1.59it/s]
#         ABPdias (mmHg) 0  ABPmean (mmHg) 0  ABPsys (mmHg) 0  HR (bpm) 0  \
# 0              67.416667         84.800000       120.483333   63.850000
# 1              63.300000         86.033333       127.183333   83.416667
# 2              59.100000         83.350000       125.050000   82.466667
# 3              63.833333         88.850000       131.766667   83.950000
# 4              86.066667        109.400000       156.550000   87.183333
# ...                  ...               ...              ...         ...
# 112637               NaN               NaN              NaN   89.050000
# 112638               NaN               NaN              NaN   91.116667
# 112639               NaN               NaN              NaN  108.066667
# 112640               NaN               NaN              NaN  108.950000
# 112641               NaN               NaN              NaN   94.133333
#
#         RESP (bpm) 0  SpO2 (%) 0  ABPdias (mmHg) 1  ABPmean (mmHg) 1  \
# 0                0.0   96.300000         63.300000         86.033333
# 1                0.0   93.600000         59.100000         83.350000
# 2                0.0   93.366667         63.833333         88.850000
# 3                0.0   93.150000         86.066667        109.400000
# 4                0.0   82.400000         85.716667        108.866667
# ...              ...         ...               ...               ...
# 112637           NaN   95.850000               NaN               NaN
# 112638           NaN   95.766667               NaN               NaN
# 112639           NaN   95.733333               NaN               NaN
# 112640           NaN   95.800000               NaN               NaN
# 112641           NaN   95.766667               NaN               NaN
#
#         ABPsys (mmHg) 1  HR (bpm) 1  ...  RESP (bpm) 3  SpO2 (%) 3  \
# 0            127.183333   83.416667  ...           0.0   93.150000
# 1            125.050000   82.466667  ...           0.0   82.400000
# 2            131.766667   83.950000  ...           0.0   96.750000
# 3            156.550000   87.183333  ...           0.0   97.283333
# 4            158.133333   86.583333  ...           0.0   95.200000
# ...                 ...         ...  ...           ...         ...
# 112637              NaN   89.466667  ...           NaN   96.350000
# 112638              NaN  108.066667  ...           NaN   96.483333
# 112639              NaN  108.950000  ...           NaN   96.200000
# 112640              NaN   87.533333  ...           NaN   96.000000
# 112641              NaN   91.700000  ...           NaN   96.316667
#
#         ABPdias (mmHg) 4  ABPmean (mmHg) 4  ABPsys (mmHg) 4  HR (bpm) 4  \
# 0              86.066667        109.400000       156.550000   87.183333
# 1              85.716667        108.866667       158.133333   86.583333
# 2              88.466667        112.650000       160.550000   86.250000
# 3             103.750000        128.666667       181.050000   93.166667
# 4             101.116667        123.700000       174.750000   92.183333
# ...                  ...               ...              ...         ...
# 112637               NaN               NaN              NaN   88.833333
# 112638               NaN               NaN              NaN   92.333333
# 112639               NaN               NaN              NaN   92.733333
# 112640               NaN               NaN              NaN   94.133333
# 112641               NaN               NaN              NaN   91.733333
#
#         RESP (bpm) 4  SpO2 (%) 4  target  target_index
# 0                0.0   82.400000   False             9
# 1                0.0   96.750000   False            10
# 2                0.0   97.283333   False            11
# 3                0.0   95.200000   False            12
# 4                0.0   90.616667   False            13
# ...              ...         ...     ...           ...
# 112637           NaN   96.083333   False        120138
# 112638           NaN   96.200000   False        120147
# 112639           NaN   96.000000   False        120148
# 112640           NaN   95.766667   False        120149
# 112641           NaN   97.000000   False        120153
#
# [112642 rows x 32 columns]

# %%
pos_neg[pos_neg["target_index"]==139]
# Out:
#      ABPdias (mmHg) 0  ABPmean (mmHg) 0  ABPsys (mmHg) 0  HR (bpm) 0  \
# 130               NaN               NaN              NaN   77.483333
#
#      RESP (bpm) 0  SpO2 (%) 0  ABPdias (mmHg) 1  ABPmean (mmHg) 1  \
# 130     22.366667        97.4               NaN               NaN
#
#      ABPsys (mmHg) 1  HR (bpm) 1  ...  RESP (bpm) 3  SpO2 (%) 3  \
# 130              NaN   81.866667  ...     18.366667        98.9
#
#      ABPdias (mmHg) 4  ABPmean (mmHg) 4  ABPsys (mmHg) 4  HR (bpm) 4  \
# 130               NaN               NaN              NaN   79.716667
#
#      RESP (bpm) 4  SpO2 (%) 4  target  target_index
# 130          11.7   99.966667    True           139
#
# [1 rows x 32 columns]

# %%
pos_neg["target"].value_counts()
# Out:
# target
# False    101523
# True      11119
# Name: count, dtype: int64

# %%
pos_neg_dropna = pos_neg.dropna()
pos_neg_dropna["target"].value_counts()
# Out:
# target
# False    79664
# True      9034
# Name: count, dtype: int64

# %%
pos_neg_dropna
# Out:
#         ABPdias (mmHg) 0  ABPmean (mmHg) 0  ABPsys (mmHg) 0  HR (bpm) 0  \
# 0              67.416667         84.800000       120.483333   63.850000
# 1              63.300000         86.033333       127.183333   83.416667
# 2              59.100000         83.350000       125.050000   82.466667
# 3              63.833333         88.850000       131.766667   83.950000
# 4              86.066667        109.400000       156.550000   87.183333
# ...                  ...               ...              ...         ...
# 112560         51.000000         76.000000       131.733333   91.683333
# 112561         50.050000         74.100000       126.983333   90.133333
# 112562         50.833333         75.383333       131.400000   91.500000
# 112563         50.200000         73.883333       128.050000   90.466667
# 112564         49.583333         74.633333       130.533333   90.933333
#
#         RESP (bpm) 0  SpO2 (%) 0  ABPdias (mmHg) 1  ABPmean (mmHg) 1  \
# 0           0.000000   96.300000         63.300000         86.033333
# 1           0.000000   93.600000         59.100000         83.350000
# 2           0.000000   93.366667         63.833333         88.850000
# 3           0.000000   93.150000         86.066667        109.400000
# 4           0.000000   82.400000         85.716667        108.866667
# ...              ...         ...               ...               ...
# 112560     21.733333   96.766667         50.050000         74.100000
# 112561     21.766667   96.166667         50.833333         75.383333
# 112562     20.966667   96.350000         50.200000         73.883333
# 112563     18.866667   96.333333         49.583333         74.633333
# 112564     19.600000   96.000000         47.583333         73.350000
#
#         ABPsys (mmHg) 1  HR (bpm) 1  ...  RESP (bpm) 3  SpO2 (%) 3  \
# 0            127.183333   83.416667  ...      0.000000   93.150000
# 1            125.050000   82.466667  ...      0.000000   82.400000
# 2            131.766667   83.950000  ...      0.000000   96.750000
# 3            156.550000   87.183333  ...      0.000000   97.283333
# 4            158.133333   86.583333  ...      0.000000   95.200000
# ...                 ...         ...  ...           ...         ...
# 112560       126.983333   90.133333  ...     18.866667   96.333333
# 112561       131.400000   91.500000  ...     19.600000   96.000000
# 112562       128.050000   90.466667  ...     20.416667   96.733333
# 112563       130.533333   90.933333  ...     23.033333   97.000000
# 112564       132.166667   91.850000  ...     23.616667   97.116667
#
#         ABPdias (mmHg) 4  ABPmean (mmHg) 4  ABPsys (mmHg) 4  HR (bpm) 4  \
# 0              86.066667        109.400000       156.550000   87.183333
# 1              85.716667        108.866667       158.133333   86.583333
# 2              88.466667        112.650000       160.550000   86.250000
# 3             103.750000        128.666667       181.050000   93.166667
# 4             101.116667        123.700000       174.750000   92.183333
# ...                  ...               ...              ...         ...
# 112560         49.583333         74.633333       130.533333   90.933333
# 112561         47.583333         73.350000       132.166667   91.850000
# 112562         47.750000         73.750000       130.850000   92.300000
# 112563         49.066667         76.933333       139.483333   92.533333
# 112564         52.383333         81.600000       143.050000   94.433333
#
#         RESP (bpm) 4  SpO2 (%) 4  target  target_index
# 0           0.000000   82.400000   False             9
# 1           0.000000   96.750000   False            10
# 2           0.000000   97.283333   False            11
# 3           0.000000   95.200000   False            12
# 4           0.000000   90.616667   False            13
# ...              ...         ...     ...           ...
# 112560     19.600000   96.000000   False        120058
# 112561     20.416667   96.733333   False        120059
# 112562     23.033333   97.000000   False        120060
# 112563     23.616667   97.116667   False        120061
# 112564     21.795455   96.983333   False        120062
#
# [88698 rows x 32 columns]

# %%
pos_neg_dropna.to_csv(fp_downsampled_dropna_file)
