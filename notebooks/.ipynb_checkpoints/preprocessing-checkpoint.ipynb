# %% [markdown]
# # Data Preprocessing

# %%
# Important libraries
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
import csv
from wordcloud import WordCloud
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt

# File paths
fp_notebooks_folder = "./"
fp_code_folder = "../"
fp_processed_folder = os.path.join(fp_code_folder, "../processed_data")
fp_converted_folder = os.path.join(fp_processed_folder, "converted_to_csv")
fp_downsampled_folder = os.path.join(fp_processed_folder, "downsampled")
fp_downsampled_concatenated_file = os.path.join(fp_downsampled_folder, "concatenated.csv")
fp_downsampled_continuous_file = os.path.join(fp_downsampled_folder, "continous.csv")
fp_downsampled_continuous_ae_file = os.path.join(fp_downsampled_folder, "continous_ae.csv")
fp_downsampled_dropna_file = os.path.join(fp_downsampled_folder, "dropna.csv")
fp_downsampled_scaler_file = os.path.join(fp_downsampled_folder, "scaler.pkl")
fp_fields_file = os.path.join(fp_converted_folder, "fields.csv")

# %%
# Get fields file to analyse
fields_df = pd.read_csv(fp_fields_file, quoting=csv.QUOTE_NONE, escapechar='/', index_col=0)
fields_df
# Out:
#            fs  sig_len  n_sig   base_date base_time  \
# 0    0.976562    51138      7  1994-12-13  08:38:53
# 1    0.976562    77038      7  1995-02-22  13:08:55
# 2    0.976562   141796      7  1995-02-24  09:44:42
# 3    0.976562   131250     12  1995-03-02  15:36:24
# 4    0.976562     4606      5  1995-01-24  08:22:11
# ..        ...      ...    ...         ...       ...
# 111  0.976562   151176     14  1996-04-06  15:26:26
# 112  0.976562   147656     15  1996-04-22  17:35:49
# 113  0.976562   154687     12  1996-04-29  14:48:52
# 114  0.976562   193946     18  1996-05-02  11:54:49
# 115  0.976562   178121      4  1996-06-23  15:01:25
#
#                                                  units  \
# 0    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 1    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 2    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 3    ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 4                 ['mmHg', 'mmHg', 'mmHg', 'bpm', '%']
# ..                                                 ...
# 111  ['mmHg', 'mmHg', 'mmHg', 'lpm', 'mmHg', 'bpm',...
# 112  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'lpm', 'mmHg',...
# 113  ['mmHg', 'mmHg', 'mmHg', 'lpm', 'mmHg', 'bpm',...
# 114  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'lpm', 'mmHg',...
# 115                        ['lpm', 'bpm', '%', 'degC']
#
#                                               sig_name comments  \
# 0    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 1    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 2    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 3    ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 4     ['NBPmean', 'NBPsys', 'NBPdias', 'RESP', 'SpO2']       []
# ..                                                 ...      ...
# 111  ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'CVP'...       []
# 112  ['ABPmean', 'ABPsys', 'ABPdias', 'AWRR', 'C.O....       []
# 113  ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'CVP'...       []
# 114  ['ABPmean', 'ABPsys', 'ABPdias', 'AWRR', 'C.O....       []
# 115                 ['C.O.', 'RESP', 'SpO2', 'Tblood']       []
#
#                                          unique_alarms record
# 0    {'*ASYSTOLE': 23, '*TACHY 216 > 180': 9, '*VEN...   048n
# 1    {'ABP  184 > 180': 115, 'ABP  182 > 180': 115,...   052n
# 2    {'PAIR VPBs': 982, 'HR  53 <  55': 560, 'MULTI...   054n
# 3    {'VPBs > 5/MIN': 1661, 'PAIR VPBs': 1584, 'MUL...   055n
# 4                             {'MULTIFORM VPBs': 4600}   208n
# ..                                                 ...    ...
# 111  {'VPBs > 5/MIN': 20341, 'VPBs > 11/MIN': 1085,...   482n
# 112  {'IRREGULAR HR': 19031, 'MULTIFORM VPBs': 1982...   484n
# 113  {'PAIR VPBs': 731, 'VPBs > 11/MIN': 567, 'IRRE...   485n
# 114  {'PAIR VPBs': 4158, 'RUN VPBs 3 - 9': 1688, 'M...   486n
# 115  {'ABP   80 < 85': 234, 'RUN VPBs 3 - 9': 199, ...   488n
#
# [116 rows x 10 columns]

# %%
def add_feat_names(fields_df):
    feat_names = []
    for i in range(len(fields_df)):
        row = fields_df.iloc[i]
        units_list, sig_list = eval(row["units"]), eval(row["sig_name"])
        cur_feat_names = {sig_list[j] + " (" + units_list[j] + ")" for j in range(len(units_list))}
        feat_names.append(cur_feat_names)
    return feat_names

fields_df["feat_cols"] = add_feat_names(fields_df)
fields_df
# Out:
#            fs  sig_len  n_sig   base_date base_time  \
# 0    0.976562    51138      7  1994-12-13  08:38:53
# 1    0.976562    77038      7  1995-02-22  13:08:55
# 2    0.976562   141796      7  1995-02-24  09:44:42
# 3    0.976562   131250     12  1995-03-02  15:36:24
# 4    0.976562     4606      5  1995-01-24  08:22:11
# ..        ...      ...    ...         ...       ...
# 111  0.976562   151176     14  1996-04-06  15:26:26
# 112  0.976562   147656     15  1996-04-22  17:35:49
# 113  0.976562   154687     12  1996-04-29  14:48:52
# 114  0.976562   193946     18  1996-05-02  11:54:49
# 115  0.976562   178121      4  1996-06-23  15:01:25
#
#                                                  units  \
# 0    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 1    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 2    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 3    ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 4                 ['mmHg', 'mmHg', 'mmHg', 'bpm', '%']
# ..                                                 ...
# 111  ['mmHg', 'mmHg', 'mmHg', 'lpm', 'mmHg', 'bpm',...
# 112  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'lpm', 'mmHg',...
# 113  ['mmHg', 'mmHg', 'mmHg', 'lpm', 'mmHg', 'bpm',...
# 114  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'lpm', 'mmHg',...
# 115                        ['lpm', 'bpm', '%', 'degC']
#
#                                               sig_name comments  \
# 0    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 1    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 2    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 3    ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 4     ['NBPmean', 'NBPsys', 'NBPdias', 'RESP', 'SpO2']       []
# ..                                                 ...      ...
# 111  ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'CVP'...       []
# 112  ['ABPmean', 'ABPsys', 'ABPdias', 'AWRR', 'C.O....       []
# 113  ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'CVP'...       []
# 114  ['ABPmean', 'ABPsys', 'ABPdias', 'AWRR', 'C.O....       []
# 115                 ['C.O.', 'RESP', 'SpO2', 'Tblood']       []
#
#                                          unique_alarms record  \
# 0    {'*ASYSTOLE': 23, '*TACHY 216 > 180': 9, '*VEN...   048n
# 1    {'ABP  184 > 180': 115, 'ABP  182 > 180': 115,...   052n
# 2    {'PAIR VPBs': 982, 'HR  53 <  55': 560, 'MULTI...   054n
# 3    {'VPBs > 5/MIN': 1661, 'PAIR VPBs': 1584, 'MUL...   055n
# 4                             {'MULTIFORM VPBs': 4600}   208n
# ..                                                 ...    ...
# 111  {'VPBs > 5/MIN': 20341, 'VPBs > 11/MIN': 1085,...   482n
# 112  {'IRREGULAR HR': 19031, 'MULTIFORM VPBs': 1982...   484n
# 113  {'PAIR VPBs': 731, 'VPBs > 11/MIN': 567, 'IRRE...   485n
# 114  {'PAIR VPBs': 4158, 'RUN VPBs 3 - 9': 1688, 'M...   486n
# 115  {'ABP   80 < 85': 234, 'RUN VPBs 3 - 9': 199, ...   488n
#
#                                              feat_cols
# 0    {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 1    {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 2    {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 3    {PULSE (bpm), C.O. (lpm), HR (bpm), PAPdias (m...
# 4    {NBPdias (mmHg), NBPsys (mmHg), RESP (bpm), NB...
# ..                                                 ...
# 111  {C.O. (lpm), CVP (mmHg), HR (bpm), PAPdias (mm...
# 112  {C.O. (lpm), LAP (mmHg), CVP (mmHg), HR (bpm),...
# 113  {C.O. (lpm), CVP (mmHg), HR (bpm), PAPdias (mm...
# 114  {C.O. (lpm), CVP (mmHg), HR (bpm), PAPdias (mm...
# 115  {C.O. (lpm), SpO2 (%), Tblood (degC), RESP (bpm)}
#
# [116 rows x 11 columns]

# %% [markdown]
# ## Select Feature Set

# %%
# Check what are the most common subset of features
def most_comment_subset_of_features(fields_df):
    feat_set_series = fields_df["feat_cols"]
    feat_set_counts = feat_set_series.value_counts().reset_index()
    feat_set_counts.columns = ["feat_set", "count"]
    feat_set_counts["num_features"] = [len(feat_set) for feat_set in feat_set_counts["feat_set"]]
    feat_set_counts = feat_set_counts.sort_values("num_features", ascending=True)
    num_unique_feat_sets = len(feat_set_counts)
    
    feat_set_inc_list = []
    for i in range(num_unique_feat_sets):
        total_count = 0
        potential_subset = feat_set_counts["feat_set"].iloc[i]
        for j in range(i,num_unique_feat_sets):
            potential_superset, count = feat_set_counts[["feat_set","count"]].iloc[j].values
            if potential_subset.issubset(potential_superset):
                total_count += count
        feat_set_inc_list.append({"feat_set": potential_subset, "inc_count": total_count})
    
    feat_set_inc_df = pd.DataFrame(feat_set_inc_list)
    
    return feat_set_counts, feat_set_inc_df.sort_values("inc_count", ascending=False)
feat_set_stats = most_comment_subset_of_features(fields_df)
display(feat_set_stats[0])
display(feat_set_stats[1])
# Out:
#                                              feat_set  count  num_features
# 39                                       {RESP (bpm)}      1             1
# 1                              {SpO2 (%), RESP (bpm)}     12             2
# 35              {C.O. (lpm), SpO2 (%), Tblood (degC)}      1             3
# 4   {C.O. (lpm), SpO2 (%), Tblood (degC), RESP (bpm)}      6             4
# 32  {IMCO2 (mmHg), RESP (bpm), ETCO2 (mmHg), AWRR ...      1             5
# 5   {NBPdias (mmHg), NBPsys (mmHg), RESP (bpm), NB...      4             5
# 10  {C.O. (lpm), Tblood (degC), RESP (bpm), PAWP (...      2             5
# 16  {HR (bpm), RESP (bpm), ABPmean (mmHg), SpO2 (%...      2             6
# 40  {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...      1             6
# 14  {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...      2             7
# 37  {C.O. (lpm), NBPdias (mmHg), NBPsys (mmHg), Tb...      1             7
# 0   {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...     15             7
# 20  {UAPmean (mmHg), C.O. (lpm), UAPsys (mmHg), Tb...      1             7
# 15  {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...      2             9
# 19  {PULSE (bpm), HR (bpm), ST2 (mV), RESP (bpm), ...      1             9
# 44  {PULSE (bpm), ARTdias (mmHg), HR (bpm), PAPdia...      1             9
# 45  {PULSE (bpm), HR (bpm), PAPdias (mmHg), PAPsys...      1             9
# 29  {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...      1            10
# 46  {HR (bpm), PAPdias (mmHg), RESP (bpm), PAWP (m...      1            10
# 6   {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...      4            10
# 3   {PULSE (bpm), HR (bpm), PAPdias (mmHg), RESP (...      7            10
# 48  {CVP (mmHg), HR (bpm), ST2 (mV), ST1 (mV), ST3...      1            11
# 41  {PULSE (bpm), NBPdias (mmHg), CVP (mmHg), HR (...      1            11
# 31  {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...      1            12
# 52  {C.O. (lpm), CVP (mmHg), HR (bpm), PAPdias (mm...      1            12
# 12  {PULSE (bpm), C.O. (lpm), HR (bpm), PAPdias (m...      2            12
# 38  {PULSE (bpm), NBPdias (mmHg), ARTdias (mmHg), ...      1            13
# 2   {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...      9            13
# 23  {PULSE (bpm), C.O. (lpm), CVP (mmHg), HR (bpm)...      1            13
# 33  {PULSE (bpm), C.O. (lpm), HR (bpm), PAPdias (m...      1            13
# 13  {NBPdias (mmHg), HR (bpm), NBPsys (mmHg), PAPd...      2            13
# 50  {PULSE (bpm), ART1dias (mmHg), ARTmean (mmHg),...      1            14
# 9   {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...      2            14
# 42  {NBPdias (mmHg), HR (bpm), NBPsys (mmHg), PAPd...      1            14
# 22  {C.O. (lpm), CVP (mmHg), HR (bpm), PAPdias (mm...      1            14
# 26  {C.O. (lpm), CVP (mmHg), HR (bpm), PAPdias (mm...      1            15
# 21  {C.O. (lpm), LAP (mmHg), CVP (mmHg), HR (bpm),...      1            15
# 36  {P4mean (mmHg), PULSE (bpm), ARTdias (mmHg), H...      1            16
# 51  {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...      1            16
# 27  {C.O. (lpm), LAP (mmHg), CVP (mmHg), ARTdias (...      1            16
# 8   {PULSE (bpm), C.O. (lpm), CVP (mmHg), HR (bpm)...      3            16
# 28  {C.O. (lpm), CVP (mmHg), HR (bpm), PAPdias (mm...      1            16
# 17  {PULSE (bpm), NBPdias (mmHg), ARTdias (mmHg), ...      2            16
# 11  {C.O. (lpm), LAP (mmHg), CVP (mmHg), HR (bpm),...      2            16
# 43  {C.O. (lpm), NBPdias (mmHg), HR (bpm), NBPsys ...      1            17
# 18  {PULSE (bpm), C.O. (lpm), LAP (mmHg), CVP (mmH...      1            17
# 7   {C.O. (lpm), CVP (mmHg), HR (bpm), PAPdias (mm...      3            18
# 25  {C.O. (lpm), CVP (mmHg), HR (bpm), PAPdias (mm...      1            18
# 30  {C.O. (lpm), PAWP (mmHg), PAPmean (mmHg), AWRR...      1            19
# 34  {C.O. (lpm), PAWP (mmHg), PAPmean (mmHg), AWRR...      1            19
# 47  {NBPdias (mmHg), NBPmean (mmHg), C.O. (lpm), P...      1            19
# 24  {C.O. (lpm), PAWP (mmHg), PAPmean (mmHg), AWRR...      1            20
# 49  {ARTsys (mmHg), C.O. (lpm), PAWP (mmHg), PAPme...      1            22
#                                              feat_set  inc_count
# 0                                        {RESP (bpm)}         90
# 1                              {SpO2 (%), RESP (bpm)}         88
# 7   {HR (bpm), RESP (bpm), ABPmean (mmHg), SpO2 (%...         57
# 11  {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...         48
# 2               {C.O. (lpm), SpO2 (%), Tblood (degC)}         37
# 16  {PULSE (bpm), HR (bpm), PAPdias (mmHg), PAPsys...         35
# 5   {NBPdias (mmHg), NBPsys (mmHg), RESP (bpm), NB...         32
# 20  {PULSE (bpm), HR (bpm), PAPdias (mmHg), RESP (...         27
# 8   {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...         24
# 9   {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...         23
# 13  {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...         23
# 19  {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...         19
# 24  {C.O. (lpm), CVP (mmHg), HR (bpm), PAPdias (mm...         19
# 3   {C.O. (lpm), SpO2 (%), Tblood (degC), RESP (bpm)}         18
# 17  {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...         16
# 34  {C.O. (lpm), CVP (mmHg), HR (bpm), PAPdias (mm...         16
# 23  {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...         16
# 35  {C.O. (lpm), CVP (mmHg), HR (bpm), PAPdias (mm...         15
# 27  {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...         14
# 18  {HR (bpm), PAPdias (mmHg), RESP (bpm), PAWP (m...         10
# 46  {C.O. (lpm), CVP (mmHg), HR (bpm), PAPdias (mm...          7
# 28  {PULSE (bpm), C.O. (lpm), CVP (mmHg), HR (bpm)...          7
# 30  {NBPdias (mmHg), HR (bpm), NBPsys (mmHg), PAPd...          6
# 6   {C.O. (lpm), Tblood (degC), RESP (bpm), PAWP (...          6
# 40  {PULSE (bpm), C.O. (lpm), CVP (mmHg), HR (bpm)...          6
# 25  {PULSE (bpm), C.O. (lpm), HR (bpm), PAPdias (m...          5
# 15  {PULSE (bpm), ARTdias (mmHg), HR (bpm), PAPdia...          5
# 14  {PULSE (bpm), HR (bpm), ST2 (mV), RESP (bpm), ...          4
# 43  {C.O. (lpm), LAP (mmHg), CVP (mmHg), HR (bpm),...          4
# 36  {C.O. (lpm), LAP (mmHg), CVP (mmHg), HR (bpm),...          3
# 32  {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...          3
# 33  {NBPdias (mmHg), HR (bpm), NBPsys (mmHg), PAPd...          3
# 26  {PULSE (bpm), NBPdias (mmHg), ARTdias (mmHg), ...          3
# 4   {IMCO2 (mmHg), RESP (bpm), ETCO2 (mmHg), AWRR ...          3
# 10  {C.O. (lpm), NBPdias (mmHg), NBPsys (mmHg), Tb...          2
# 49  {C.O. (lpm), PAWP (mmHg), PAPmean (mmHg), AWRR...          2
# 48  {C.O. (lpm), PAWP (mmHg), PAPmean (mmHg), AWRR...          2
# 39  {C.O. (lpm), LAP (mmHg), CVP (mmHg), ARTdias (...          2
# 47  {C.O. (lpm), CVP (mmHg), HR (bpm), PAPdias (mm...          2
# 41  {C.O. (lpm), CVP (mmHg), HR (bpm), PAPdias (mm...          2
# 42  {PULSE (bpm), NBPdias (mmHg), ARTdias (mmHg), ...          2
# 29  {PULSE (bpm), C.O. (lpm), HR (bpm), PAPdias (m...          2
# 45  {PULSE (bpm), C.O. (lpm), LAP (mmHg), CVP (mmH...          1
# 51  {C.O. (lpm), PAWP (mmHg), PAPmean (mmHg), AWRR...          1
# 50  {NBPdias (mmHg), NBPmean (mmHg), C.O. (lpm), P...          1
# 31  {PULSE (bpm), ART1dias (mmHg), ARTmean (mmHg),...          1
# 44  {C.O. (lpm), NBPdias (mmHg), HR (bpm), NBPsys ...          1
# 12  {UAPmean (mmHg), C.O. (lpm), UAPsys (mmHg), Tb...          1
# 38  {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...          1
# 37  {P4mean (mmHg), PULSE (bpm), ARTdias (mmHg), H...          1
# 21  {CVP (mmHg), HR (bpm), ST2 (mV), ST1 (mV), ST3...          1
# 22  {PULSE (bpm), NBPdias (mmHg), CVP (mmHg), HR (...          1
# 52  {ARTsys (mmHg), C.O. (lpm), PAWP (mmHg), PAPme...          1

# %%
feat_set = feat_set_stats[1].iloc[2][0]
print(feat_set)
# Check above count
def check_feat_set_count(fields_df, cur_feat_set):
    feat_set_series = fields_df["feat_cols"]
    count = 0
    for fs in feat_set_series:
        if cur_feat_set.issubset(fs):
            count += 1
    return count
print(check_feat_set_count(fields_df, cur_feat_set=feat_set))
# Out:
# {'HR (bpm)', 'RESP (bpm)', 'ABPmean (mmHg)', 'SpO2 (%)', 'ABPdias (mmHg)', 'ABPsys (mmHg)'}
# 57

# %%
# Shortlist patients with feat_set
def shortlist_patients_with_feat_set(fields_df, cur_feat_set):
    feat_set_series = fields_df["feat_cols"]
    records = []
    for i, fs in enumerate(feat_set_series):
        if cur_feat_set.issubset(fs):
            records.append(fields_df["record"].iloc[i])
    return records
shortlisted_records = shortlist_patients_with_feat_set(fields_df, cur_feat_set=feat_set)
print(len(shortlisted_records), "Records:", shortlisted_records)
# Out:
# 57 Records: ['048n', '052n', '054n', '055n', '211n', '212n', '213n', '214n', '216n', '220n', '221n', '226n', '230n', '231n', '232n', '235n', '237n', '240n', '241n', '242n', '243n', '245n', '248n', '252n', '253n', '254n', '259n', '260n', '264n', '267n', '268n', '269n', '271n', '291n', '293n', '401n', '403n', '408n', '409n', '413n', '414n', '415n', '417n', '418n', '427n', '442n', '449n', '455n', '457n', '464n', '465n', '466n', '467n', '471n', '472n', '474n', '476n']

# %%
fields_df_shortlisted = fields_df[fields_df["record"].isin(shortlisted_records)]
fields_df_shortlisted
# Out:
#            fs  sig_len  n_sig   base_date base_time  \
# 0    0.976562    51138      7  1994-12-13  08:38:53
# 1    0.976562    77038      7  1995-02-22  13:08:55
# 2    0.976562   141796      7  1995-02-24  09:44:42
# 3    0.976562   131250     12  1995-03-02  15:36:24
# 7    0.976562    75991      6  1995-01-26  14:34:07
# 8    0.976562   145275     10  1995-04-04  14:00:03
# 9    0.976562   171093      7  1995-04-06  09:17:44
# 10   0.976562    90157     10  1995-04-19  07:14:25
# 12   0.976562    95654     16  1995-05-07  14:11:32
# 15   0.976562     4101      7  1995-05-17  08:26:10
# 16   0.976562    83362      7  1995-05-18  11:50:31
# 20   0.976562   112500      7  1995-06-05  07:46:28
# 21   0.976562    66796     13  1995-06-20  12:43:49
# 22   0.976562   150000     10  1995-06-23  09:44:09
# 23   0.976562    92799      7  1995-06-29  07:25:01
# 25   0.976562   166999     11  1995-07-13  13:30:04
# 26   0.976562   150000     13  1995-07-20  12:40:36
# 27   0.976562   107226     14  1995-08-24  11:47:32
# 28   0.976562    70163     14  1995-08-28  12:43:36
# 29   0.976562   149414     13  1995-08-29  09:03:14
# 30   0.976562   164063     10  1995-09-27  13:36:48
# 31   0.976562   150585     10  1995-10-24  13:31:03
# 32   0.976562   120116     10  1995-11-10  10:55:33
# 33   0.976562    99023     10  1995-11-19  19:40:47
# 34   0.976562   149414     14  1995-11-22  07:16:04
# 35   0.976562   149415     17  1995-11-24  14:00:57
# 37   0.976562   165224     12  1995-12-11  10:17:51
# 38   0.976562    46289     13  1995-12-15  07:23:50
# 40   0.976562   162346     13  1996-01-04  12:40:13
# 41   0.976562   161541     13  1996-01-13  11:17:31
# 42   0.976562   130155     13  1996-01-15  10:31:12
# 43   0.976562   151700     10  1996-01-17  00:30:30
# 44   0.976562   110884     13  1996-01-19  08:29:27
# 55   0.976562    75788      6  1996-04-04  10:40:44
# 56   0.976562   176367     10  1996-04-06  16:07:55
# 57   0.976562    88387      7  1995-01-25  12:41:44
# 58   0.976562   149999      7  1995-01-26  14:20:11
# 61   0.976562   169814      7  1995-05-03  05:19:47
# 62   0.976562   152343      7  1995-05-05  11:35:21
# 65   0.976562    75124      7  1995-05-18  14:17:54
# 66   0.976562    88094      7  1995-05-19  13:14:10
# 67   0.976562   147655     13  1995-05-22  12:45:31
# 68   0.976562    42773     16  1995-05-26  07:40:48
# 69   0.976562    95162     16  1995-06-01  09:13:34
# 71   0.976562   205664     16  1995-06-23  13:02:51
# 82   0.976562   123555      7  1995-11-07  11:08:32
# 87   0.976562   149433      9  1995-12-02  13:39:23
# 93   0.976562   171097     17  1996-01-07  18:55:39
# 95   0.976562   202734     16  1996-01-15  10:18:48
# 98   0.976562    93737     10  1996-01-31  08:04:57
# 99   0.976562   222655     10  1996-02-01  11:10:52
# 100  0.976562   241406     10  1996-02-08  12:32:05
# 101  0.976562   193946     13  1996-02-13  08:58:09
# 103  0.976562   220312     13  1996-03-05  08:27:37
# 104  0.976562    30469     13  1996-03-11  08:33:09
# 105  0.976562   135352     20  1996-03-12  23:17:36
# 106  0.976562    62109     18  1996-03-15  22:42:01
#
#                                                  units  \
# 0    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 1    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 2    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 3    ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 7          ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', '%']
# 8    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 9    ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 10   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 12   ['mmHg', 'mmHg', 'mmHg', 'mmHg', 'mmHg', 'mmHg...
# 15   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 16   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 20   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 21   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 22   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 23   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 25   ['mmHg', 'mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg'...
# 26   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 27   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 28   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 29   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 30   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 31   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 32   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 33   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 34   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 35   ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 37   ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 38   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 40   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 41   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 42   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 43   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 44   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 55         ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', '%']
# 56   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 57   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 58   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 61   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 62   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 65   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 66   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 67   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 68   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 69   ['mmHg', 'mmHg', 'mmHg', 'mmHg', 'mmHg', 'mmHg...
# 71   ['mmHg', 'mmHg', 'mmHg', 'mmHg', 'mmHg', 'mmHg...
# 82   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 87   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 93   ['mmHg', 'mmHg', 'mmHg', 'lpm', 'mmHg', 'bpm',...
# 95   ['mmHg', 'mmHg', 'mmHg', 'lpm', 'mmHg', 'bpm',...
# 98   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 99   ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 100  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 101  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 103  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'mmHg', 'mmHg'...
# 104  ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 105  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'lpm', 'mmHg',...
# 106  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'lpm', 'mmHg',...
#
#                                               sig_name comments  \
# 0    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 1    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 2    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 3    ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 7    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'RESP',...       []
# 8    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 9    ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 10   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 12   ['ABPmean', 'ABPsys', 'ABPdias', 'ARTmean', 'A...       []
# 15   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 16   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 20   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 21   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 22   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 23   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 25   ['ABPmean', 'ABPsys', 'ABPdias', 'CVP', 'HR', ...       []
# 26   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 27   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 28   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 29   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 30   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 31   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 32   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 33   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 34   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 35   ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 37   ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 38   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 40   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 41   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 42   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 43   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 44   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 55   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'RESP',...       []
# 56   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 57   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 58   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 61   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 62   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 65   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 66   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 67   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 68   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 69   ['ABPmean', 'ABPsys', 'ABPdias', 'ARTmean', 'A...       []
# 71   ['ABPmean', 'ABPsys', 'ABPdias', 'ARTmean', 'A...       []
# 82   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 87   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 93   ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'CVP'...       []
# 95   ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'CVP'...       []
# 98   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 99   ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PAPmea...       []
# 100  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 101  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 103  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'NBPmea...       []
# 104  ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 105  ['ABPmean', 'ABPsys', 'ABPdias', 'AWRR', 'C.O....       []
# 106  ['ABPmean', 'ABPsys', 'ABPdias', 'AWRR', 'C.O....       []
#
#                                          unique_alarms record  \
# 0    {'*ASYSTOLE': 23, '*TACHY 216 > 180': 9, '*VEN...   048n
# 1    {'ABP  184 > 180': 115, 'ABP  182 > 180': 115,...   052n
# 2    {'PAIR VPBs': 982, 'HR  53 <  55': 560, 'MULTI...   054n
# 3    {'VPBs > 5/MIN': 1661, 'PAIR VPBs': 1584, 'MUL...   055n
# 7    {'PAIR VPBs': 328, 'HR 126 > 120': 99, 'ABP  2...   211n
# 8    {'VPBs >  5/MIN': 11644, 'MISSED BEATS': 10580...   212n
# 9    {'VPBs >  5/MIN': 3536, 'ABP   87 < 90': 717, ...   213n
# 10   {'RUN VPBs > 2': 3855, 'PAIR VPBs': 2566, 'VEN...   214n
# 12   {'VENT TRIGEMINY': 483, 'VPBs >  5/MIN': 389, ...   216n
# 15                             {'MULTIFORM VPBs': 309}   220n
# 16   {'PAIR VPBs': 793, 'MULTIFORM VPBs': 565, 'ABP...   221n
# 20   {'HR 141 > 140': 1655, 'MISSED BEATS': 625, 'V...   226n
# 21   {'VPBs >  5/MIN': 2331, 'PAIR VPBs': 1673, 'IR...   230n
# 22   {'PAIR VPBs': 6251, 'MULTIFORM VPBs': 1619, 'M...   231n
# 23   {'PAIR VPBs': 21307, 'IRREGULAR HR': 10410, 'V...   232n
# 25   {'HR 121 > 120': 1959, 'HR 130 > 125': 1746, '...   235n
# 26   {'MULTIFORM VPBs': 9554, 'VPBs >  5/MIN': 8578...   237n
# 27   {'ABP   78 < 90': 286, 'MISSED BEATS': 268, 'A...   240n
# 28   {'MULTIFORM VPBs': 13232, 'PAIR VPBs': 11212, ...   241n
# 29   {'MULTIFORM VPBs': 26064, 'PAIR VPBs': 10354, ...   242n
# 30   {'HR 151 > 150': 803, 'HR 152 > 150': 549, 'HR...   243n
# 31   {'MISSED BEATS': 12082, 'RUN VPBs > 2': 285, '...   245n
# 32   {'MULTIFORM VPBs': 7413, 'PAIR VPBs': 2154, 'H...   248n
# 33   {'R-ON-T VPBs': 335, 'ABP   45 < 80': 31, 'ABP...   252n
# 34   {'R-ON-T VPBs': 370, 'MULTIFORM VPBs': 276, 'A...   253n
# 35   {'PAIR VPBs': 459, 'ABP   75 < 90': 321, '*VEN...   254n
# 37   {'PAIR VPBs': 2421, 'RUN VPBs > 2': 2139, 'R-O...   259n
# 38   {'PAIR VPBs': 574, 'R-ON-T VPBs': 293, 'RUN VP...   260n
# 40   {'VPBs >  8/MIN': 94262, 'MISSED BEATS': 10998...   264n
# 41   {'PAIR VPBs': 8237, 'MULTIFORM VPBs': 1093, 'V...   267n
# 42   {'HR 169 > 155': 287, 'PAP   46 > 40': 76, 'MI...   268n
# 43   {'PAIR VPBs': 25488, 'RUN VPBs > 2': 25332, 'V...   269n
# 44   {'VPBs >  5/MIN': 4308, 'PAIR VPBs': 3330, 'RU...   271n
# 55   {'ABP  320 > 150': 8, 'ABP   67 < 90': 3, 'ABP...   291n
# 56                              {'NBP  166 > 160': 46}   293n
# 57   {'ABP  222 > 195': 17, 'ABP  198 > 195': 15, '...   401n
# 58   {'ABP   79 < 80': 64, 'ABP   78 < 80': 28, '*A...   403n
# 61   {'IRREGULAR HR': 2290, 'MULTIFORM VPBs': 681, ...   408n
# 62   {'IRREGULAR HR': 28905, 'MULTIFORM VPBs': 9678...   409n
# 65   {'MULTIFORM VPBs': 9862, 'MISSED BEATS': 9671,...   413n
# 66   {'MULTIFORM VPBs': 18499, 'MISSED BEATS': 9796...   414n
# 67   {'MISSED BEATS': 281, 'ABP  171 > 160': 23, 'P...   415n
# 68   {'MULTIFORM VPBs': 288, 'MISSED BEATS': 106, '...   417n
# 69   {'R-ON-T VPBs': 1209, 'ABP   55 < 60': 17, 'PA...   418n
# 71   {'VPBs >  5/MIN': 2338, 'HR 111 > 110': 534, '...   427n
# 82   {'MULTIFORM VPBs': 25724, 'PAIR VPBs': 22615, ...   442n
# 87   {'ABP   84 < 85': 123, 'ABP   83 < 85': 98, 'A...   449n
# 93   {'PAIR VPBs': 3514, 'MULTIFORM VPBs': 2186, 'H...   455n
# 95   {'HR 170 > 120': 2410, 'HR 150 > 120': 908, 'H...   457n
# 98   {'VENT BIGEMINY': 1184, 'PAP  240 > 40': 510, ...   464n
# 99   {'PACER NOT CAPT': 4996, 'IRREGULAR HR': 4783,...   465n
# 100  {'IRREGULAR HR': 1627, 'PAP   53 > 50': 505, '...   466n
# 101  {'MULTIFORM VPBs': 15456, 'PAIR VPBs': 6949, '...   467n
# 103  {'IRREGULAR HR': 23790, 'VPBs >  5/MIN': 7678,...   471n
# 104  {'PAIR VPBs': 1887, 'VPBs > 11/MIN': 1818, 'MU...   472n
# 105  {'IRREGULAR HR': 2457, 'HR  64 <  65': 448, 'H...   474n
# 106  {'ST2   0.9>0.6': 776, 'ST3   0.8>0.6': 742, '...   476n
#
#                                              feat_cols
# 0    {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 1    {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 2    {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 3    {PULSE (bpm), C.O. (lpm), HR (bpm), PAPdias (m...
# 7    {HR (bpm), RESP (bpm), ABPmean (mmHg), SpO2 (%...
# 8    {PULSE (bpm), HR (bpm), PAPdias (mmHg), RESP (...
# 9    {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 10   {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...
# 12   {PULSE (bpm), NBPdias (mmHg), ARTdias (mmHg), ...
# 15   {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 16   {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 20   {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 21   {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...
# 22   {PULSE (bpm), HR (bpm), PAPdias (mmHg), RESP (...
# 23   {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 25   {PULSE (bpm), NBPdias (mmHg), CVP (mmHg), HR (...
# 26   {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...
# 27   {NBPdias (mmHg), HR (bpm), NBPsys (mmHg), PAPd...
# 28   {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...
# 29   {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...
# 30   {PULSE (bpm), HR (bpm), PAPdias (mmHg), RESP (...
# 31   {PULSE (bpm), HR (bpm), PAPdias (mmHg), RESP (...
# 32   {PULSE (bpm), HR (bpm), PAPdias (mmHg), RESP (...
# 33   {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...
# 34   {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...
# 35   {C.O. (lpm), NBPdias (mmHg), HR (bpm), NBPsys ...
# 37   {PULSE (bpm), C.O. (lpm), HR (bpm), PAPdias (m...
# 38   {NBPdias (mmHg), HR (bpm), NBPsys (mmHg), PAPd...
# 40   {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...
# 41   {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...
# 42   {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...
# 43   {HR (bpm), PAPdias (mmHg), RESP (bpm), PAWP (m...
# 44   {NBPdias (mmHg), HR (bpm), NBPsys (mmHg), PAPd...
# 55   {HR (bpm), RESP (bpm), ABPmean (mmHg), SpO2 (%...
# 56   {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...
# 57   {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 58   {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 61   {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 62   {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 65   {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 66   {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 67   {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...
# 68   {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...
# 69   {PULSE (bpm), NBPdias (mmHg), ARTdias (mmHg), ...
# 71   {P4mean (mmHg), PULSE (bpm), ARTdias (mmHg), H...
# 82   {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 87   {PULSE (bpm), HR (bpm), ST2 (mV), RESP (bpm), ...
# 93   {PULSE (bpm), C.O. (lpm), LAP (mmHg), CVP (mmH...
# 95   {C.O. (lpm), CVP (mmHg), HR (bpm), PAPdias (mm...
# 98   {PULSE (bpm), HR (bpm), PAPdias (mmHg), RESP (...
# 99   {PULSE (bpm), HR (bpm), PAPdias (mmHg), RESP (...
# 100  {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...
# 101  {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...
# 103  {PULSE (bpm), NBPdias (mmHg), HR (bpm), NBPsys...
# 104  {PULSE (bpm), C.O. (lpm), HR (bpm), PAPdias (m...
# 105  {C.O. (lpm), PAWP (mmHg), PAPmean (mmHg), AWRR...
# 106  {C.O. (lpm), CVP (mmHg), HR (bpm), PAPdias (mm...

# %%
fields_df_shortlisted.head()
# Out:
#          fs  sig_len  n_sig   base_date base_time  \
# 0  0.976562    51138      7  1994-12-13  08:38:53
# 1  0.976562    77038      7  1995-02-22  13:08:55
# 2  0.976562   141796      7  1995-02-24  09:44:42
# 3  0.976562   131250     12  1995-03-02  15:36:24
# 7  0.976562    75991      6  1995-01-26  14:34:07
#
#                                                units  \
# 0  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 1  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 2  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 3  ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 7        ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', '%']
#
#                                             sig_name comments  \
# 0  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 1  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 2  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 3  ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 7  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'RESP',...       []
#
#                                        unique_alarms record  \
# 0  {'*ASYSTOLE': 23, '*TACHY 216 > 180': 9, '*VEN...   048n
# 1  {'ABP  184 > 180': 115, 'ABP  182 > 180': 115,...   052n
# 2  {'PAIR VPBs': 982, 'HR  53 <  55': 560, 'MULTI...   054n
# 3  {'VPBs > 5/MIN': 1661, 'PAIR VPBs': 1584, 'MUL...   055n
# 7  {'PAIR VPBs': 328, 'HR 126 > 120': 99, 'ABP  2...   211n
#
#                                            feat_cols
# 0  {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 1  {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 2  {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 3  {PULSE (bpm), C.O. (lpm), HR (bpm), PAPdias (m...
# 7  {HR (bpm), RESP (bpm), ABPmean (mmHg), SpO2 (%...

# %% [markdown]
# ## Split Records into Train, Valid, Test Records

# %%
# split records by train, valid, test
def recordwise_train_valid_test_split(df, valid_prop, test_prop, seed):
    records = df["record"].unique()
    num_records = len(records)
    record_indices = np.arange(num_records)
    np.random.seed(seed=seed)
    np.random.shuffle(record_indices)
    shuffled_records = records[record_indices]
    num_valid, num_test = round(valid_prop * num_records), round(test_prop * num_records)
    num_train = num_records - num_valid - num_test
    train_records, valid_records, test_records = (
        shuffled_records[:num_train], shuffled_records[num_train: num_train+num_valid],
        shuffled_records[num_train+num_valid:num_train+num_valid+num_test],
    )
    return train_records, valid_records, test_records

train_records, valid_records, test_records = recordwise_train_valid_test_split(
    fields_df_shortlisted, valid_prop=0.1, test_prop=0.2, seed=2023)

# %%
print(len(train_records), "Train Records:", train_records)
print(len(valid_records), "Valid Records:", valid_records)
print(len(test_records), "Test Records:", test_records)
# Out:
# 40 Train Records: ['474n' '269n' '241n' '232n' '230n' '242n' '221n' '048n' '220n' '415n'
#  '418n' '403n' '226n' '259n' '268n' '401n' '464n' '260n' '476n' '237n'
#  '471n' '427n' '054n' '243n' '442n' '414n' '245n' '455n' '409n' '052n'
#  '211n' '293n' '216n' '417n' '235n' '472n' '267n' '457n' '214n' '449n']
# 6 Valid Records: ['467n' '466n' '253n' '212n' '413n' '231n']
# 11 Test Records: ['240n' '465n' '271n' '408n' '248n' '055n' '264n' '291n' '213n' '254n'
#  '252n']

# %%
fields_df_shortlisted.head()
# Out:
#          fs  sig_len  n_sig   base_date base_time  \
# 0  0.976562    51138      7  1994-12-13  08:38:53
# 1  0.976562    77038      7  1995-02-22  13:08:55
# 2  0.976562   141796      7  1995-02-24  09:44:42
# 3  0.976562   131250     12  1995-03-02  15:36:24
# 7  0.976562    75991      6  1995-01-26  14:34:07
#
#                                                units  \
# 0  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 1  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 2  ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', 'bpm', ...
# 3  ['mmHg', 'mmHg', 'mmHg', 'lpm', 'bpm', 'mmHg',...
# 7        ['mmHg', 'mmHg', 'mmHg', 'bpm', 'bpm', '%']
#
#                                             sig_name comments  \
# 0  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 1  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 2  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'PULSE'...       []
# 3  ['ABPmean', 'ABPsys', 'ABPdias', 'C.O.', 'HR',...       []
# 7  ['ABPmean', 'ABPsys', 'ABPdias', 'HR', 'RESP',...       []
#
#                                        unique_alarms record  \
# 0  {'*ASYSTOLE': 23, '*TACHY 216 > 180': 9, '*VEN...   048n
# 1  {'ABP  184 > 180': 115, 'ABP  182 > 180': 115,...   052n
# 2  {'PAIR VPBs': 982, 'HR  53 <  55': 560, 'MULTI...   054n
# 3  {'VPBs > 5/MIN': 1661, 'PAIR VPBs': 1584, 'MUL...   055n
# 7  {'PAIR VPBs': 328, 'HR 126 > 120': 99, 'ABP  2...   211n
#
#                                            feat_cols
# 0  {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 1  {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 2  {PULSE (bpm), HR (bpm), RESP (bpm), ABPmean (m...
# 3  {PULSE (bpm), C.O. (lpm), HR (bpm), PAPdias (m...
# 7  {HR (bpm), RESP (bpm), ABPmean (mmHg), SpO2 (%...

# %% [markdown]
# ## Load Data

# %%
def load_data(fields_df_shortlisted, feat_set):
    df_list = []
    records = fields_df_shortlisted["record"].tolist()
    for record in tqdm(records):
        fp_csv = os.path.join(fp_converted_folder, record+".csv")
        df = pd.read_csv(fp_csv, index_col=0)[list(feat_set)]
        df["record"] = record
        df_list.append(df)
    all_df = pd.concat(df_list).reset_index()
    all_df.columns = ["record_index"] + all_df.columns[1:].to_list()
    return all_df
all_df = load_data(fields_df_shortlisted, feat_set)
all_df.head()
# Out:
#   0%|                                                    | 0/57 [00:00<?, ?it/s]/tmp/ipykernel_572966/3472446142.py:6: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)[list(feat_set)]
#   5%|██▎                                         | 3/57 [00:00<00:02, 20.94it/s]/tmp/ipykernel_572966/3472446142.py:6: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)[list(feat_set)]
#  21%|█████████                                  | 12/57 [00:00<00:02, 17.42it/s]/tmp/ipykernel_572966/3472446142.py:6: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)[list(feat_set)]
# /tmp/ipykernel_572966/3472446142.py:6: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)[list(feat_set)]
#  28%|████████████                               | 16/57 [00:00<00:02, 15.20it/s]/tmp/ipykernel_572966/3472446142.py:6: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)[list(feat_set)]
#  39%|████████████████▌                          | 22/57 [00:01<00:02, 14.45it/s]/tmp/ipykernel_572966/3472446142.py:6: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)[list(feat_set)]
#  56%|████████████████████████▏                  | 32/57 [00:02<00:02, 12.22it/s]/tmp/ipykernel_572966/3472446142.py:6: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)[list(feat_set)]
#  72%|██████████████████████████████▉            | 41/57 [00:02<00:01, 14.32it/s]/tmp/ipykernel_572966/3472446142.py:6: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)[list(feat_set)]
#  75%|████████████████████████████████▍          | 43/57 [00:02<00:00, 14.66it/s]/tmp/ipykernel_572966/3472446142.py:6: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)[list(feat_set)]
#  79%|█████████████████████████████████▉         | 45/57 [00:03<00:00, 12.72it/s]/tmp/ipykernel_572966/3472446142.py:6: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)[list(feat_set)]
#  82%|███████████████████████████████████▍       | 47/57 [00:03<00:00, 13.26it/s]/tmp/ipykernel_572966/3472446142.py:6: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)[list(feat_set)]
#  86%|████████████████████████████████████▉      | 49/57 [00:03<00:00, 11.06it/s]/tmp/ipykernel_572966/3472446142.py:6: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)[list(feat_set)]
#  96%|█████████████████████████████████████████▍ | 55/57 [00:04<00:00, 11.89it/s]/tmp/ipykernel_572966/3472446142.py:6: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp_csv, index_col=0)[list(feat_set)]
# 100%|███████████████████████████████████████████| 57/57 [00:04<00:00, 13.66it/s]
#    record_index  HR (bpm)  RESP (bpm)  ABPmean (mmHg)  SpO2 (%)  \
# 0             0      85.0         0.0           110.0      97.0
# 1             1      85.0         0.0           111.0      97.0
# 2             2      85.0         0.0           111.0      97.0
# 3             3      85.0         0.0           113.0      97.0
# 4             4      85.0         0.0           113.0      97.0
#
#    ABPdias (mmHg)  ABPsys (mmHg) record
# 0            89.0          159.0   048n
# 1            90.0          161.0   048n
# 2            90.0          161.0   048n
# 3            92.0          163.0   048n
# 4            92.0          164.0   048n

# %%
def plot_columns(df):
    import seaborn as sns
    df = df.copy()
    df = df.drop("record_index", axis=1)
    df = df.drop("record", axis=1)
    df = df.dropna()
    print(df.columns)
    num_rows = 2
    num_cols = 3

    # Create subplots
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 6), dpi=300)

    # Flatten the axes array for easier iteration
    axes = axes.flatten()

    # Loop through each column and create a violin plot
    for i, column in enumerate(df.columns):
        ax = axes[i]
        sns.boxplot(data=df, y=column, ax=ax)
        ax.set_title(column)
#         ax.set_xlabel(column)
        ax.set_ylabel('Value')

    # Hide any remaining empty subplots
    for i in range(len(df.columns), num_rows * num_cols):
        axes[i].axis('off')

    plt.tight_layout()  # Ensures proper spacing between subplots
    plt.show()
    
plot_columns(all_df)
# Out:
# Index(['HR (bpm)', 'RESP (bpm)', 'ABPmean (mmHg)', 'SpO2 (%)',
#        'ABPdias (mmHg)', 'ABPsys (mmHg)'],
#       dtype='object')

# %%
all_df.to_csv(fp_downsampled_concatenated_file, index=False)

# %%
all_df = pd.read_csv(fp_downsampled_concatenated_file)

# %%
all_df.describe()
# Out:
#        record_index      HR (bpm)    RESP (bpm)  ABPmean (mmHg)      SpO2 (%)  \
# count  7.207482e+06  7.135349e+06  6.497795e+06    6.320376e+06  6.812051e+06
# mean   7.337624e+04  8.732022e+01  1.624711e+01    8.391586e+01  6.942284e+01
# std    4.988713e+04  1.927226e+01  9.045125e+00    2.142368e+01  4.298076e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00   -4.000000e+01  0.000000e+00
# 25%    3.213200e+04  7.500000e+01  1.200000e+01    7.300000e+01  0.000000e+00
# 50%    6.601600e+04  8.800000e+01  1.600000e+01    8.100000e+01  9.500000e+01
# 75%    1.084060e+05  9.800000e+01  2.100000e+01    9.300000e+01  9.800000e+01
# max    2.414050e+05  2.260000e+02  1.190000e+02    3.610000e+02  1.000000e+02
#
#        ABPdias (mmHg)  ABPsys (mmHg)
# count    6.320376e+06   6.320376e+06
# mean     6.298281e+01   1.241891e+02
# std      1.913398e+01   2.935350e+01
# min     -4.000000e+01  -4.000000e+01
# 25%      5.300000e+01   1.070000e+02
# 50%      6.100000e+01   1.200000e+02
# 75%      7.000000e+01   1.380000e+02
# max      3.610000e+02   3.610000e+02

# %% [markdown]
# ## Set outlier values to NA

# %%
all_df.isna().sum()
# Out:
# record_index           0
# HR (bpm)           72133
# RESP (bpm)        709687
# ABPmean (mmHg)    887106
# SpO2 (%)          395431
# ABPdias (mmHg)    887106
# ABPsys (mmHg)     887106
# record                 0
# dtype: int64

# %% [markdown]
# - Drop anything that is 0 – basically means machine disconnected, for any feature in the dataset
# - Drop BP > 250 – this is highly unlikely (he told me he will check for us to see if some other threshold is better, but 250 is very safe.)

# %%
list(feat_set)
# Out:
# ['HR (bpm)',
#  'RESP (bpm)',
#  'ABPmean (mmHg)',
#  'SpO2 (%)',
#  'ABPdias (mmHg)',
#  'ABPsys (mmHg)']

# %%
def set_outliers_to_na(df, predictors):
    df = df.copy()
    # 1. Drop anything that is 0 – basically means machine disconnected, for any feature in the dataset
    df[df[predictors]<=0] = np.nan
    
    # 2. Drop BP > 250 – this is highly unlikely
    bp_cols = ["ABPmean (mmHg)", 'ABPdias (mmHg)', 'ABPsys (mmHg)']
    df[df[bp_cols]>250] = np.nan 
    return df
    
all_df = set_outliers_to_na(all_df, predictors=list(feat_set))

# %%
all_df
# Out:
#          record_index  HR (bpm)  RESP (bpm)  ABPmean (mmHg)  SpO2 (%)  \
# 0                   0      85.0         NaN           110.0      97.0
# 1                   1      85.0         NaN           111.0      97.0
# 2                   2      85.0         NaN           111.0      97.0
# 3                   3      85.0         NaN           113.0      97.0
# 4                   4      85.0         NaN           113.0      97.0
# ...               ...       ...         ...             ...       ...
# 7207477         62104       NaN         NaN             NaN       NaN
# 7207478         62105       NaN         NaN             NaN       NaN
# 7207479         62106       NaN         NaN             NaN       NaN
# 7207480         62107       NaN         NaN             NaN       NaN
# 7207481         62108       NaN         NaN             NaN       NaN
#
#          ABPdias (mmHg)  ABPsys (mmHg) record
# 0                  89.0          159.0   048n
# 1                  90.0          161.0   048n
# 2                  90.0          161.0   048n
# 3                  92.0          163.0   048n
# 4                  92.0          164.0   048n
# ...                 ...            ...    ...
# 7207477             NaN            NaN   476n
# 7207478             NaN            NaN   476n
# 7207479             NaN            NaN   476n
# 7207480             NaN            NaN   476n
# 7207481             NaN            NaN   476n
#
# [7207482 rows x 8 columns]

# %%
all_df.describe()
# Out:
#        record_index      HR (bpm)    RESP (bpm)  ABPmean (mmHg)      SpO2 (%)  \
# count  7.207482e+06  7.058686e+06  5.780386e+06    6.256825e+06  4.930607e+06
# mean   7.337624e+04  8.826858e+01  1.826355e+01    8.416617e+01  9.591353e+01
# std    4.988713e+04  1.708048e+01  7.425692e+00    1.757085e+01  3.383506e+00
# min    0.000000e+00  2.000000e+01  1.000000e+00    1.000000e+00  2.000000e+00
# 25%    3.213200e+04  7.600000e+01  1.300000e+01    7.300000e+01  9.400000e+01
# 50%    6.601600e+04  8.800000e+01  1.700000e+01    8.100000e+01  9.700000e+01
# 75%    1.084060e+05  9.800000e+01  2.200000e+01    9.300000e+01  9.800000e+01
# max    2.414050e+05  2.260000e+02  1.190000e+02    2.500000e+02  1.000000e+02
#
#        ABPdias (mmHg)  ABPsys (mmHg)
# count    6.256682e+06   6.256652e+06
# mean     6.302049e+01   1.248409e+02
# std      1.485357e+01   2.602730e+01
# min      1.000000e+00   1.000000e+00
# 25%      5.300000e+01   1.070000e+02
# 50%      6.100000e+01   1.200000e+02
# 75%      7.000000e+01   1.380000e+02
# max      2.500000e+02   2.500000e+02

# %%
plot_columns(all_df)
# Out:
# Index(['HR (bpm)', 'RESP (bpm)', 'ABPmean (mmHg)', 'SpO2 (%)',
#        'ABPdias (mmHg)', 'ABPsys (mmHg)'],
#       dtype='object')

# %% [markdown]
# ## Standardise Data

# %%
def standardise_data(df, train_records, valid_records, test_records, predictors):
    from sklearn.preprocessing import StandardScaler
    df_train, df_valid, df_test = (
        df[df["record"].isin(train_records)], df[df["record"].isin(valid_records)],
        df[df["record"].isin(test_records)]
    )
    scaler = StandardScaler()
    scaler.fit(df_train[predictors])
    df_train[predictors] = scaler.transform(df_train[predictors])
    df_valid[predictors] = scaler.transform(df_valid[predictors])
    df_test[predictors] = scaler.transform(df_test[predictors])
    
    return pd.concat([df_train, df_valid, df_test]), scaler

all_df, scaler = standardise_data(all_df, train_records, valid_records, test_records, list(feat_set))
all_df.head()
# Out:
# /tmp/ipykernel_572966/3431272954.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train[predictors] = scaler.transform(df_train[predictors])
# /tmp/ipykernel_572966/3431272954.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_valid[predictors] = scaler.transform(df_valid[predictors])
# /tmp/ipykernel_572966/3431272954.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test[predictors] = scaler.transform(df_test[predictors])
#    record_index  HR (bpm)  RESP (bpm)  ABPmean (mmHg)  SpO2 (%)  \
# 0             0 -0.160195         NaN         1.37323   0.27073
# 1             1 -0.160195         NaN         1.42918   0.27073
# 2             2 -0.160195         NaN         1.42918   0.27073
# 3             3 -0.160195         NaN         1.54108   0.27073
# 4             4 -0.160195         NaN         1.54108   0.27073
#
#    ABPdias (mmHg)  ABPsys (mmHg) record
# 0        1.771772       1.133825   048n
# 1        1.839573       1.206455   048n
# 2        1.839573       1.206455   048n
# 3        1.975173       1.279086   048n
# 4        1.975173       1.315401   048n

# %%
all_df.shape
# Out:
# (7207482, 8)

# %%
def save_scaler(scaler, fp_downsampled_scaler_file):
    import pickle 
    with open(fp_downsampled_scaler_file, 'wb') as handle:
        pickle.dump(scaler, handle, protocol=pickle.HIGHEST_PROTOCOL)
save_scaler(scaler, fp_downsampled_scaler_file)

# %%
all_df[all_df["record"]=='052n'].shape[0]/60
# Out:
# 1283.9666666666667

# %%
all_df["record"].unique()
# Out:
# array(['048n', '052n', '054n', '211n', '214n', '216n', '220n', '221n',
#        '226n', '230n', '232n', '235n', '237n', '241n', '242n', '243n',
#        '245n', '259n', '260n', '267n', '268n', '269n', '293n', '401n',
#        '403n', '409n', '414n', '415n', '417n', '418n', '427n', '442n',
#        '449n', '455n', '457n', '464n', '471n', '472n', '474n', '476n',
#        '212n', '231n', '253n', '413n', '466n', '467n', '055n', '213n',
#        '240n', '248n', '252n', '254n', '264n', '271n', '291n', '408n',
#        '465n'], dtype=object)

# %% [markdown]
# ## Downsample Time Series Data

# %%
def downsample_all_df(all_df, feat_set, window=60):
    all_downsampled_df_list = []
    feat_set = list(feat_set)
    for record, record_df in all_df.groupby("record"):
        window_groups = record_df.groupby((record_df.index//window).astype('i'))
        # Downsample with mean
        downsampled_df = window_groups[feat_set].mean()
        downsampled_df.columns = [col + "_mean" for col in feat_set]
        # Downsample with std
        std_cols = [col + "_std" for col in feat_set]
        downsampled_df[std_cols] = window_groups[feat_set].std()
        downsampled_df["record"] = record
        # Get record df index
        downsampled_df = downsampled_df.reset_index(drop=True)
        downsampled_df["record_index"] = downsampled_df.index
        all_downsampled_df_list.append(downsampled_df)
    all_downsampled_df = pd.concat(all_downsampled_df_list)
    return all_downsampled_df
downsampled_df = downsample_all_df(all_df, feat_set, window=60)
downsampled_df.head(10)
# Out:
#    HR (bpm)_mean  RESP (bpm)_mean  ABPmean (mmHg)_mean  SpO2 (%)_mean  \
# 0      -0.152358              NaN             0.912202       0.075853
# 1      -0.253263              NaN             0.032295      -0.675816
# 2      -0.309104              NaN            -0.117837      -0.740775
# 3      -0.221914              NaN             0.189887      -0.801094
# 4      -0.031860              NaN             1.339660      -0.264647
# 5      -0.067127              NaN             1.309820       0.201131
# 6      -0.086721              NaN             1.521497       0.349609
# 7       0.319839              NaN             2.417630      -0.230382
# 8       0.262039              NaN             2.139745      -1.078782
# 9       0.098436              NaN             1.297697      -1.842548
#
#    ABPdias (mmHg)_mean  ABPsys (mmHg)_mean  HR (bpm)_std  RESP (bpm)_std  \
# 0             1.222590            0.610158      0.067019             NaN
# 1             0.029305           -0.021607      0.031163             NaN
# 2            -0.255456           -0.099080      0.047749             NaN
# 3             0.065465            0.144838      0.054569             NaN
# 4             1.572892            1.044852      0.090863             NaN
# 5             1.549162            1.102352      0.087447             NaN
# 6             1.735612            1.190114      0.060860             NaN
# 7             2.771827            1.934577      0.166313             NaN
# 8             2.593286            1.705791      0.054641             NaN
# 9             1.648602            0.894749      0.077438             NaN
#
#    ABPmean (mmHg)_std  SpO2 (%)_std  ABPdias (mmHg)_std  ABPsys (mmHg)_std  \
# 0            0.708760      0.200492            0.783799           0.841499
# 1            0.265037      0.186225            0.231963           0.373858
# 2            0.064187      0.153486            0.068030           0.086514
# 3            0.239340      0.176259            0.335923           0.156715
# 4            0.130383      0.197597            0.169267           0.149571
# 5            0.195579      0.121566            0.180936           0.192333
# 6            0.139666      0.126509            0.109158           0.156438
# 7            0.312904      0.412610            0.341092           0.321315
# 8            0.447635      0.282274            0.535913           0.358421
# 9            0.171392      0.173164            0.170927           0.186051
#
#   record  record_index
# 0   048n             0
# 1   048n             1
# 2   048n             2
# 3   048n             3
# 4   048n             4
# 5   048n             5
# 6   048n             6
# 7   048n             7
# 8   048n             8
# 9   048n             9

# %%
downsampled_df.shape
# Out:
# (120179, 14)

# %%
downsampled_df[downsampled_df["record"]=='052n']
# Out:
#       HR (bpm)_mean  RESP (bpm)_mean  ABPmean (mmHg)_mean  SpO2 (%)_mean  \
# 0         -0.259669         0.290796             1.629243       0.635296
# 1         -0.269917         0.097975             1.624072       0.549126
# 2         -0.294409         0.073596             1.586772       0.549126
# 3         -0.254243         0.060298             1.659507       0.549126
# 4         -0.141582         0.722980             1.846007       0.604805
# ...             ...              ...                  ...            ...
# 1280      -0.703908         0.394963             0.324167       0.576966
# 1281      -0.862613         0.000457             0.228120       0.590885
# 1282      -0.842040         0.355069             0.337222       0.535206
# 1283      -0.909637        -0.037221             0.250500       0.521286
# 1284      -0.928005         0.107949             0.422080       0.549126
#
#       ABPdias (mmHg)_mean  ABPsys (mmHg)_mean  HR (bpm)_std  RESP (bpm)_std  \
# 0                0.695186            1.748984      0.057036        0.067920
# 1                0.941219            1.754816      0.060707        0.066715
# 2                0.934439            1.742711      0.116102        0.106628
# 3                0.998849            1.783263      0.034563        0.100552
# 4                1.273440            1.814737      0.144990        0.520311
# ...                   ...                 ...           ...             ...
# 1280            -0.288226            1.084799      0.116370        0.164408
# 1281            -0.375237            1.049694      0.061625        0.159597
# 1282            -0.289356            1.110825      0.162406        0.244212
# 1283            -0.370717            1.073299      0.085643        0.177344
# 1284            -0.228336            1.192837      0.039975        0.174232
#
#       ABPmean (mmHg)_std  SpO2 (%)_std  ABPdias (mmHg)_std  ABPsys (mmHg)_std  \
# 0               0.034349      0.130262            0.464431           0.032658
# 1               0.046631      0.000000            0.059377           0.027324
# 2               0.086488      0.000000            0.089865           0.043004
# 3               0.055561      0.000000            0.057476           0.036063
# 4               0.390826      0.210091            0.436697           0.182819
# ...                  ...           ...                 ...                ...
# 1280            0.105368      0.084224            0.095143           0.064071
# 1281            0.051985      0.100246            0.066836           0.031710
# 1282            0.121227      0.129924            0.115223           0.066516
# 1283            0.043542      0.175325            0.033496           0.028888
# 1284            0.124271      0.000000            0.110717           0.076031
#
#      record  record_index
# 0      052n             0
# 1      052n             1
# 2      052n             2
# 3      052n             3
# 4      052n             4
# ...     ...           ...
# 1280   052n          1280
# 1281   052n          1281
# 1282   052n          1282
# 1283   052n          1283
# 1284   052n          1284
#
# [1285 rows x 14 columns]

# %%
downsampled_df.to_csv(fp_downsampled_continuous_file, index=False)

# %% [markdown]
# ## Flatten Data and Generate Data for Training

# %%
# Update feat set
downsampled_feat_set = [f"{feat}_mean" for feat in feat_set] + [f"{feat}_std" for feat in feat_set] 
print(downsampled_feat_set)
# Out:
# ['HR (bpm)_mean', 'RESP (bpm)_mean', 'ABPmean (mmHg)_mean', 'SpO2 (%)_mean', 'ABPdias (mmHg)_mean', 'ABPsys (mmHg)_mean', 'HR (bpm)_std', 'RESP (bpm)_std', 'ABPmean (mmHg)_std', 'SpO2 (%)_std', 'ABPdias (mmHg)_std', 'ABPsys (mmHg)_std']

# %%
pred_cols = [f"{feat}_mean" for feat in feat_set]
print(pred_cols)
# Out:
# ['HR (bpm)_mean', 'RESP (bpm)_mean', 'ABPmean (mmHg)_mean', 'SpO2 (%)_mean', 'ABPdias (mmHg)_mean', 'ABPsys (mmHg)_mean']

# %%
def generate_data_for_training(
    downsampled_df, downsampled_feat_set, input_mins, prediction_mins, pred_cols):
    data = []
    downsampled_feat_set = list(downsampled_feat_set)
    # The flattened features for past input_days
    new_feat_set = [feat + " Min" + str(i) for i in range(input_mins) for feat in downsampled_feat_set] + \
        [feat + " PredMin" + str(i) for i in prediction_mins for feat in pred_cols] + \
        ["target_index"] + ["input_start_index"] + ["input_end_index"] + ["record"]

    # Sort prediction mins e.g. 1, 3, 2 -> 1, 2, 3
    prediction_mins.sort() 
    # For each record
    record_groups = downsampled_df.groupby("record")
    for record, record_df in tqdm(record_groups):
        record_df = record_df.set_index("record_index")
        # Go through possible end_input indices
        for end_input in record_df.index:
            # Not enough input information
            if end_input < input_mins-1:
                continue
            # Not enough pred information
            elif end_input + prediction_mins[-1] > record_df.index[-1]:
                break
            start_input = end_input - input_mins + 1
            # (input) 0 1 2 3 4, (output) 5, 6, 7
            pred_indices = [end_input + pred_min for pred_min in prediction_mins]
            # Get the rows we are predicting
            pred_rows = record_df[pred_cols].loc[pred_indices]
            # Get rows we are using to predict
            input_rows = record_df[downsampled_feat_set].loc[start_input:end_input]
            
            # Get input
            feat_list = list(input_rows.values.flatten())
            # Get prediction
            pred_list = list(pred_rows.values.flatten())
            
            # Add row
            new_row = (
                feat_list + pred_list +
                [pred_rows.index.tolist(), start_input, end_input, record]
            )
            data.append(new_row)
    return pd.DataFrame(data, columns=new_feat_set)

flattened_df = generate_data_for_training(
    downsampled_df, downsampled_feat_set, input_mins=5, prediction_mins=[1, 2, 3], pred_cols=pred_cols)
flattened_df.head()
# Out:
# 100%|███████████████████████████████████████████| 57/57 [01:03<00:00,  1.11s/it]
#    HR (bpm)_mean Min0  RESP (bpm)_mean Min0  ABPmean (mmHg)_mean Min0  \
# 0           -0.152358                   NaN                  0.912202
# 1           -0.253263                   NaN                  0.032295
# 2           -0.309104                   NaN                 -0.117837
# 3           -0.221914                   NaN                  0.189887
# 4           -0.031860                   NaN                  1.339660
#
#    SpO2 (%)_mean Min0  ABPdias (mmHg)_mean Min0  ABPsys (mmHg)_mean Min0  \
# 0            0.075853                  1.222590                 0.610158
# 1           -0.675816                  0.029305                -0.021607
# 2           -0.740775                 -0.255456                -0.099080
# 3           -0.801094                  0.065465                 0.144838
# 4           -0.264647                  1.572892                 1.044852
#
#    HR (bpm)_std Min0  RESP (bpm)_std Min0  ABPmean (mmHg)_std Min0  \
# 0           0.067019                  NaN                 0.708760
# 1           0.031163                  NaN                 0.265037
# 2           0.047749                  NaN                 0.064187
# 3           0.054569                  NaN                 0.239340
# 4           0.090863                  NaN                 0.130383
#
#    SpO2 (%)_std Min0  ...  HR (bpm)_mean PredMin3  RESP (bpm)_mean PredMin3  \
# 0           0.200492  ...                0.319839                       NaN
# 1           0.186225  ...                0.262039                       NaN
# 2           0.153486  ...                0.098436                       NaN
# 3           0.176259  ...                0.032798                       NaN
# 4           0.197597  ...               -0.025982                       NaN
#
#    ABPmean (mmHg)_mean PredMin3  SpO2 (%)_mean PredMin3  \
# 0                      2.417630               -0.230382
# 1                      2.139745               -1.078782
# 2                      1.297697               -1.842548
# 3                      1.345255               -0.325037
# 4                      1.001162               -0.156144
#
#    ABPdias (mmHg)_mean PredMin3  ABPsys (mmHg)_mean PredMin3  target_index  \
# 0                      2.771827                     1.934577     [5, 6, 7]
# 1                      2.593286                     1.705791     [6, 7, 8]
# 2                      1.648602                     0.894749     [7, 8, 9]
# 3                      1.754822                     0.782172    [8, 9, 10]
# 4                      1.235020                     0.639332   [9, 10, 11]
#
#    input_start_index  input_end_index  record
# 0                  0                4    048n
# 1                  1                5    048n
# 2                  2                6    048n
# 3                  3                7    048n
# 4                  4                8    048n
#
# [5 rows x 82 columns]

# %%
flattened_df.shape # previously, 119780
# Out:
# (119780, 82)

# %% [markdown]
# ## Remove Rows With NaN Values

# %%
flattened_df = flattened_df.dropna()
flattened_df.head()
# Out:
#     HR (bpm)_mean Min0  RESP (bpm)_mean Min0  ABPmean (mmHg)_mean Min0  \
# 18            0.014185              0.756224                  0.787620
# 19           -0.091619             -0.150253                  0.395037
# 20           -0.198402             -0.223392                  0.114355
# 21           -0.163586              0.339555                  0.601120
# 22           -0.294409             -0.615682                  0.649610
#
#     SpO2 (%)_mean Min0  ABPdias (mmHg)_mean Min0  ABPsys (mmHg)_mean Min0  \
# 18           -0.095824                  0.656458                 0.701673
# 19            0.052653                  0.421417                 0.216258
# 20           -0.132944                  0.120835                 0.063734
# 21           -0.689736                  0.607867                 0.493465
# 22           -0.527338                  0.714088                 0.555201
#
#     HR (bpm)_std Min0  RESP (bpm)_std Min0  ABPmean (mmHg)_std Min0  \
# 18           0.032406             0.975804                 0.095789
# 19           0.132176             0.333454                 0.520543
# 20           0.058103             0.401908                 0.308951
# 21           0.056324             0.303800                 0.154450
# 22           0.039157             0.436255                 0.203398
#
#     SpO2 (%)_std Min0  ...  HR (bpm)_mean PredMin3  RESP (bpm)_mean PredMin3  \
# 18           0.140295  ...               -0.227792                  0.257551
# 19           0.126509  ...               -0.282653                  0.590000
# 20           0.139669  ...               -0.231711                  0.463669
# 21           0.385024  ...               -0.225833                  0.242036
# 22           0.140060  ...               -0.265019                  0.124571
#
#     ABPmean (mmHg)_mean PredMin3  SpO2 (%)_mean PredMin3  \
# 18                      0.954537               -0.230382
# 19                      0.883667               -0.235022
# 20                      1.039395               -0.230382
# 21                      0.663597               -0.081905
# 22                      0.421147               -0.583017
#
#     ABPdias (mmHg)_mean PredMin3  ABPsys (mmHg)_mean PredMin3  target_index  \
# 18                      1.023709                     0.893539  [23, 24, 25]
# 19                      0.940089                     0.730120  [24, 25, 26]
# 20                      1.050829                     0.822119  [25, 26, 27]
# 21                      0.663238                     0.526754  [26, 27, 28]
# 22                      0.611258                     0.089155  [27, 28, 29]
#
#     input_start_index  input_end_index  record
# 18                 18               22    048n
# 19                 19               23    048n
# 20                 20               24    048n
# 21                 21               25    048n
# 22                 22               26    048n
#
# [5 rows x 82 columns]

# %%
flattened_df.shape # previously 90000+
# Out:
# (59566, 82)

# %%
flattened_df["ABPmean (mmHg)_mean PredMin1"].hist()
# Out:
# <Axes: >

# %%
def label_train_valid_test_samples(df, train_records, valid_records, test_records):
    df = df.copy()
    df["train"] = df["record"].isin(train_records)
    df["valid"] = df["record"].isin(valid_records)
    df["test"] = df["record"].isin(test_records)
    return df

train_valid_test_labelled_df = label_train_valid_test_samples(flattened_df, train_records, valid_records, test_records)
train_valid_test_labelled_df.head()
# Out:
#     HR (bpm)_mean Min0  RESP (bpm)_mean Min0  ABPmean (mmHg)_mean Min0  \
# 18            0.014185              0.756224                  0.787620
# 19           -0.091619             -0.150253                  0.395037
# 20           -0.198402             -0.223392                  0.114355
# 21           -0.163586              0.339555                  0.601120
# 22           -0.294409             -0.615682                  0.649610
#
#     SpO2 (%)_mean Min0  ABPdias (mmHg)_mean Min0  ABPsys (mmHg)_mean Min0  \
# 18           -0.095824                  0.656458                 0.701673
# 19            0.052653                  0.421417                 0.216258
# 20           -0.132944                  0.120835                 0.063734
# 21           -0.689736                  0.607867                 0.493465
# 22           -0.527338                  0.714088                 0.555201
#
#     HR (bpm)_std Min0  RESP (bpm)_std Min0  ABPmean (mmHg)_std Min0  \
# 18           0.032406             0.975804                 0.095789
# 19           0.132176             0.333454                 0.520543
# 20           0.058103             0.401908                 0.308951
# 21           0.056324             0.303800                 0.154450
# 22           0.039157             0.436255                 0.203398
#
#     SpO2 (%)_std Min0  ...  SpO2 (%)_mean PredMin3  \
# 18           0.140295  ...               -0.230382
# 19           0.126509  ...               -0.235022
# 20           0.139669  ...               -0.230382
# 21           0.385024  ...               -0.081905
# 22           0.140060  ...               -0.583017
#
#     ABPdias (mmHg)_mean PredMin3  ABPsys (mmHg)_mean PredMin3  target_index  \
# 18                      1.023709                     0.893539  [23, 24, 25]
# 19                      0.940089                     0.730120  [24, 25, 26]
# 20                      1.050829                     0.822119  [25, 26, 27]
# 21                      0.663238                     0.526754  [26, 27, 28]
# 22                      0.611258                     0.089155  [27, 28, 29]
#
#     input_start_index  input_end_index  record  train  valid   test
# 18                 18               22    048n   True  False  False
# 19                 19               23    048n   True  False  False
# 20                 20               24    048n   True  False  False
# 21                 21               25    048n   True  False  False
# 22                 22               26    048n   True  False  False
#
# [5 rows x 85 columns]

# %%
train_valid_test_labelled_df.to_csv(fp_downsampled_dropna_file)
